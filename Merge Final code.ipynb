# %%
import cv2
import torch
from ultralytics import YOLO

# %%
def natural_sort_key(filename):
    """Extract numerical values from filenames for correct sorting."""
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', filename)]

# %%
def detect_objects(model, image_path):
    image = cv2.imread(image_path)
    results = model(image)  # Perform object detection
    return results, image

# %%
def get_ceiling_floor_coordinates(results, floor_model):
    ceiling_y = None  # Initialize
    floor_y = None  # Initialize
    best_ceiling = None
    best_floor = None

    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coords
            confidence = float(box.conf[0].cpu().numpy())  # Confidence score
            class_id = int(box.cls[0].cpu().numpy())  # Class ID
            
            class_name = floor_model.names.get(class_id, "Unknown")

            if class_name == "ceiling":
                if best_ceiling is None or confidence > best_ceiling[1]:
                    best_ceiling = ((x1, y1, x2, y2), confidence)

            if class_name == "floor":
                if best_floor is None or confidence > best_floor[1]:
                    best_floor = ((x1, y1, x2, y2), confidence)

    ceiling_mid, floor_mid = None, None  

    if best_ceiling:
        (_, ceiling_y1, _, ceiling_y2), _ = best_ceiling
        ceiling_y = (ceiling_y1 + ceiling_y2)// 2  # Midpoint

    if best_floor:
        (_, floor_y1, _, floor_y2), _ = best_floor
        floor_y = (floor_y1 + floor_y2)// 2  # Midpoint

    return ceiling_y, floor_y

# %%
def get_floor_coordinates(results):
    """Extract the top Y-coordinate and bounding box of the floor"""
    floor_y_top = None
    floor_box = None
    
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls.cpu().numpy().item())  # Get class ID
            x_min, y_min, x_max, y_max = map(int, box.xyxy[0])  # Bounding box
            
            if class_id == 1:  # Assuming class 1 is "floor"
                floor_y_top = y_min  # Top Y-coordinate of floor
                floor_box = (x_min, y_min, x_max, y_max)
    
    return floor_y_top, floor_box

# %%
def get_propeller_coordinates(results):
    """Extract the bottom Y-coordinates and bounding boxes of propellers"""
    propeller_boxes = []  # Store bounding boxes of detected propellers
    propeller_y_bottoms = []  # Store Y-bottom of propellers
    
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls.cpu().numpy().item())  # Get class ID
            x_min, y_min, x_max, y_max = map(int, box.xyxy[0])  # Bounding box
            
            if class_id == 0:  # Assuming class 0 is "propeller"
                propeller_y_bottoms.append(y_max)  # Store bottom Y-coordinate
                propeller_boxes.append((x_min, y_min, x_max, y_max))
    
    return propeller_y_bottoms, propeller_boxes

# %%
def detect_height_bottle(image_path, model):
    """Detect Coca-Cola bottles and return their bounding box height in pixels."""
    image = cv2.imread(image_path)
    results = model(image)
    
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Bounding box coordinates
            height_pixels = y2 - y1  # Bottle height in pixels
            real_height_cm = 26  # Known height of Coca-Cola bottle
            
            pixel_to_cm_ratio = real_height_cm / height_pixels
            estimated_real_height = height_pixels * pixel_to_cm_ratio
            
            return height_pixels, estimated_real_height

    return None, None  # If no bottle is detected

# %%
def calculate_height(ceiling_y, floor_y, calibration_obj):
    """Calculate ceiling height using a calibration object (Coca-Cola bottle)."""
    if ceiling_y is None or floor_y is None:
        print("Error: Ceiling or Floor not detected!")
        return None  # Avoid TypeError

    pixel_height = floor_y - ceiling_y

    if calibration_obj:
        real_height, obj_pixel_height = calibration_obj
        pixel_to_cm_ratio = real_height / obj_pixel_height
        return pixel_height * pixel_to_cm_ratio
    
    return pixel_height  # Return pixel height if no calibration object

# %%
def draw_detections(image, propeller_boxes, floor_box, calibration_obj, floor_results):
    best_ceiling = None
    best_floor = None  # Ensure variables are initialized

    for i, (x1, y1, x2, y2) in enumerate(propeller_boxes):  # Unpacking tuple directly
        x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])  # Ensure integer values
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
        
        # Calculate height from floor to propeller
        pixel_height = y1 - floor_box[1]
        real_height = calculate_height(y1, floor_box[1], calibration_obj)
        height_text = f"Height: {real_height:.2f} cm"
        
        # Draw text label
        cv2.putText(image, height_text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Label the calibration object
    if calibration_obj:
        real_height, obj_pixel_height = calibration_obj
        cal_text = f"Calibration: {real_height:.2f} cm ({obj_pixel_height} px)"
        cv2.putText(image, cal_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)
    
    # Process results
    for result in floor_results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coordinates
            confidence = float(box.conf[0].cpu().numpy())  # Confidence score
            class_id = int(box.cls[0].cpu().numpy())  # Class ID

            # Get class name correctly
            class_name = floor_model.names.get(class_id, "Unknown")  # Ensure we get the correct class label

            # Store the most confident "ceiling" and "floor" detection
            if class_name == "ceiling":
                if best_ceiling is None or confidence > best_ceiling[1]:
                    best_ceiling = ((x1, y1, x2, y2), confidence, class_name)

            if class_name == "floor":
                if best_floor is None or confidence > best_floor[1]:
                    best_floor = ((x1, y1, x2, y2), confidence, class_name)

    # Draw only the best detections on the image
    for best in [best_ceiling, best_floor]:
        if best is not None:  # Ensure best_ceiling and best_floor are not None
            (x1, y1, x2, y2), confidence, class_name = best
            label = f'{class_name}: {confidence:.2f}'
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    return image

# %%
def draw_annotations(image, coke_boxes, ceiling_y, floor_y, pixel_to_cm_ratio=None):
    """Draws bounding boxes, vertical line, and labels on the image."""
    annotated_image = image.copy()
    
    # Draw Coca-Cola bounding boxes
    for (x1, y1, x2, y2, height_pixels) in coke_boxes:
        cv2.rectangle(annotated_image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green box
        cv2.putText(annotated_image, f"{height_pixels}px", (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Draw vertical line from floor to ceiling
    if ceiling_y is not None and floor_y is not None:
        mid_x = image.shape[1] // 2  # Center x-coordinate
        cv2.line(annotated_image, (mid_x, ceiling_y), (mid_x, floor_y), (0, 0, 255), 2)  # Red line
        
        # Calculate real-world ceiling height if calibration object exists
        pixel_height = floor_y - ceiling_y
        if pixel_to_cm_ratio:
            real_ceiling_height = pixel_height * pixel_to_cm_ratio
            height_text = f"Height: {real_ceiling_height:.2f} cm"
        else:
            height_text = f"Height: {pixel_height} pixels"

        # Add text label
        cv2.putText(annotated_image, height_text, (mid_x + 10, (ceiling_y + floor_y) // 2),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    return annotated_image

# %%
# # Define folders
# image_folder = "Input_test_folder(3m approx)"
# output_folder = "output_test_folder(3m approx)"
# os.makedirs(output_folder, exist_ok=True)  # Ensure output folder exists

# coke_model_path = "best (8).pt"
# ceiling_floor_model_path = "best (5).pt"
# coke_model = YOLO(coke_model_path)  # Load Coca-Cola bottle detection model
# ceiling_floor_model = YOLO(ceiling_floor_model_path)
# image_heights = {}  # Declare outside to store all images' heights

# for image_name in os.listdir(image_folder):
#     if image_name.lower().endswith(('.jpg', '.jpeg', '.png')):
#         image_path = os.path.join(image_folder, image_name)

#         # Detect Coca-Cola bottle height
#         height_pixels, estimated_real_height = detect_height_bottle(image_path, coke_model)

#         if height_pixels is None:
#             print(f"Skipping {image_name}: No Coca-Cola bottle detected.")
#             continue

#         print(f"Detected Coca-Cola Bottle Height: {height_pixels:.2f} pixels")
#         print(f"Estimated Real-World Height: {estimated_real_height:.2f} cm")

#         # Detect ceiling and floor
#         results = ceiling_floor_model(image_path)
#         ceiling_y, floor_y = get_ceiling_floor_coordinates(results)

#         if ceiling_y is None or floor_y is None:
#             print(f"Skipping {image_name}: Ceiling or floor not detected.")
#             continue

#         # Calculate ceiling height using Coca-Cola bottle as a calibration object
#         calibration_obj = (estimated_real_height, height_pixels)
#         ceiling_height = calculate_height(ceiling_y, floor_y, calibration_obj)

#         print(f"Ceiling Height: {ceiling_height:.2f} cm")

#         # image_heights = {}

#         image_heights[image_name] = ceiling_height  # Dynamically update dictionary
#         image = cv2.imread(image_path)
        

#         # Detect objects
#         coke_boxes = detect_coke_bottle(image)
#         ceiling_y, floor_y = detect_ceiling_floor(image)
        
#         # Calibration: Use Coca-Cola bottle to calculate pixel-to-cm ratio
#         if coke_boxes:
#             real_coke_height_cm = 24
#             _, _, _, _, height_pixels = coke_boxes[0]  # First detected bottle
#             pixel_to_cm_ratio = real_coke_height_cm / height_pixels
#         else:
#             pixel_to_cm_ratio = None

#         # Draw results
#         annotated_image = draw_annotations(image, coke_boxes, ceiling_y, floor_y, pixel_to_cm_ratio)

#         # calculated_height = compute_height(image_name)  # Replace with your actual function
#         # image_heights[image_name] = calculated_height  # Dynamically update dictionary
#         # Save annotated image
#         output_path = os.path.join(output_folder, f"annotated_{image_name}")
#         cv2.imwrite(output_path, annotated_image)

# print("Processing complete! Check the 'output_images' folder.")

# This code able to calculate the height of floor to ceiling .

# import os
# image_folder = "Input_test_folder(3m approx)"
# output_folder = "Output_test_folder_propeller"
# model_floor_path = "best (5).pt"
# model_propeller_path = "best (9).pt"
# coke_model_path = "best (8).pt"
# coke_model = YOLO(coke_model_path)

# os.makedirs(output_folder, exist_ok=True)
# floor_model = load_model(model_floor_path)
# propeller_model = load_model(model_propeller_path)
# for image_name in os.listdir(image_folder):
#     image_path = os.path.join(image_folder, image_name)

    
    
#     height_pixels, estimated_real_height = detect_height_bottle(image_path, coke_model)

#     if height_pixels is None:
#         print(f"Skipping {image_name}: No Coca-Cola bottle detected.")
#         continue

#     print(f"Detected Coca-Cola Bottle Height: {height_pixels:.2f} pixels")
#     print(f"Estimated Real-World Height: {estimated_real_height:.2f} cm")
    
#     calibration_obj = (estimated_real_height,height_pixels)
    
#     floor_results, image = detect_objects(floor_model, image_path)
#     floor_y_top, floor_box = get_floor_coordinates(floor_results)
#     propeller_results, _ = detect_objects(propeller_model, image_path)
#     propeller_y_bottoms, propeller_boxes = get_propeller_coordinates(propeller_results)
#     if not propeller_boxes or floor_y_top is None:
#         print(f"No propellers or floor detected in {image_path}")
#         continue
#     print(f"\nImage: {image_path}")
#     for i, propeller_y_bottom in enumerate(propeller_y_bottoms):
#         real_height = calculate_height(propeller_y_bottom, floor_y_top, calibration_obj)
#         print(f"  Propeller {i+1}: {real_height:.2f} cm from floor")
#     output_image = draw_detections(image, propeller_boxes, floor_box, calibration_obj)
#     output_path = os.path.join(output_folder, image_name)
#     cv2.imwrite(output_path, output_image)
#     print(f"Output saved at: {output_path}")

# %%
# import os
# import re

# def natural_sort_key(filename):
#     """Extract numerical values from filenames for correct sorting."""
#     return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', filename)]

# # Define folders
# image_folder = "Input_test_folder(3m approx)"
# output_folder = "Output_test_folder_combined"
# os.makedirs(output_folder, exist_ok=True)

# # Load models
# coke_model = YOLO("best (8).pt")
# floor_model = YOLO("best (5).pt")
# propeller_model = YOLO("best (9).pt")

# image_heights = {}  # Declare outside to store all images' heights

# # Store image results
# image_results = []

# # Get and sort image filenames using natural sorting
# image_files = sorted(
#     [f for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))],
#     key=natural_sort_key
# )

# for image_name in image_files:  # Process images in correct order
#     image_path = os.path.join(image_folder, image_name)
    
#     # Detect Coca-Cola bottle height (for calibration)
#     height_pixels, estimated_real_height = detect_height_bottle(image_path, coke_model)
#     if height_pixels is None:
#         print(f"Skipping {image_name}: No Coca-Cola bottle detected.")
#         calibration_obj = None
#     else:
#         calibration_obj = (estimated_real_height, height_pixels)
    
#     # Detect ceiling and floor
#     floor_results, image = detect_objects(floor_model, image_path)
#     ceiling_y, floor_y = get_ceiling_floor_coordinates(floor_results)

#     if ceiling_y is None or floor_y is None:
#         ceiling_height = "XXXXX"
#     elif calibration_obj:
#         ceiling_height = f"{calculate_height(ceiling_y, floor_y, calibration_obj):.2f} cm"
#     else:
#         ceiling_height = "XXXXX"

#     print(f"Ceiling Height for {image_name}: {ceiling_height}")

#     # image_heights = {}

#     image_heights[image_name] = ceiling_height  # Dynamically update dictionary
#     image = cv2.imread(image_path)

#     # Detect propellers (AC)
#     propeller_results, _ = detect_objects(propeller_model, image_path)
#     propeller_y_bottoms, propeller_boxes = get_propeller_coordinates(propeller_results)
    
#     if propeller_boxes and calibration_obj:
#         propeller_heights = [f"{calculate_height(y, floor_y, calibration_obj):.2f} cm" for y in propeller_y_bottoms]
#     else:
#         propeller_heights = []

#     # Format AC height output
#     ac_height = ", ".join(propeller_heights) if propeller_heights else "YYYY"
#     print(f"AC Height for {image_name}: {ac_height}")

#     # Draw detections
#     if calibration_obj:
#         output_image = draw_detections(image, propeller_boxes, (floor_y, floor_y), calibration_obj)
#         output_path = os.path.join(output_folder, image_name)
#         cv2.imwrite(output_path, output_image)
#         print(f"Output saved at: {output_path}")

#     # Store results in required format
#     image_results.append(f"{image_name} | ID photo 123456 | Ceiling height {ceiling_height} | AC Height {ac_height}")

# # Print final results
# print("\nFinal Results:")
# for result in image_results:
#     print(result)

# %%
import os
import re
import cv2
import numpy as np

def natural_sort_key(filename):
    """Extract numerical values from filenames for correct sorting."""
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', filename)]

# Define folders
image_folder = "Input_test_folder(3m approx)"
output_folder = "OUTPUT"
os.makedirs(output_folder, exist_ok=True)

# Load models
coke_model = YOLO("best (8).pt")
floor_model = YOLO("best (5).pt")
propeller_model = YOLO("best (9).pt")

image_heights = {}  # Store detected ceiling heights
image_results = []

# Get and sort image filenames
image_files = sorted(
    [f for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))],
    key=natural_sort_key
)

i = 0
for image_name in image_files:
    image_path = os.path.join(image_folder, image_name)
    
    # Detect Coca-Cola bottle height (for calibration)
    height_pixels, estimated_real_height = detect_height_bottle(image_path, coke_model)
    calibration_obj = (estimated_real_height, height_pixels) if height_pixels else None
    
    # Detect ceiling and floor
    floor_results, image = detect_objects(floor_model, image_path)
    # Perform inference
        

    # Store the best detection for ceiling and floor
    # best_ceiling = None
    # best_floor = None

    # # Process results
    # for result in floor_results:
    #     for box in result.boxes:
    #         x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coordinates
    #         confidence = float(box.conf[0].cpu().numpy())  # Confidence score
    #         class_id = int(box.cls[0].cpu().numpy())  # Class ID
                
    #         # Get class name correctly
    #         class_name = floor_model.names.get(class_id, "Unknown")  # Ensure we get the correct class label

    #         # Store the most confident "ceiling" and "floor" detection
    #         if class_name == "ceiling":
    #             if best_ceiling is None or confidence > best_ceiling[1]:
    #                 best_ceiling = ((x1, y1, x2, y2), confidence, class_name)

    #         if class_name == "floor":
    #             if best_floor is None or confidence > best_floor[1]:
    #                 best_floor = ((x1, y1, x2, y2), confidence, class_name)

    #     # Draw only the best detections on the image
    # for best in [best_ceiling, best_floor]:
    #     if best is not None:
    #         (x1, y1, x2, y2), confidence, class_name = best
    #         label = f'{class_name}: {confidence:.2f}'
    #         cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
    #         cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    
    ceiling_y,floor_y = get_ceiling_floor_coordinates(floor_results,floor_model)
    
    if ceiling_y is None or floor_y is None:
        ceiling_height = "XXXXX"
    elif calibration_obj:
        ceiling_height = calculate_height(ceiling_y, floor_y, calibration_obj)
    else:
        ceiling_height = "XXXXX"
    
    print(f"Ceiling Height for {image_name}: {ceiling_height}")
    
    if ceiling_height != "XXXXX":
        image_heights[image_name] = ceiling_height
    
    # Read the image
    image = cv2.imread(image_path)
    
    # Detect propellers (AC)
    propeller_results, _ = detect_objects(propeller_model, image_path)
    propeller_y_bottoms, propeller_boxes = get_propeller_coordinates(propeller_results)
    
    if propeller_boxes and calibration_obj:
        propeller_heights = [f"{calculate_height(y, floor_y, calibration_obj):.2f} cm" for y in propeller_y_bottoms]
    else:
        propeller_heights = []
    
    ac_height = ", ".join(propeller_heights) if propeller_heights else "YYYY"
    print(f"AC Height for {image_name}: {ac_height}")
    
    
    # Draw vertical reference line
    if ceiling_y is not None and floor_y is not None and ceiling_height != "XXXXX":
        mid_x = image.shape[1] // 2
        cv2.line(image, (mid_x, ceiling_y), (mid_x, floor_y), (0, 255, 0), 3)
        text_position = (mid_x + 10, (ceiling_y + floor_y) // 2)
        cv2.putText(image, f"{ceiling_height:.2f} cm", text_position, cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
    # Draw propeller detections
    if calibration_obj:
        output_image = draw_detections(image, propeller_boxes, (floor_y, floor_y), calibration_obj,floor_results)
        output_path = os.path.join(output_folder, image_name)
        cv2.imwrite(output_path, output_image)
        print(f"Output saved at: {output_path}")
    
    # Store results
    image_results.append(f"Photo {i+1} | ID {image_name} | Ceiling height {ceiling_height} | AC Height {ac_height}")
    i += 1

# Print final results
print("\nFinal Results:")
for result in image_results:
    print(result)
# Out:
# 0: 800x608 1 750ml coke, 436.0ms
# Speed: 4.2ms preprocess, 436.0ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 4 wallss, 334.6ms
# Speed: 2.5ms preprocess, 334.6ms inference, 11.7ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image1.jpeg: 307.62640380859375
#
# 0: 800x608 (no detections), 343.8ms
# Speed: 5.3ms preprocess, 343.8ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image1.jpeg: YYYY
# Output saved at: OUTPUT/image1.jpeg
#
# 0: 800x608 1 750ml coke, 343.6ms
# Speed: 4.1ms preprocess, 343.6ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 5 floors, 2 wallss, 324.2ms
# Speed: 2.7ms preprocess, 324.2ms inference, 9.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image2.jpeg: XXXXX
#
# 0: 800x608 (no detections), 345.2ms
# Speed: 4.0ms preprocess, 345.2ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image2.jpeg: YYYY
# Output saved at: OUTPUT/image2.jpeg
#
# 0: 800x608 2 750ml cokes, 335.3ms
# Speed: 4.0ms preprocess, 335.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 1 walls, 310.1ms
# Speed: 2.2ms preprocess, 310.1ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image3.jpeg: 304.51629638671875
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 338.3ms
# Speed: 3.6ms preprocess, 338.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image3.jpeg: 173.87 cm
# Output saved at: OUTPUT/image3.jpeg
#
# 0: 800x608 2 750ml cokes, 332.9ms
# Speed: 3.9ms preprocess, 332.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 2 wallss, 323.7ms
# Speed: 3.2ms preprocess, 323.7ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image4.jpeg: 328.1935119628906
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 333.7ms
# Speed: 3.4ms preprocess, 333.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image4.jpeg: 216.60 cm
# Output saved at: OUTPUT/image4.jpeg
#
# 0: 800x608 1 750ml coke, 339.8ms
# Speed: 3.5ms preprocess, 339.8ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 2 wallss, 301.8ms
# Speed: 2.1ms preprocess, 301.8ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image5.jpeg: 368.6772766113281
#
# 0: 800x608 4 Propellers detection - v1 2025-02-20 11-43ams, 338.0ms
# Speed: 3.9ms preprocess, 338.0ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image5.jpeg: 202.35 cm, 266.27 cm, 294.87 cm, 250.73 cm
# Output saved at: OUTPUT/image5.jpeg
#
# 0: 800x608 1 750ml coke, 339.9ms
# Speed: 3.5ms preprocess, 339.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 5 wallss, 303.5ms
# Speed: 2.4ms preprocess, 303.5ms inference, 10.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image6.jpeg: 351.9576721191406
#
# 0: 800x608 (no detections), 333.2ms
# Speed: 3.5ms preprocess, 333.2ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image6.jpeg: YYYY
# Output saved at: OUTPUT/image6.jpeg
#
# 0: 800x608 1 750ml coke, 334.3ms
# Speed: 4.1ms preprocess, 334.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 5 wallss, 303.8ms
# Speed: 3.0ms preprocess, 303.8ms inference, 10.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image7.jpeg: 321.4752502441406
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 330.0ms
# Speed: 4.0ms preprocess, 330.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image7.jpeg: 205.35 cm, 166.19 cm
# Output saved at: OUTPUT/image7.jpeg
#
# 0: 800x608 1 750ml coke, 333.6ms
# Speed: 4.0ms preprocess, 333.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 floors, 1 walls, 301.7ms
# Speed: 2.4ms preprocess, 301.7ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image8.jpeg: XXXXX
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 340.7ms
# Speed: 3.6ms preprocess, 340.7ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image8.jpeg: 299.79 cm
# Output saved at: OUTPUT/image8.jpeg
#
# 0: 800x608 2 750ml cokes, 344.1ms
# Speed: 3.4ms preprocess, 344.1ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 4 floors, 1 walls, 300.0ms
# Speed: 2.1ms preprocess, 300.0ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image9.jpeg: 298.9192199707031
#
# 0: 800x608 3 Propellers detection - v1 2025-02-20 11-43ams, 330.3ms
# Speed: 3.5ms preprocess, 330.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image9.jpeg: 193.49 cm, 155.25 cm, 209.89 cm
# Output saved at: OUTPUT/image9.jpeg
#
# 0: 800x608 1 750ml coke, 345.8ms
# Speed: 3.8ms preprocess, 345.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 2 wallss, 303.8ms
# Speed: 2.1ms preprocess, 303.8ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image10.jpeg: 379.2301330566406
#
# 0: 800x608 5 Propellers detection - v1 2025-02-20 11-43ams, 337.4ms
# Speed: 3.8ms preprocess, 337.4ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image10.jpeg: 256.92 cm, 251.86 cm, 233.40 cm, 238.10 cm, 223.27 cm
# Output saved at: OUTPUT/image10.jpeg
#
# 0: 800x608 1 750ml coke, 337.8ms
# Speed: 3.7ms preprocess, 337.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 3 wallss, 296.2ms
# Speed: 2.2ms preprocess, 296.2ms inference, 9.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image11.jpeg: 314.8735656738281
#
# 0: 800x608 4 Propellers detection - v1 2025-02-20 11-43ams, 331.2ms
# Speed: 3.8ms preprocess, 331.2ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image11.jpeg: 188.50 cm, 192.75 cm, 192.22 cm, 67.17 cm
# Output saved at: OUTPUT/image11.jpeg
#
# 0: 800x608 2 750ml cokes, 376.6ms
# Speed: 4.5ms preprocess, 376.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 floor, 3 wallss, 303.5ms
# Speed: 2.2ms preprocess, 303.5ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image12.jpeg: XXXXX
#
# 0: 800x608 (no detections), 341.8ms
# Speed: 4.4ms preprocess, 341.8ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image12.jpeg: YYYY
# Output saved at: OUTPUT/image12.jpeg
#
# 0: 800x608 1 750ml coke, 340.7ms
# Speed: 3.7ms preprocess, 340.7ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 floors, 3 wallss, 304.5ms
# Speed: 2.0ms preprocess, 304.5ms inference, 9.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image13.jpeg: XXXXX
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 357.7ms
# Speed: 3.3ms preprocess, 357.7ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image13.jpeg: 161.21 cm
# Output saved at: OUTPUT/image13.jpeg
#
# 0: 800x608 1 750ml coke, 343.4ms
# Speed: 3.5ms preprocess, 343.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 5 floors, 3 wallss, 301.2ms
# Speed: 2.1ms preprocess, 301.2ms inference, 11.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image14.jpeg: 299.755859375
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 341.6ms
# Speed: 3.8ms preprocess, 341.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image14.jpeg: 262.46 cm
# Output saved at: OUTPUT/image14.jpeg
#
# 0: 800x608 2 750ml cokes, 331.0ms
# Speed: 3.9ms preprocess, 331.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 6 wallss, 296.1ms
# Speed: 2.5ms preprocess, 296.1ms inference, 11.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image15.jpeg: 300.988525390625
#
# 0: 800x608 (no detections), 342.7ms
# Speed: 3.6ms preprocess, 342.7ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image15.jpeg: YYYY
# Output saved at: OUTPUT/image15.jpeg
#
# 0: 800x608 2 750ml cokes, 333.7ms
# Speed: 3.6ms preprocess, 333.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 5 wallss, 308.0ms
# Speed: 2.2ms preprocess, 308.0ms inference, 12.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image16.jpeg: 322.65887451171875
#
# 0: 800x608 (no detections), 339.8ms
# Speed: 3.9ms preprocess, 339.8ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image16.jpeg: YYYY
# Output saved at: OUTPUT/image16.jpeg
#
# 0: 800x608 1 750ml coke, 330.8ms
# Speed: 4.1ms preprocess, 330.8ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 4 wallss, 294.3ms
# Speed: 2.2ms preprocess, 294.3ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image17.jpeg: 305.1661376953125
#
# 0: 800x608 (no detections), 337.3ms
# Speed: 3.7ms preprocess, 337.3ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image17.jpeg: YYYY
# Output saved at: OUTPUT/image17.jpeg
#
# 0: 800x608 1 750ml coke, 337.2ms
# Speed: 3.4ms preprocess, 337.2ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 7 wallss, 304.3ms
# Speed: 2.3ms preprocess, 304.3ms inference, 14.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image18.jpeg: 285.68414306640625
#
# 0: 800x608 (no detections), 338.8ms
# Speed: 3.4ms preprocess, 338.8ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image18.jpeg: YYYY
# Output saved at: OUTPUT/image18.jpeg
#
# 0: 800x608 1 750ml coke, 338.3ms
# Speed: 3.5ms preprocess, 338.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 2 wallss, 310.7ms
# Speed: 1.9ms preprocess, 310.7ms inference, 8.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image19.jpeg: 264.6062927246094
#
# 0: 800x608 (no detections), 330.7ms
# Speed: 3.9ms preprocess, 330.7ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image19.jpeg: YYYY
# Output saved at: OUTPUT/image19.jpeg
#
# 0: 800x608 1 750ml coke, 371.4ms
# Speed: 3.4ms preprocess, 371.4ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 4 wallss, 351.9ms
# Speed: 3.2ms preprocess, 351.9ms inference, 15.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image20.jpeg: 289.513427734375
#
# 0: 800x608 (no detections), 367.3ms
# Speed: 3.6ms preprocess, 367.3ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image20.jpeg: YYYY
# Output saved at: OUTPUT/image20.jpeg
#
# 0: 800x608 1 750ml coke, 385.3ms
# Speed: 8.0ms preprocess, 385.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 floor, 4 wallss, 386.1ms
# Speed: 1.9ms preprocess, 386.1ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image21.jpeg: XXXXX
#
# 0: 800x608 (no detections), 351.5ms
# Speed: 3.7ms preprocess, 351.5ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image21.jpeg: YYYY
# Output saved at: OUTPUT/image21.jpeg
#
# 0: 800x608 1 750ml coke, 389.3ms
# Speed: 4.3ms preprocess, 389.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 4 floors, 8 wallss, 302.8ms
# Speed: 1.9ms preprocess, 302.8ms inference, 22.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image22.jpeg: 273.50665283203125
#
# 0: 800x608 (no detections), 491.4ms
# Speed: 4.5ms preprocess, 491.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image22.jpeg: YYYY
# Output saved at: OUTPUT/image22.jpeg
#
# 0: 800x608 1 750ml coke, 374.8ms
# Speed: 8.9ms preprocess, 374.8ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 9 wallss, 324.5ms
# Speed: 2.6ms preprocess, 324.5ms inference, 20.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image23.jpeg: 323.05523681640625
#
# 0: 800x608 (no detections), 405.0ms
# Speed: 6.5ms preprocess, 405.0ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image23.jpeg: YYYY
# Output saved at: OUTPUT/image23.jpeg
#
# 0: 800x608 1 750ml coke, 417.1ms
# Speed: 5.0ms preprocess, 417.1ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 3 wallss, 320.4ms
# Speed: 2.1ms preprocess, 320.4ms inference, 12.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image24.jpeg: 272.6295166015625
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 380.3ms
# Speed: 3.9ms preprocess, 380.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image24.jpeg: 218.10 cm, 246.75 cm
# Output saved at: OUTPUT/image24.jpeg
#
# 0: 800x608 2 750ml cokes, 432.8ms
# Speed: 9.6ms preprocess, 432.8ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 floors, 4 wallss, 436.6ms
# Speed: 4.0ms preprocess, 436.6ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image25.jpeg: XXXXX
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 345.3ms
# Speed: 5.3ms preprocess, 345.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image25.jpeg: 256.72 cm
# Output saved at: OUTPUT/image25.jpeg
#
# 0: 800x608 1 750ml coke, 401.4ms
# Speed: 6.7ms preprocess, 401.4ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 5 wallss, 317.4ms
# Speed: 2.7ms preprocess, 317.4ms inference, 11.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image26.jpeg: 274.9057312011719
#
# 0: 800x608 (no detections), 375.8ms
# Speed: 4.2ms preprocess, 375.8ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image26.jpeg: YYYY
# Output saved at: OUTPUT/image26.jpeg
#
# 0: 800x608 1 750ml coke, 486.0ms
# Speed: 4.2ms preprocess, 486.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 2 floors, 4 wallss, 307.4ms
# Speed: 3.1ms preprocess, 307.4ms inference, 13.6ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image27.jpeg: 294.5539855957031
#
# 0: 800x608 (no detections), 359.5ms
# Speed: 4.4ms preprocess, 359.5ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image27.jpeg: YYYY
# Output saved at: OUTPUT/image27.jpeg
#
# 0: 800x608 1 750ml coke, 393.1ms
# Speed: 3.7ms preprocess, 393.1ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 3 floors, 10 wallss, 328.7ms
# Speed: 3.3ms preprocess, 328.7ms inference, 24.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image28.jpeg: 301.8333740234375
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 339.4ms
# Speed: 4.7ms preprocess, 339.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image28.jpeg: 220.19 cm
# Output saved at: OUTPUT/image28.jpeg
#
# 0: 800x608 1 750ml coke, 348.1ms
# Speed: 4.6ms preprocess, 348.1ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 2 floors, 5 wallss, 354.0ms
# Speed: 5.9ms preprocess, 354.0ms inference, 15.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image29.jpeg: 315.21002197265625
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 473.6ms
# Speed: 5.0ms preprocess, 473.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image29.jpeg: 272.98 cm, 258.21 cm
# Output saved at: OUTPUT/image29.jpeg
#
# 0: 800x608 1 750ml coke, 350.5ms
# Speed: 4.8ms preprocess, 350.5ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 4 wallss, 324.4ms
# Speed: 2.8ms preprocess, 324.4ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image30.jpeg: 321.8470764160156
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 452.1ms
# Speed: 3.8ms preprocess, 452.1ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image30.jpeg: 241.03 cm
# Output saved at: OUTPUT/image30.jpeg
#
# 0: 800x608 1 750ml coke, 398.1ms
# Speed: 14.4ms preprocess, 398.1ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 6 wallss, 315.2ms
# Speed: 3.1ms preprocess, 315.2ms inference, 15.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image31.jpeg: 249.3293914794922
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 344.2ms
# Speed: 3.9ms preprocess, 344.2ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image31.jpeg: 293.25 cm, 264.53 cm
# Output saved at: OUTPUT/image31.jpeg
#
# 0: 800x608 1 750ml coke, 332.7ms
# Speed: 4.8ms preprocess, 332.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 5 wallss, 305.5ms
# Speed: 3.8ms preprocess, 305.5ms inference, 10.6ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image32.jpeg: 245.54425048828125
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 351.0ms
# Speed: 8.9ms preprocess, 351.0ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image32.jpeg: 237.09 cm
# Output saved at: OUTPUT/image32.jpeg
#
# 0: 800x608 1 750ml coke, 351.8ms
# Speed: 4.6ms preprocess, 351.8ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 4 floors, 5 wallss, 365.3ms
# Speed: 2.1ms preprocess, 365.3ms inference, 17.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image33.jpeg: 290.0688171386719
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 405.8ms
# Speed: 5.8ms preprocess, 405.8ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image33.jpeg: 282.88 cm
# Output saved at: OUTPUT/image33.jpeg
#
# 0: 800x608 1 750ml coke, 405.4ms
# Speed: 10.8ms preprocess, 405.4ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 floor, 1 walls, 406.1ms
# Speed: 2.9ms preprocess, 406.1ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image34.jpeg: XXXXX
#
# 0: 800x608 (no detections), 412.4ms
# Speed: 4.3ms preprocess, 412.4ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image34.jpeg: YYYY
# Output saved at: OUTPUT/image34.jpeg
#
# 0: 800x608 1 750ml coke, 478.0ms
# Speed: 5.2ms preprocess, 478.0ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 2 floors, 10 wallss, 426.3ms
# Speed: 2.9ms preprocess, 426.3ms inference, 28.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image35.jpeg: 343.8022155761719
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 576.8ms
# Speed: 15.1ms preprocess, 576.8ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image35.jpeg: 300.05 cm, 261.20 cm
# Output saved at: OUTPUT/image35.jpeg
#
# 0: 800x608 1 750ml coke, 455.7ms
# Speed: 4.1ms preprocess, 455.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 5 wallss, 427.9ms
# Speed: 10.4ms preprocess, 427.9ms inference, 16.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image36.jpeg: 252.3086395263672
#
# 0: 800x608 3 Propellers detection - v1 2025-02-20 11-43ams, 437.9ms
# Speed: 9.1ms preprocess, 437.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image36.jpeg: 303.22 cm, 242.32 cm, 193.98 cm
# Output saved at: OUTPUT/image36.jpeg
#
# 0: 800x608 1 750ml coke, 449.3ms
# Speed: 7.6ms preprocess, 449.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 4 wallss, 399.4ms
# Speed: 5.6ms preprocess, 399.4ms inference, 13.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image37.jpeg: 338.0289001464844
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 458.9ms
# Speed: 4.5ms preprocess, 458.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image37.jpeg: 260.49 cm, 281.64 cm
# Output saved at: OUTPUT/image37.jpeg
#
# 0: 800x608 1 750ml coke, 434.8ms
# Speed: 5.0ms preprocess, 434.8ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 4 wallss, 430.4ms
# Speed: 2.4ms preprocess, 430.4ms inference, 17.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image38.jpeg: 294.5360107421875
#
# 0: 800x608 (no detections), 441.3ms
# Speed: 9.2ms preprocess, 441.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image38.jpeg: YYYY
# Output saved at: OUTPUT/image38.jpeg
#
# 0: 800x608 2 750ml cokes, 432.6ms
# Speed: 5.9ms preprocess, 432.6ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 5 wallss, 380.1ms
# Speed: 2.4ms preprocess, 380.1ms inference, 16.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image39.jpeg: 344.34552001953125
#
# 0: 800x608 (no detections), 421.4ms
# Speed: 5.1ms preprocess, 421.4ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image39.jpeg: YYYY
# Output saved at: OUTPUT/image39.jpeg
#
# 0: 800x608 1 750ml coke, 397.6ms
# Speed: 5.3ms preprocess, 397.6ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 8 wallss, 452.9ms
# Speed: 25.5ms preprocess, 452.9ms inference, 17.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image40.jpeg: 361.7627258300781
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 417.3ms
# Speed: 5.0ms preprocess, 417.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image40.jpeg: 204.75 cm, 206.10 cm
# Output saved at: OUTPUT/image40.jpeg
#
# 0: 800x608 1 750ml coke, 405.3ms
# Speed: 9.3ms preprocess, 405.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 5 ceilings, 1 floor, 6 wallss, 366.4ms
# Speed: 5.0ms preprocess, 366.4ms inference, 21.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image41.jpeg: 267.814208984375
#
# 0: 800x608 (no detections), 404.4ms
# Speed: 4.8ms preprocess, 404.4ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image41.jpeg: YYYY
# Output saved at: OUTPUT/image41.jpeg
#
# 0: 800x608 1 750ml coke, 409.6ms
# Speed: 5.2ms preprocess, 409.6ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 3 wallss, 360.8ms
# Speed: 4.9ms preprocess, 360.8ms inference, 10.6ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image42.jpeg: 326.19915771484375
#
# 0: 800x608 (no detections), 413.4ms
# Speed: 5.8ms preprocess, 413.4ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image42.jpeg: YYYY
# Output saved at: OUTPUT/image42.jpeg
#
# 0: 800x608 1 750ml coke, 411.8ms
# Speed: 4.2ms preprocess, 411.8ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 1 walls, 381.8ms
# Speed: 2.4ms preprocess, 381.8ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image43.jpeg: 314.77947998046875
#
# 0: 800x608 (no detections), 435.6ms
# Speed: 5.9ms preprocess, 435.6ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image43.jpeg: YYYY
# Output saved at: OUTPUT/image43.jpeg
#
# 0: 800x608 1 750ml coke, 403.0ms
# Speed: 6.8ms preprocess, 403.0ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 4 wallss, 376.0ms
# Speed: 3.3ms preprocess, 376.0ms inference, 13.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image44.jpeg: 328.72503662109375
#
# 0: 800x608 (no detections), 423.0ms
# Speed: 4.4ms preprocess, 423.0ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image44.jpeg: YYYY
# Output saved at: OUTPUT/image44.jpeg
#
# 0: 800x608 1 750ml coke, 522.3ms
# Speed: 5.4ms preprocess, 522.3ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 3 floors, 4 wallss, 364.5ms
# Speed: 2.6ms preprocess, 364.5ms inference, 16.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image45.jpeg: 313.1964111328125
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 420.1ms
# Speed: 5.2ms preprocess, 420.1ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image45.jpeg: 258.22 cm
# Output saved at: OUTPUT/image45.jpeg
#
# 0: 800x608 1 750ml coke, 412.9ms
# Speed: 6.5ms preprocess, 412.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 6 wallss, 375.2ms
# Speed: 2.4ms preprocess, 375.2ms inference, 17.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image46.jpeg: 262.62066650390625
#
# 0: 800x608 (no detections), 408.9ms
# Speed: 5.0ms preprocess, 408.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image46.jpeg: YYYY
# Output saved at: OUTPUT/image46.jpeg
#
# 0: 800x608 1 750ml coke, 418.6ms
# Speed: 6.6ms preprocess, 418.6ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 2 wallss, 433.3ms
# Speed: 3.6ms preprocess, 433.3ms inference, 7.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image47.jpeg: 309.025390625
#
# 0: 800x608 (no detections), 472.9ms
# Speed: 5.9ms preprocess, 472.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image47.jpeg: YYYY
# Output saved at: OUTPUT/image47.jpeg
#
# 0: 800x608 1 750ml coke, 481.0ms
# Speed: 4.7ms preprocess, 481.0ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 3 wallss, 411.5ms
# Speed: 2.8ms preprocess, 411.5ms inference, 11.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image48.jpeg: 330.5956115722656
#
# 0: 800x608 (no detections), 502.3ms
# Speed: 14.0ms preprocess, 502.3ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image48.jpeg: YYYY
# Output saved at: OUTPUT/image48.jpeg
#
# 0: 800x608 1 750ml coke, 422.2ms
# Speed: 7.1ms preprocess, 422.2ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 7 wallss, 381.9ms
# Speed: 3.1ms preprocess, 381.9ms inference, 17.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image49.jpeg: 278.7380065917969
#
# 0: 800x608 (no detections), 409.9ms
# Speed: 5.1ms preprocess, 409.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image49.jpeg: YYYY
# Output saved at: OUTPUT/image49.jpeg
#
# 0: 800x608 1 750ml coke, 501.2ms
# Speed: 7.2ms preprocess, 501.2ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 3 wallss, 386.2ms
# Speed: 4.6ms preprocess, 386.2ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image50.jpeg: 251.76600646972656
#
# 0: 800x608 (no detections), 462.4ms
# Speed: 4.6ms preprocess, 462.4ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image50.jpeg: YYYY
# Output saved at: OUTPUT/image50.jpeg
#
# 0: 800x608 2 750ml cokes, 408.4ms
# Speed: 5.1ms preprocess, 408.4ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 6 wallss, 366.9ms
# Speed: 3.1ms preprocess, 366.9ms inference, 20.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image51.jpeg: 337.9875793457031
#
# 0: 800x608 (no detections), 414.9ms
# Speed: 4.1ms preprocess, 414.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image51.jpeg: YYYY
# Output saved at: OUTPUT/image51.jpeg
#
# 0: 800x608 1 750ml coke, 443.7ms
# Speed: 4.3ms preprocess, 443.7ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 6 floors, 7 wallss, 377.9ms
# Speed: 5.6ms preprocess, 377.9ms inference, 24.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image52.jpeg: 201.9465789794922
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 401.5ms
# Speed: 7.6ms preprocess, 401.5ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image52.jpeg: 148.67 cm
# Output saved at: OUTPUT/image52.jpeg
#
# 0: 800x608 1 750ml coke, 556.9ms
# Speed: 12.6ms preprocess, 556.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 2 floors, 8 wallss, 359.5ms
# Speed: 3.0ms preprocess, 359.5ms inference, 20.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image53.jpeg: 257.3297119140625
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 420.0ms
# Speed: 5.3ms preprocess, 420.0ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image53.jpeg: 226.04 cm
# Output saved at: OUTPUT/image53.jpeg
#
# 0: 800x608 1 750ml coke, 429.6ms
# Speed: 4.3ms preprocess, 429.6ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 floors, 8 wallss, 376.3ms
# Speed: 2.7ms preprocess, 376.3ms inference, 19.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image54.jpeg: XXXXX
#
# 0: 800x608 (no detections), 409.3ms
# Speed: 6.6ms preprocess, 409.3ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image54.jpeg: YYYY
# Output saved at: OUTPUT/image54.jpeg
#
# Final Results:
# Photo 1 | ID image1.jpeg | Ceiling height 307.62640380859375 | AC Height YYYY
# Photo 2 | ID image2.jpeg | Ceiling height XXXXX | AC Height YYYY
# Photo 3 | ID image3.jpeg | Ceiling height 304.51629638671875 | AC Height 173.87 cm
# Photo 4 | ID image4.jpeg | Ceiling height 328.1935119628906 | AC Height 216.60 cm
# Photo 5 | ID image5.jpeg | Ceiling height 368.6772766113281 | AC Height 202.35 cm, 266.27 cm, 294.87 cm, 250.73 cm
# Photo 6 | ID image6.jpeg | Ceiling height 351.9576721191406 | AC Height YYYY
# Photo 7 | ID image7.jpeg | Ceiling height 321.4752502441406 | AC Height 205.35 cm, 166.19 cm
# Photo 8 | ID image8.jpeg | Ceiling height XXXXX | AC Height 299.79 cm
# Photo 9 | ID image9.jpeg | Ceiling height 298.9192199707031 | AC Height 193.49 cm, 155.25 cm, 209.89 cm
# Photo 10 | ID image10.jpeg | Ceiling height 379.2301330566406 | AC Height 256.92 cm, 251.86 cm, 233.40 cm, 238.10 cm, 223.27 cm
# Photo 11 | ID image11.jpeg | Ceiling height 314.8735656738281 | AC Height 188.50 cm, 192.75 cm, 192.22 cm, 67.17 cm
# Photo 12 | ID image12.jpeg | Ceiling height XXXXX | AC Height YYYY
# Photo 13 | ID image13.jpeg | Ceiling height XXXXX | AC Height 161.21 cm
# Photo 14 | ID image14.jpeg | Ceiling height 299.755859375 | AC Height 262.46 cm
# Photo 15 | ID image15.jpeg | Ceiling height 300.988525390625 | AC Height YYYY
# Photo 16 | ID image16.jpeg | Ceiling height 322.65887451171875 | AC Height YYYY
# Photo 17 | ID image17.jpeg | Ceiling height 305.1661376953125 | AC Height YYYY
# Photo 18 | ID image18.jpeg | Ceiling height 285.68414306640625 | AC Height YYYY
# Photo 19 | ID image19.jpeg | Ceiling height 264.6062927246094 | AC Height YYYY
# Photo 20 | ID image20.jpeg | Ceiling height 289.513427734375 | AC Height YYYY
# Photo 21 | ID image21.jpeg | Ceiling height XXXXX | AC Height YYYY
# Photo 22 | ID image22.jpeg | Ceiling height 273.50665283203125 | AC Height YYYY
# Photo 23 | ID image23.jpeg | Ceiling height 323.05523681640625 | AC Height YYYY
# Photo 24 | ID image24.jpeg | Ceiling height 272.6295166015625 | AC Height 218.10 cm, 246.75 cm
# Photo 25 | ID image25.jpeg | Ceiling height XXXXX | AC Height 256.72 cm
# Photo 26 | ID image26.jpeg | Ceiling height 274.9057312011719 | AC Height YYYY
# Photo 27 | ID image27.jpeg | Ceiling height 294.5539855957031 | AC Height YYYY
# Photo 28 | ID image28.jpeg | Ceiling height 301.8333740234375 | AC Height 220.19 cm
# Photo 29 | ID image29.jpeg | Ceiling height 315.21002197265625 | AC Height 272.98 cm, 258.21 cm
# Photo 30 | ID image30.jpeg | Ceiling height 321.8470764160156 | AC Height 241.03 cm
# Photo 31 | ID image31.jpeg | Ceiling height 249.3293914794922 | AC Height 293.25 cm, 264.53 cm
# Photo 32 | ID image32.jpeg | Ceiling height 245.54425048828125 | AC Height 237.09 cm
# Photo 33 | ID image33.jpeg | Ceiling height 290.0688171386719 | AC Height 282.88 cm
# Photo 34 | ID image34.jpeg | Ceiling height XXXXX | AC Height YYYY
# Photo 35 | ID image35.jpeg | Ceiling height 343.8022155761719 | AC Height 300.05 cm, 261.20 cm
# Photo 36 | ID image36.jpeg | Ceiling height 252.3086395263672 | AC Height 303.22 cm, 242.32 cm, 193.98 cm
# Photo 37 | ID image37.jpeg | Ceiling height 338.0289001464844 | AC Height 260.49 cm, 281.64 cm
# Photo 38 | ID image38.jpeg | Ceiling height 294.5360107421875 | AC Height YYYY
# Photo 39 | ID image39.jpeg | Ceiling height 344.34552001953125 | AC Height YYYY
# Photo 40 | ID image40.jpeg | Ceiling height 361.7627258300781 | AC Height 204.75 cm, 206.10 cm
# Photo 41 | ID image41.jpeg | Ceiling height 267.814208984375 | AC Height YYYY
# Photo 42 | ID image42.jpeg | Ceiling height 326.19915771484375 | AC Height YYYY
# Photo 43 | ID image43.jpeg | Ceiling height 314.77947998046875 | AC Height YYYY
# Photo 44 | ID image44.jpeg | Ceiling height 328.72503662109375 | AC Height YYYY
# Photo 45 | ID image45.jpeg | Ceiling height 313.1964111328125 | AC Height 258.22 cm
# Photo 46 | ID image46.jpeg | Ceiling height 262.62066650390625 | AC Height YYYY
# Photo 47 | ID image47.jpeg | Ceiling height 309.025390625 | AC Height YYYY
# Photo 48 | ID image48.jpeg | Ceiling height 330.5956115722656 | AC Height YYYY
# Photo 49 | ID image49.jpeg | Ceiling height 278.7380065917969 | AC Height YYYY
# Photo 50 | ID image50.jpeg | Ceiling height 251.76600646972656 | AC Height YYYY
# Photo 51 | ID image51.jpeg | Ceiling height 337.9875793457031 | AC Height YYYY
# Photo 52 | ID image52.jpeg | Ceiling height 201.9465789794922 | AC Height 148.67 cm
# Photo 53 | ID image53.jpeg | Ceiling height 257.3297119140625 | AC Height 226.04 cm
# Photo 54 | ID image54.jpeg | Ceiling height XXXXX | AC Height YYYY

# %%
# import os
# import re

# def natural_sort_key(filename):
#     """Extract numerical values from filenames for correct sorting."""
#     return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', filename)]

# # Define folders
# image_folder = "Input_test_folder(3m approx)"
# output_folder = "Output_test_folder_combined"
# os.makedirs(output_folder, exist_ok=True)

# # Load models
# coke_model = YOLO("best (8).pt")
# floor_model = YOLO("best (5).pt")
# propeller_model = YOLO("best (9).pt")

# image_heights = {}  # Declare outside to store all images' heights

# # Store image results
# image_results = []

# # Get and sort image filenames using natural sorting
# image_files = sorted(
#     [f for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))],
#     key=natural_sort_key
# )

# for image_name in image_files:  # Process images in correct order
#     image_path = os.path.join(image_folder, image_name)
    
#     # Detect Coca-Cola bottle height (for calibration)
#     height_pixels, estimated_real_height = detect_height_bottle(image_path, coke_model)
#     if height_pixels is None:
#         print(f"Skipping {image_name}: No Coca-Cola bottle detected.")
#         calibration_obj = None
#     else:
#         calibration_obj = (estimated_real_height, height_pixels)
    
#     # Detect ceiling and floor
#     floor_results, image = detect_objects(floor_model, image_path)
#     ceiling_y, floor_y = get_ceiling_floor_coordinates(floor_results)

#     if ceiling_y is None or floor_y is None:
#         ceiling_height = "XXXXX"
#     elif calibration_obj:
#         ceiling_height = calculate_height(ceiling_y, floor_y, calibration_obj)
#     else:
#         ceiling_height = "XXXXX"

#     print(f"Ceiling Height for {image_name}: {ceiling_height}")

#     # Store ceiling height only if it's numeric
#     if ceiling_height != "XXXXX":
#         image_heights[image_name] = ceiling_height  # Convert to float for consistency


#     # image_heights = {}

#     # image_heights[image_name] = ceiling_height  # Dynamically update dictionary
#     image = cv2.imread(image_path)

#     # Detect propellers (AC)
#     propeller_results, _ = detect_objects(propeller_model, image_path)
#     propeller_y_bottoms, propeller_boxes = get_propeller_coordinates(propeller_results)
    
#     if propeller_boxes and calibration_obj:
#         propeller_heights = [f"{calculate_height(y, floor_y, calibration_obj):.2f} cm" for y in propeller_y_bottoms]
#     else:
#         propeller_heights = []

#     # Format AC height output
#     ac_height = ", ".join(propeller_heights) if propeller_heights else "YYYY"
#     print(f"AC Height for {image_name}: {ac_height}")

#     # Draw detections
#     if calibration_obj:
#         output_image = draw_detections(image, propeller_boxes, (floor_y, floor_y), calibration_obj)
#         output_path = os.path.join(output_folder, image_name)
#         cv2.imwrite(output_path, output_image)
#         print(f"Output saved at: {output_path}")

#     # Store results in required format
#     image_results.append(f"{image_name} | ID photo 123456 | Ceiling height {ceiling_height} | AC Height {ac_height}")

# # Print final results
# print("\nFinal Results:")
# for result in image_results:
#     print(result)

# %%
import numpy as np

# Predicted height (assumed constant for all images as per your requirement)
actual_height = 340# cm

# Extract actual heights from the provided results
# image_heights = {
#     "image2.jpeg": 197.32,
#     "image5.jpeg": 210.09,
#     "image4.jpeg": 196.10,
#     "image1.jpeg": 120.91,
# }

# List to store actual heights dynamically
predicted_heights = []
real_heights = []

# Fetch actual heights using a loop
# Convert actual heights to a NumPy array
predicted_heights = np.array(list(image_heights.values()))

# Create an array of the actual height for comparison
real_heights = np.full_like(predicted_heights, actual_height)

# Convert to NumPy arrays for calculations
# actual_heights = np.array(actual_heights)
# predicted_heights = np.full_like(actual_heights, predicted_height)

# Compute evaluation metrics
mae = np.mean(np.abs(real_heights - predicted_heights))  # Mean Absolute Error
mse = np.mean((real_heights - predicted_heights) ** 2)  # Mean Squared Error
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Print results
formatted_heights = ", ".join(f"{h:.2f}" for h in predicted_heights)
print(f"Predicted Heights: [{formatted_heights}]")
print(f"MAE: {mae:.2f} cm")
print(f"MSE: {mse:.2f} cm²")
print(f"RMSE: {rmse:.2f} cm")
# Out:
# Predicted Heights: [307.63, 304.52, 328.19, 368.68, 351.96, 321.48, 298.92, 379.23, 314.87, 299.76, 300.99, 322.66, 305.17, 285.68, 264.61, 289.51, 273.51, 323.06, 272.63, 274.91, 294.55, 301.83, 315.21, 321.85, 249.33, 245.54, 290.07, 343.80, 252.31, 338.03, 294.54, 344.35, 361.76, 267.81, 326.20, 314.78, 328.73, 313.20, 262.62, 309.03, 330.60, 278.74, 251.77, 337.99, 201.95, 257.33]
# MAE: 42.12 cm
# MSE: 2666.52 cm²
# RMSE: 51.64 cm

# %%
# Calculate Mean Absolute Percentage Error (MAPE)
mape = np.mean(np.abs((real_heights - predicted_heights) / real_heights)) * 100

# Calculate Accuracy
accuracy = 100 - mape

# Print results
print(f"MAPE: {mape:.2f}%")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# MAPE: 12.39%
# Accuracy: 87.61%
