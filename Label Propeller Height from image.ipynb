# %%
import cv2
import torch
from ultralytics import YOLO

# %%
def detect_coke_bottle(image):
    """Detects Coca-Cola bottles and returns their bounding boxes and pixel heights."""
    results = coke_model(image)
    coke_boxes = []

    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Get bounding box coordinates
            height_pixels = y2 - y1  # Calculate height in pixels
            coke_boxes.append((x1, y1, x2, y2, height_pixels))

    return coke_boxes

# %%
def detect_height_bottle(image_path, model):
    """Detect Coca-Cola bottles and return their bounding box height in pixels."""
    image = cv2.imread(image_path)
    results = model(image)
    
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Bounding box coordinates
            height_pixels = y2 - y1  # Bottle height in pixels
            real_height_cm = 24  # Known height of Coca-Cola bottle
            
            pixel_to_cm_ratio = real_height_cm / height_pixels
            estimated_real_height = height_pixels * pixel_to_cm_ratio
            
            return height_pixels, estimated_real_height

    return None, None  # If no bottle is detected

# %%
import torch
import cv2
import numpy as np
from ultralytics import YOLO

# %%
def load_model(model_path):
    model = YOLO(model_path)  # Load YOLO model
    return model

# %%
def detect_objects(model, image_path):
    image = cv2.imread(image_path)
    results = model(image)  # Perform object detection
    return results, image

# %%
def get_floor_coordinates(results):
    """Extract the top Y-coordinate and bounding box of the floor"""
    floor_y_top = None
    floor_box = None
    
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls.cpu().numpy().item())  # Get class ID
            x_min, y_min, x_max, y_max = map(int, box.xyxy[0])  # Bounding box
            
            if class_id == 1:  # Assuming class 1 is "floor"
                floor_y_top = y_min  # Top Y-coordinate of floor
                floor_box = (x_min, y_min, x_max, y_max)
    
    return floor_y_top, floor_box

# %%
def get_propeller_coordinates(results):
    """Extract the bottom Y-coordinates and bounding boxes of propellers"""
    propeller_boxes = []  # Store bounding boxes of detected propellers
    propeller_y_bottoms = []  # Store Y-bottom of propellers
    
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls.cpu().numpy().item())  # Get class ID
            x_min, y_min, x_max, y_max = map(int, box.xyxy[0])  # Bounding box
            
            if class_id == 0:  # Assuming class 0 is "propeller"
                propeller_y_bottoms.append(y_max)  # Store bottom Y-coordinate
                propeller_boxes.append((x_min, y_min, x_max, y_max))
    
    return propeller_y_bottoms, propeller_boxes

# %%
def draw_detections(image, propeller_boxes, floor_box, calibration_obj):
    for i, (x1, y1, x2, y2) in enumerate(propeller_boxes):  # Unpacking tuple directly
        x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])  # Ensure integer values
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
        
        # Calculate height from floor to propeller
        pixel_height = y1 - floor_box[1]
        real_height = calculate_height(y1, floor_box[1], calibration_obj)
        height_text = f"Height: {real_height:.2f} cm"
        
        # Draw text label
        cv2.putText(image, height_text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Label the calibration object
    if calibration_obj:
        real_height, obj_pixel_height = calibration_obj
        cal_text = f"Calibration: {real_height:.2f} cm ({obj_pixel_height} px)"
        cv2.putText(image, cal_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

    return image

# %%
def calculate_height(propeller_y, floor_y, calibration_obj=None):
    """
    Calculates the real-world height from the floor to each propeller.
    Uses a calibration object if available.
    """
    if propeller_y is None or floor_y is None:
        print("Propeller or Floor not detected!")
        return None
    
    pixel_height = propeller_y - floor_y  # Distance in pixels
    
    if calibration_obj:
        real_height, obj_pixel_height = calibration_obj
        pixel_to_cm_ratio = real_height / obj_pixel_height
        real_propeller_height = pixel_height * pixel_to_cm_ratio
        return real_propeller_height
    
    return pixel_height  # Returns pixels if no calibration object

# %%
import os
image_folder = "Input_test_folder(3m approx)"
output_folder = "Output_test_folder_propeller"
model_floor_path = "best (5).pt"
model_propeller_path = "best (9).pt"
coke_model_path = "best (8).pt"
coke_model = YOLO(coke_model_path)

os.makedirs(output_folder, exist_ok=True)
floor_model = load_model(model_floor_path)
propeller_model = load_model(model_propeller_path)
for image_name in os.listdir(image_folder):
    image_path = os.path.join(image_folder, image_name)

    
    
    height_pixels, estimated_real_height = detect_height_bottle(image_path, coke_model)

    if height_pixels is None:
        print(f"Skipping {image_name}: No Coca-Cola bottle detected.")
        continue

    print(f"Detected Coca-Cola Bottle Height: {height_pixels:.2f} pixels")
    print(f"Estimated Real-World Height: {estimated_real_height:.2f} cm")
    
    calibration_obj = (estimated_real_height,height_pixels)
    
    floor_results, image = detect_objects(floor_model, image_path)
    floor_y_top, floor_box = get_floor_coordinates(floor_results)
    propeller_results, _ = detect_objects(propeller_model, image_path)
    propeller_y_bottoms, propeller_boxes = get_propeller_coordinates(propeller_results)
    if not propeller_boxes or floor_y_top is None:
        print(f"No propellers or floor detected in {image_path}")
        continue
    print(f"\nImage: {image_path}")
    for i, propeller_y_bottom in enumerate(propeller_y_bottoms):
        real_height = calculate_height(propeller_y_bottom, floor_y_top, calibration_obj)
        print(f"  Propeller {i+1}: {real_height:.2f} cm from floor")
    output_image = draw_detections(image, propeller_boxes, floor_box, calibration_obj)
    output_path = os.path.join(output_folder, image_name)
    cv2.imwrite(output_path, output_image)
    print(f"Output saved at: {output_path}")
# Out:
# 0: 800x608 1 750ml coke, 374.1ms
# Speed: 4.4ms preprocess, 374.1ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 79.81 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 2 floors, 4 wallss, 345.3ms
# Speed: 2.4ms preprocess, 345.3ms inference, 9.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 360.0ms
# Speed: 7.4ms preprocess, 360.0ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image44.jpeg
#
# 0: 800x608 1 750ml coke, 348.2ms
# Speed: 4.3ms preprocess, 348.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 79.93 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 1 floor, 2 wallss, 318.7ms
# Speed: 2.9ms preprocess, 318.7ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 371.1ms
# Speed: 4.5ms preprocess, 371.1ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image47.jpeg
#
# 0: 800x608 1 750ml coke, 355.4ms
# Speed: 4.1ms preprocess, 355.4ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 77.69 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 floor, 1 walls, 351.6ms
# Speed: 2.6ms preprocess, 351.6ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 347.0ms
# Speed: 7.8ms preprocess, 347.0ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image34.jpeg
#
# 0: 800x608 1 750ml coke, 364.9ms
# Speed: 4.3ms preprocess, 364.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 76.96 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 2 floors, 6 wallss, 319.3ms
# Speed: 2.8ms preprocess, 319.3ms inference, 16.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 348.6ms
# Speed: 4.4ms preprocess, 348.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image31.jpeg
#   Propeller 1: -243.25 cm from floor
#   Propeller 2: -216.74 cm from floor
# Output saved at: Output_test_folder_propeller/image31.jpeg
#
# 0: 800x608 1 750ml coke, 370.5ms
# Speed: 3.7ms preprocess, 370.5ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 76.73 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 2 floors, 3 wallss, 377.3ms
# Speed: 9.5ms preprocess, 377.3ms inference, 9.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 400.0ms
# Speed: 5.5ms preprocess, 400.0ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image50.jpeg
#
# 0: 800x608 1 750ml coke, 353.0ms
# Speed: 5.1ms preprocess, 353.0ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 75.72 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 3 ceilings, 2 floors, 5 wallss, 314.7ms
# Speed: 5.6ms preprocess, 314.7ms inference, 12.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 363.7ms
# Speed: 4.0ms preprocess, 363.7ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image29.jpeg
#   Propeller 1: -200.00 cm from floor
#   Propeller 2: -186.37 cm from floor
# Output saved at: Output_test_folder_propeller/image29.jpeg
#
# 0: 800x608 1 750ml coke, 408.8ms
# Speed: 5.2ms preprocess, 408.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 71.85 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 1 floor, 2 wallss, 454.8ms
# Speed: 2.5ms preprocess, 454.8ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 5 Propellers detection - v1 2025-02-20 11-43ams, 406.2ms
# Speed: 5.7ms preprocess, 406.2ms inference, 8.2ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image10.jpeg
#   Propeller 1: -170.69 cm from floor
#   Propeller 2: -166.01 cm from floor
#   Propeller 3: -148.98 cm from floor
#   Propeller 4: -153.32 cm from floor
#   Propeller 5: -139.62 cm from floor
# Output saved at: Output_test_folder_propeller/image10.jpeg
#
# 0: 800x608 1 750ml coke, 353.9ms
# Speed: 3.8ms preprocess, 353.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 91.77 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 4 floors, 3 wallss, 335.0ms
# Speed: 2.4ms preprocess, 335.0ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 354.1ms
# Speed: 5.7ms preprocess, 354.1ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image13.jpeg
#   Propeller 1: -194.58 cm from floor
# Output saved at: Output_test_folder_propeller/image13.jpeg
#
# 0: 800x608 1 750ml coke, 366.9ms
# Speed: 3.7ms preprocess, 366.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 89.58 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 4 floors, 8 wallss, 344.7ms
# Speed: 3.3ms preprocess, 344.7ms inference, 15.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 380.9ms
# Speed: 3.5ms preprocess, 380.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image54.jpeg
#
# 0: 800x608 2 750ml cokes, 393.7ms
# Speed: 3.6ms preprocess, 393.7ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 80.89 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 4 floors, 1 walls, 335.6ms
# Speed: 1.8ms preprocess, 335.6ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 3 Propellers detection - v1 2025-02-20 11-43ams, 334.5ms
# Speed: 3.3ms preprocess, 334.5ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image9.jpeg
#   Propeller 1: -176.24 cm from floor
#   Propeller 2: -140.93 cm from floor
#   Propeller 3: -191.37 cm from floor
# Output saved at: Output_test_folder_propeller/image9.jpeg
#
# 0: 800x608 1 750ml coke, 340.7ms
# Speed: 3.6ms preprocess, 340.7ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 73.21 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 5 floors, 3 wallss, 310.6ms
# Speed: 2.2ms preprocess, 310.6ms inference, 11.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 342.4ms
# Speed: 3.9ms preprocess, 342.4ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image14.jpeg
#   Propeller 1: -151.46 cm from floor
# Output saved at: Output_test_folder_propeller/image14.jpeg
#
# 0: 800x608 2 750ml cokes, 346.0ms
# Speed: 3.4ms preprocess, 346.0ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 80.62 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 floors, 4 wallss, 310.5ms
# Speed: 2.0ms preprocess, 310.5ms inference, 8.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 343.0ms
# Speed: 4.5ms preprocess, 343.0ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image25.jpeg
#   Propeller 1: -149.15 cm from floor
# Output saved at: Output_test_folder_propeller/image25.jpeg
#
# 0: 800x608 2 750ml cokes, 339.6ms
# Speed: 3.8ms preprocess, 339.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 72.91 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 2 floors, 6 wallss, 301.2ms
# Speed: 2.1ms preprocess, 301.2ms inference, 11.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 359.9ms
# Speed: 3.5ms preprocess, 359.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image15.jpeg
#
# 0: 800x608 1 750ml coke, 338.4ms
# Speed: 4.3ms preprocess, 338.4ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 75.34 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 3 floors, 3 wallss, 289.2ms
# Speed: 2.2ms preprocess, 289.2ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 336.3ms
# Speed: 4.1ms preprocess, 336.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image24.jpeg
#   Propeller 1: -99.71 cm from floor
#   Propeller 2: -126.15 cm from floor
# Output saved at: Output_test_folder_propeller/image24.jpeg
#
# 0: 800x608 1 750ml coke, 339.2ms
# Speed: 4.1ms preprocess, 339.2ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 89.16 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 2 floors, 5 wallss, 307.1ms
# Speed: 1.9ms preprocess, 307.1ms inference, 10.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 337.4ms
# Speed: 3.4ms preprocess, 337.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image32.jpeg
#   Propeller 1: -182.78 cm from floor
# Output saved at: Output_test_folder_propeller/image32.jpeg
#
# 0: 800x608 1 750ml coke, 336.1ms
# Speed: 3.7ms preprocess, 336.1ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 77.72 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 2 floors, 2 wallss, 298.8ms
# Speed: 2.3ms preprocess, 298.8ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 341.4ms
# Speed: 3.4ms preprocess, 341.4ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image19.jpeg
#
# 0: 800x608 2 750ml cokes, 345.7ms
# Speed: 3.4ms preprocess, 345.7ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 77.36 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 3 floors, 5 wallss, 314.2ms
# Speed: 2.0ms preprocess, 314.2ms inference, 12.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 331.0ms
# Speed: 3.8ms preprocess, 331.0ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image16.jpeg
#
# 0: 800x608 1 750ml coke, 326.3ms
# Speed: 4.2ms preprocess, 326.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 79.63 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 4 ceilings, 2 floors, 10 wallss, 289.1ms
# Speed: 3.1ms preprocess, 289.1ms inference, 23.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 350.5ms
# Speed: 4.7ms preprocess, 350.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image35.jpeg
#   Propeller 1: -216.69 cm from floor
#   Propeller 2: -180.83 cm from floor
# Output saved at: Output_test_folder_propeller/image35.jpeg
#
# 0: 800x608 2 750ml cokes, 349.4ms
# Speed: 3.8ms preprocess, 349.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 69.99 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 3 ceilings, 1 floor, 5 wallss, 325.5ms
# Speed: 2.1ms preprocess, 325.5ms inference, 11.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 532.6ms
# Speed: 3.8ms preprocess, 532.6ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image39.jpeg
#
# 0: 800x608 1 750ml coke, 371.8ms
# Speed: 4.4ms preprocess, 371.8ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 78.55 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 2 floors, 1 walls, 341.5ms
# Speed: 2.1ms preprocess, 341.5ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 352.4ms
# Speed: 5.8ms preprocess, 352.4ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image43.jpeg
#
# 0: 800x608 1 750ml coke, 383.5ms
# Speed: 4.3ms preprocess, 383.5ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 85.01 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 5 floors, 2 wallss, 354.5ms
# Speed: 2.0ms preprocess, 354.5ms inference, 12.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 361.0ms
# Speed: 3.8ms preprocess, 361.0ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image2.jpeg
#
# 0: 800x608 1 750ml coke, 373.6ms
# Speed: 5.6ms preprocess, 373.6ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 76.35 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 2 floors, 5 wallss, 345.9ms
# Speed: 2.8ms preprocess, 345.9ms inference, 11.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 399.1ms
# Speed: 5.5ms preprocess, 399.1ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image7.jpeg
#   Propeller 1: -230.42 cm from floor
#   Propeller 2: -194.27 cm from floor
# Output saved at: Output_test_folder_propeller/image7.jpeg
#
# 0: 800x608 1 750ml coke, 347.6ms
# Speed: 5.1ms preprocess, 347.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 81.15 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 3 ceilings, 1 floor, 4 wallss, 337.6ms
# Speed: 2.7ms preprocess, 337.6ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 371.6ms
# Speed: 5.5ms preprocess, 371.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image37.jpeg
#   Propeller 1: -179.53 cm from floor
#   Propeller 2: -199.05 cm from floor
# Output saved at: Output_test_folder_propeller/image37.jpeg
#
# 0: 800x608 1 750ml coke, 377.7ms
# Speed: 4.3ms preprocess, 377.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 73.56 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 1 floor, 9 wallss, 331.9ms
# Speed: 4.7ms preprocess, 331.9ms inference, 16.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 369.8ms
# Speed: 4.8ms preprocess, 369.8ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image23.jpeg
#
# 0: 800x608 1 750ml coke, 357.6ms
# Speed: 4.7ms preprocess, 357.6ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 80.69 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 2 floors, 5 wallss, 318.3ms
# Speed: 2.8ms preprocess, 318.3ms inference, 11.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 3 Propellers detection - v1 2025-02-20 11-43ams, 381.2ms
# Speed: 4.1ms preprocess, 381.2ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image36.jpeg
#   Propeller 1: -249.56 cm from floor
#   Propeller 2: -193.34 cm from floor
#   Propeller 3: -148.72 cm from floor
# Output saved at: Output_test_folder_propeller/image36.jpeg
#
# 0: 800x608 2 750ml cokes, 404.9ms
# Speed: 4.8ms preprocess, 404.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 78.81 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 1 floor, 1 walls, 499.5ms
# Speed: 2.9ms preprocess, 499.5ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 384.2ms
# Speed: 8.4ms preprocess, 384.2ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image3.jpeg
#   Propeller 1: -69.44 cm from floor
# Output saved at: Output_test_folder_propeller/image3.jpeg
#
# 0: 800x608 1 750ml coke, 431.1ms
# Speed: 9.9ms preprocess, 431.1ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 79.59 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 4 floors, 5 wallss, 301.4ms
# Speed: 5.7ms preprocess, 301.4ms inference, 14.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 363.1ms
# Speed: 5.7ms preprocess, 363.1ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image33.jpeg
#   Propeller 1: -116.99 cm from floor
# Output saved at: Output_test_folder_propeller/image33.jpeg
#
# 0: 800x608 1 750ml coke, 369.6ms
# Speed: 5.1ms preprocess, 369.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 85.58 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 3 ceilings, 2 floors, 8 wallss, 322.7ms
# Speed: 2.6ms preprocess, 322.7ms inference, 30.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 450.0ms
# Speed: 4.9ms preprocess, 450.0ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image53.jpeg
#   Propeller 1: -118.07 cm from floor
# Output saved at: Output_test_folder_propeller/image53.jpeg
#
# 0: 800x608 1 750ml coke, 439.5ms
# Speed: 8.0ms preprocess, 439.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 79.84 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 3 floors, 4 wallss, 387.6ms
# Speed: 2.7ms preprocess, 387.6ms inference, 13.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 370.5ms
# Speed: 4.7ms preprocess, 370.5ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image20.jpeg
#
# 0: 800x608 1 750ml coke, 380.4ms
# Speed: 5.7ms preprocess, 380.4ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 79.67 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 3 floors, 3 wallss, 366.5ms
# Speed: 5.6ms preprocess, 366.5ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 362.3ms
# Speed: 5.4ms preprocess, 362.3ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image48.jpeg
#
# 0: 800x608 1 750ml coke, 416.2ms
# Speed: 4.0ms preprocess, 416.2ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 81.24 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 2 floors, 7 wallss, 342.6ms
# Speed: 4.3ms preprocess, 342.6ms inference, 14.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 422.3ms
# Speed: 5.2ms preprocess, 422.3ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image49.jpeg
#
# 0: 800x608 1 750ml coke, 362.2ms
# Speed: 8.8ms preprocess, 362.2ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 88.11 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 3 floors, 6 wallss, 331.4ms
# Speed: 8.5ms preprocess, 331.4ms inference, 17.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 351.4ms
# Speed: 5.2ms preprocess, 351.4ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image46.jpeg
#
# 0: 800x608 1 750ml coke, 336.6ms
# Speed: 5.2ms preprocess, 336.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 72.38 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 1 floor, 4 wallss, 317.0ms
# Speed: 3.5ms preprocess, 317.0ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 347.1ms
# Speed: 3.6ms preprocess, 347.1ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image30.jpeg
#   Propeller 1: -137.27 cm from floor
# Output saved at: Output_test_folder_propeller/image30.jpeg
#
# 0: 800x608 2 750ml cokes, 415.5ms
# Speed: 26.3ms preprocess, 415.5ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 76.08 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 2 floors, 6 wallss, 354.4ms
# Speed: 4.4ms preprocess, 354.4ms inference, 14.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 347.9ms
# Speed: 5.2ms preprocess, 347.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image51.jpeg
#
# 0: 800x608 1 750ml coke, 356.9ms
# Speed: 4.7ms preprocess, 356.9ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 73.63 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 3 floors, 2 wallss, 397.4ms
# Speed: 2.4ms preprocess, 397.4ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 4 Propellers detection - v1 2025-02-20 11-43ams, 348.5ms
# Speed: 6.1ms preprocess, 348.5ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image5.jpeg
#   Propeller 1: -191.35 cm from floor
#   Propeller 2: -250.35 cm from floor
#   Propeller 3: -276.75 cm from floor
#   Propeller 4: -236.01 cm from floor
# Output saved at: Output_test_folder_propeller/image5.jpeg
#
# 0: 800x608 1 750ml coke, 363.8ms
# Speed: 5.1ms preprocess, 363.8ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 80.00 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 1 floor, 4 wallss, 330.6ms
# Speed: 2.6ms preprocess, 330.6ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 344.4ms
# Speed: 4.0ms preprocess, 344.4ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image17.jpeg
#
# 0: 800x608 1 750ml coke, 343.3ms
# Speed: 4.3ms preprocess, 343.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 73.30 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 3 ceilings, 3 floors, 4 wallss, 318.8ms
# Speed: 2.8ms preprocess, 318.8ms inference, 13.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 342.7ms
# Speed: 5.0ms preprocess, 342.7ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image45.jpeg
#   Propeller 1: -108.05 cm from floor
# Output saved at: Output_test_folder_propeller/image45.jpeg
#
# 0: 800x608 1 750ml coke, 343.5ms
# Speed: 3.6ms preprocess, 343.5ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 85.21 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 1 floor, 5 wallss, 310.4ms
# Speed: 3.7ms preprocess, 310.4ms inference, 10.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 347.4ms
# Speed: 5.1ms preprocess, 347.4ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image26.jpeg
#
# 0: 800x608 1 750ml coke, 347.6ms
# Speed: 13.9ms preprocess, 347.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 74.43 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 3 ceilings, 4 floors, 8 wallss, 317.5ms
# Speed: 2.1ms preprocess, 317.5ms inference, 21.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 348.6ms
# Speed: 5.6ms preprocess, 348.6ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image22.jpeg
#
# 0: 800x608 1 750ml coke, 370.3ms
# Speed: 4.4ms preprocess, 370.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 83.94 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 6 floors, 7 wallss, 304.6ms
# Speed: 2.0ms preprocess, 304.6ms inference, 20.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 346.9ms
# Speed: 3.9ms preprocess, 346.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image52.jpeg
#   Propeller 1: -73.19 cm from floor
# Output saved at: Output_test_folder_propeller/image52.jpeg
#
# 0: 800x608 1 750ml coke, 355.5ms
# Speed: 4.7ms preprocess, 355.5ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 65.91 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 3 floors, 1 walls, 305.9ms
# Speed: 2.3ms preprocess, 305.9ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 353.5ms
# Speed: 14.9ms preprocess, 353.5ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image8.jpeg
#   Propeller 1: -301.85 cm from floor
# Output saved at: Output_test_folder_propeller/image8.jpeg
#
# 0: 800x608 1 750ml coke, 337.2ms
# Speed: 3.6ms preprocess, 337.2ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 81.12 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 3 ceilings, 1 floor, 4 wallss, 314.6ms
# Speed: 2.4ms preprocess, 314.6ms inference, 12.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 345.7ms
# Speed: 4.2ms preprocess, 345.7ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image38.jpeg
#
# 0: 800x608 1 750ml coke, 349.4ms
# Speed: 4.3ms preprocess, 349.4ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 80.77 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 4 ceilings, 2 floors, 4 wallss, 327.4ms
# Speed: 2.3ms preprocess, 327.4ms inference, 13.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 349.9ms
# Speed: 4.5ms preprocess, 349.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image27.jpeg
#
# 0: 800x608 2 750ml cokes, 330.6ms
# Speed: 5.6ms preprocess, 330.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 78.98 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 2 floors, 2 wallss, 317.4ms
# Speed: 2.3ms preprocess, 317.4ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 348.4ms
# Speed: 4.0ms preprocess, 348.4ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image4.jpeg
#   Propeller 1: -143.12 cm from floor
# Output saved at: Output_test_folder_propeller/image4.jpeg
#
# 0: 800x608 1 750ml coke, 342.3ms
# Speed: 5.4ms preprocess, 342.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 80.98 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 1 floor, 3 wallss, 319.0ms
# Speed: 2.2ms preprocess, 319.0ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 346.2ms
# Speed: 3.9ms preprocess, 346.2ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image42.jpeg
#
# 0: 800x608 1 750ml coke, 334.8ms
# Speed: 5.0ms preprocess, 334.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 77.33 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 1 floor, 8 wallss, 306.3ms
# Speed: 2.3ms preprocess, 306.3ms inference, 17.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 419.7ms
# Speed: 4.9ms preprocess, 419.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image40.jpeg
#   Propeller 1: -130.66 cm from floor
#   Propeller 2: -131.90 cm from floor
# Output saved at: Output_test_folder_propeller/image40.jpeg
#
# 0: 800x608 2 750ml cokes, 333.4ms
# Speed: 3.7ms preprocess, 333.4ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 81.03 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 floor, 3 wallss, 317.0ms
# Speed: 3.5ms preprocess, 317.0ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 339.2ms
# Speed: 5.2ms preprocess, 339.2ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image12.jpeg
#
# 0: 800x608 1 750ml coke, 365.5ms
# Speed: 4.1ms preprocess, 365.5ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 75.70 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 floor, 4 wallss, 320.3ms
# Speed: 3.5ms preprocess, 320.3ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 339.9ms
# Speed: 5.2ms preprocess, 339.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image21.jpeg
#
# 0: 800x608 1 750ml coke, 366.1ms
# Speed: 5.4ms preprocess, 366.1ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 97.93 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 3 ceilings, 1 floor, 3 wallss, 308.6ms
# Speed: 2.2ms preprocess, 308.6ms inference, 9.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 4 Propellers detection - v1 2025-02-20 11-43ams, 338.7ms
# Speed: 6.2ms preprocess, 338.7ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image11.jpeg
#   Propeller 1: -166.16 cm from floor
#   Propeller 2: -170.08 cm from floor
#   Propeller 3: -169.59 cm from floor
#   Propeller 4: -54.16 cm from floor
# Output saved at: Output_test_folder_propeller/image11.jpeg
#
# 0: 800x608 1 750ml coke, 336.6ms
# Speed: 4.6ms preprocess, 336.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 87.76 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 5 ceilings, 1 floor, 6 wallss, 327.8ms
# Speed: 2.3ms preprocess, 327.8ms inference, 18.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 338.7ms
# Speed: 6.7ms preprocess, 338.7ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image41.jpeg
#
# 0: 800x608 1 750ml coke, 356.5ms
# Speed: 5.5ms preprocess, 356.5ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 69.07 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 1 ceiling, 1 floor, 5 wallss, 348.5ms
# Speed: 3.5ms preprocess, 348.5ms inference, 11.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 365.4ms
# Speed: 6.1ms preprocess, 365.4ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image6.jpeg
#
# 0: 800x608 1 750ml coke, 583.0ms
# Speed: 19.6ms preprocess, 583.0ms inference, 6.3ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 82.73 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 2 floors, 7 wallss, 384.7ms
# Speed: 2.2ms preprocess, 384.7ms inference, 16.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 372.1ms
# Speed: 7.6ms preprocess, 372.1ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image18.jpeg
#
# 0: 800x608 1 750ml coke, 462.5ms
# Speed: 7.6ms preprocess, 462.5ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 84.07 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 4 ceilings, 3 floors, 10 wallss, 341.4ms
# Speed: 2.1ms preprocess, 341.4ms inference, 34.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 373.5ms
# Speed: 5.4ms preprocess, 373.5ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# Image: Input_test_folder(3m approx)/image28.jpeg
#   Propeller 1: -175.56 cm from floor
# Output saved at: Output_test_folder_propeller/image28.jpeg
#
# 0: 800x608 1 750ml coke, 359.6ms
# Speed: 5.4ms preprocess, 359.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 78.43 pixels
# Estimated Real-World Height: 24.00 cm
#
# 0: 640x480 2 ceilings, 2 floors, 4 wallss, 331.3ms
# Speed: 2.1ms preprocess, 331.3ms inference, 12.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 337.0ms
# Speed: 4.3ms preprocess, 337.0ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# No propellers or floor detected in Input_test_folder(3m approx)/image1.jpeg
