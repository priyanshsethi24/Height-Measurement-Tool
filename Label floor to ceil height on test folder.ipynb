# %%
import cv2
import torch
from ultralytics import YOLO

# %%
def detect_coke_bottle(image):
    """Detects Coca-Cola bottles and returns their bounding boxes and pixel heights."""
    results = coke_model(image)
    coke_boxes = []

    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Get bounding box coordinates
            height_pixels = y2 - y1  # Calculate height in pixels
            coke_boxes.append((x1, y1, x2, y2, height_pixels))

    return coke_boxes

# %%
def detect_height_bottle(image_path, model):
    """Detect Coca-Cola bottles and return their bounding box height in pixels."""
    image = cv2.imread(image_path)
    results = model(image)
    
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Bounding box coordinates
            height_pixels = y2 - y1  # Bottle height in pixels
            real_height_cm = 26  # Known height of Coca-Cola bottle
            
            pixel_to_cm_ratio = real_height_cm / height_pixels
            estimated_real_height = height_pixels * pixel_to_cm_ratio
            
            return height_pixels, estimated_real_height

    return None, None  # If no bottle is detected

# %%
import torch
import cv2
import numpy as np
from ultralytics import YOLO

# %%
def load_model(model_path):
    model = YOLO(model_path)  # Load YOLO model
    return model

# %%
def detect_objects(model, image_path):
    image = cv2.imread(image_path)
    results = model(image)  # Perform object detection
    return results, image

# %%
def get_ceiling_floor_coordinates(results):
    """Get Y-coordinates of the ceiling and floor."""
    ceiling_y, floor_y = None, None
    
    for result in results:
        for box in result.boxes:
            cls = int(box.cls.cpu().numpy().item())  # Extract class label
            y_min, y_max = int(box.xyxy[0][1]), int(box.xyxy[0][3])
            
            if cls == 0:  # Assuming class 0 is 'ceiling'
                ceiling_y = y_min
            elif cls == 1:  # Assuming class 1 is 'floor'
                floor_y = y_max
    
    return ceiling_y, floor_y

# %%
def calculate_height(ceiling_y, floor_y, calibration_obj):
    """Calculate ceiling height using a calibration object (Coca-Cola bottle)."""
    if ceiling_y is None or floor_y is None:
        print("Error: Ceiling or Floor not detected!")
        return None  # Avoid TypeError

    pixel_height = floor_y - ceiling_y

    if calibration_obj:
        real_height, obj_pixel_height = calibration_obj
        pixel_to_cm_ratio = real_height / obj_pixel_height
        return pixel_height * pixel_to_cm_ratio
    
    return pixel_height  # Return pixel height if no calibration object

# %%
coke_model_path = "best (8).pt"
ceiling_floor_model_path = "best (5).pt"
coke_model = YOLO(coke_model_path)  # Load Coca-Cola bottle detection model
ceiling_floor_model = YOLO(ceiling_floor_model_path)

# %%
def detect_coke_bottle(image):
    """Detects Coca-Cola bottles and returns their bounding boxes and pixel heights."""
    results = coke_model(image)
    coke_boxes = []

    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Get bounding box coordinates
            height_pixels = y2 - y1  # Calculate height in pixels
            coke_boxes.append((x1, y1, x2, y2, height_pixels))

    return coke_boxes

# %%
def detect_ceiling_floor(image):
    """Detects the ceiling and floor, returning their y-coordinates."""
    results = ceiling_floor_model(image)
    ceiling_y, floor_y = None, None

    for result in results:
        for box in result.boxes:
            cls = int(box.cls.cpu().numpy().item())  # Extract class ID
            y_min, y_max = int(box.xyxy[0][1]), int(box.xyxy[0][3])

            if cls == 0:  # Assuming class 0 is ceiling
                ceiling_y = y_min
            elif cls == 1:  # Assuming class 1 is floor
                floor_y = y_max

    return ceiling_y, floor_y

# %%
def draw_annotations(image, coke_boxes, ceiling_y, floor_y, pixel_to_cm_ratio=None):
    """Draws bounding boxes, vertical line, and labels on the image."""
    annotated_image = image.copy()
    
    # Draw Coca-Cola bounding boxes
    for (x1, y1, x2, y2, height_pixels) in coke_boxes:
        cv2.rectangle(annotated_image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green box
        cv2.putText(annotated_image, f"{height_pixels}px", (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Draw vertical line from floor to ceiling
    if ceiling_y is not None and floor_y is not None:
        mid_x = image.shape[1] // 2  # Center x-coordinate
        cv2.line(annotated_image, (mid_x, ceiling_y), (mid_x, floor_y), (0, 0, 255), 2)  # Red line
        
        # Calculate real-world ceiling height if calibration object exists
        pixel_height = floor_y - ceiling_y
        if pixel_to_cm_ratio:
            real_ceiling_height = pixel_height * pixel_to_cm_ratio
            height_text = f"Height: {real_ceiling_height:.2f} cm"
        else:
            height_text = f"Height: {pixel_height} pixels"

        # Add text label
        cv2.putText(annotated_image, height_text, (mid_x + 10, (ceiling_y + floor_y) // 2),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    return annotated_image

# %%
import os

# %%
'''# Process all images in test_images folder
image_folder = "image_folder"
output_folder = "output_images"
os.makedirs(output_folder, exist_ok=True)  # Ensure output folder exists
for image_name in os.listdir(image_folder):
    if image_name.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(image_folder, image_name)
        model_path = "best (8).pt"  # Path to your trained YOLO model
        height_pixels, estimated_real_height =detect_height_bottle(image_path, model_path)

        print(f"Detected Coca-Cola Bottle Height: {height_pixels:.2f} pixels")
        print(f"Estimated Real-World Height: {estimated_real_height:.2f} cm")
        # image = cv2.imread(image_path)

        # Detect objects
        # coke_boxes = detect_coke_bottle(image
        # calibration_obj = (estimated_real_height, height_pixels)
        # Example usage
        model_path1 = "best (5).pt"  # Path to trained YOLO model
         # Input image path
        calibration_obj = (estimated_real_height, height_pixels)  # Example: (real-world height in cm, pixel height)

        model = load_model(model_path1)
        results, image = detect_objects(model, image_path)
        ceiling_y, floor_y = get_ceiling_floor_coordinates(results)
        pixel_height = floor_y - ceiling_y  # Calculate pixel height
        print(f"Pixel Height: {pixel_height} pixels")  # Output the result

        height = calculate_height(ceiling_y, floor_y, calibration_obj)
        print(f"Ceiling Height: {height} cm" if calibration_obj else f"Ceiling Height: {height} pixels")

        
        image = cv2.imread(image_path)
        

        # Detect objects
        coke_boxes = detect_coke_bottle(image)
        ceiling_y, floor_y = detect_ceiling_floor(image)
        
        # Calibration: Use Coca-Cola bottle to calculate pixel-to-cm ratio
        if coke_boxes:
            real_coke_height_cm = 24
            _, _, _, _, height_pixels = coke_boxes[0]  # First detected bottle
            pixel_to_cm_ratio = real_coke_height_cm / height_pixels
        else:
            pixel_to_cm_ratio = None

        # Draw results
        annotated_image = draw_annotations(image, coke_boxes, ceiling_y, floor_y, pixel_to_cm_ratio)

        # Save annotated image
        output_path = os.path.join(output_folder, f"annotated_{image_name}")
        cv2.imwrite(output_path, annotated_image)

print("Processing complete! Check the 'output_images' folder.")'''
# Out:
# '# Process all images in test_images folder\nimage_folder = "image_folder"\noutput_folder = "output_images"\nos.makedirs(output_folder, exist_ok=True)  # Ensure output folder exists\nfor image_name in os.listdir(image_folder):\n    if image_name.lower().endswith((\'.jpg\', \'.jpeg\', \'.png\')):\n        image_path = os.path.join(image_folder, image_name)\n        model_path = "best (8).pt"  # Path to your trained YOLO model\n        height_pixels, estimated_real_height =detect_height_bottle(image_path, model_path)\n\n        print(f"Detected Coca-Cola Bottle Height: {height_pixels:.2f} pixels")\n        print(f"Estimated Real-World Height: {estimated_real_height:.2f} cm")\n        # image = cv2.imread(image_path)\n\n        # Detect objects\n        # coke_boxes = detect_coke_bottle(image\n        # calibration_obj = (estimated_real_height, height_pixels)\n        # Example usage\n        model_path1 = "best (5).pt"  # Path to trained YOLO model\n         # Input image path\n        calibration_obj = (estimated_real_height, height_pixels)  # Example: (real-world height in cm, pixel height)\n\n        model = load_model(model_path1)\n        results, image = detect_objects(model, image_path)\n        ceiling_y, floor_y = get_ceiling_floor_coordinates(results)\n        pixel_height = floor_y - ceiling_y  # Calculate pixel height\n        print(f"Pixel Height: {pixel_height} pixels")  # Output the result\n\n        height = calculate_height(ceiling_y, floor_y, calibration_obj)\n        print(f"Ceiling Height: {height} cm" if calibration_obj else f"Ceiling Height: {height} pixels")\n\n        \n        image = cv2.imread(image_path)\n        \n\n        # Detect objects\n        coke_boxes = detect_coke_bottle(image)\n        ceiling_y, floor_y = detect_ceiling_floor(image)\n        \n        # Calibration: Use Coca-Cola bottle to calculate pixel-to-cm ratio\n        if coke_boxes:\n            real_coke_height_cm = 24\n            _, _, _, _, height_pixels = coke_boxes[0]  # First detected bottle\n            pixel_to_cm_ratio = real_coke_height_cm / height_pixels\n        else:\n            pixel_to_cm_ratio = None\n\n        # Draw results\n        annotated_image = draw_annotations(image, coke_boxes, ceiling_y, floor_y, pixel_to_cm_ratio)\n\n        # Save annotated image\n        output_path = os.path.join(output_folder, f"annotated_{image_name}")\n        cv2.imwrite(output_path, annotated_image)\n\nprint("Processing complete! Check the \'output_images\' folder.")'

# %%
# Define folders
image_folder = "Input_test_folder(3m approx)"
output_folder = "output_test_folder(ceil_height)"
os.makedirs(output_folder, exist_ok=True)  # Ensure output folder exists

# %%
coke_model_path = "best (8).pt"
ceiling_floor_model_path = "best (5).pt"
coke_model = YOLO(coke_model_path)  # Load Coca-Cola bottle detection model
ceiling_floor_model = YOLO(ceiling_floor_model_path)
image_heights = {}  # Declare outside to store all images' heights

for image_name in os.listdir(image_folder):
    if image_name.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(image_folder, image_name)

        # Detect Coca-Cola bottle height
        height_pixels, estimated_real_height = detect_height_bottle(image_path, coke_model)

        if height_pixels is None:
            print(f"Skipping {image_name}: No Coca-Cola bottle detected.")
            continue

        print(f"Detected Coca-Cola Bottle Height: {height_pixels:.2f} pixels")
        print(f"Estimated Real-World Height: {estimated_real_height:.2f} cm")

        # Detect ceiling and floor
        results = ceiling_floor_model(image_path)
        ceiling_y, floor_y = get_ceiling_floor_coordinates(results)

        if ceiling_y is None or floor_y is None:
            print(f"Skipping {image_name}: Ceiling or floor not detected.")
            continue

        # Calculate ceiling height using Coca-Cola bottle as a calibration object
        calibration_obj = (estimated_real_height, height_pixels)
        ceiling_height = calculate_height(ceiling_y, floor_y, calibration_obj)

        print(f"Ceiling Height: {ceiling_height:.2f} cm")

        # image_heights = {}

        image_heights[image_name] = ceiling_height  # Dynamically update dictionary
        image = cv2.imread(image_path)
        

        # Detect objects
        coke_boxes = detect_coke_bottle(image)
        ceiling_y, floor_y = detect_ceiling_floor(image)
        
        # Calibration: Use Coca-Cola bottle to calculate pixel-to-cm ratio
        if coke_boxes:
            real_coke_height_cm = 24
            _, _, _, _, height_pixels = coke_boxes[0]  # First detected bottle
            pixel_to_cm_ratio = real_coke_height_cm / height_pixels
        else:
            pixel_to_cm_ratio = None

        # Draw results
        annotated_image = draw_annotations(image, coke_boxes, ceiling_y, floor_y, pixel_to_cm_ratio)

        # calculated_height = compute_height(image_name)  # Replace with your actual function
        # image_heights[image_name] = calculated_height  # Dynamically update dictionary
        # Save annotated image
        output_path = os.path.join(output_folder, f"annotated_{image_name}")
        cv2.imwrite(output_path, annotated_image)

print("Processing complete! Check the 'output_images' folder.")
# Out:
# 0: 800x608 1 750ml coke, 369.6ms
# Speed: 3.5ms preprocess, 369.6ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 79
pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image33.jpeg: 640x480 2 ceilings, 4 floors, 5 wallss, 307.5ms
# Speed: 2.2ms preprocess, 307.5ms inference, 17.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 286.15 cm
#
# 0: 800x608 1 750ml coke, 334.9ms
# Speed: 3.8ms preprocess, 334.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 4 floors, 5 wallss, 309.4ms
# Speed: 3.1ms preprocess, 309.4ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 338.9ms
# Speed: 7.7ms preprocess, 338.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 85.58 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image53.jpeg: 640x480 3 ceilings, 2 floors, 8 wallss, 298.3ms
# Speed: 4.1ms preprocess, 298.3ms inference, 20.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 276.17 cm
#
# 0: 800x608 1 750ml coke, 336.8ms
# Speed: 4.3ms preprocess, 336.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 2 floors, 8 wallss, 308.2ms
# Speed: 2.1ms preprocess, 308.2ms inference, 17.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 329.4ms
# Speed: 5.3ms preprocess, 329.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 79.84 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image20.jpeg: 640x480 2 ceilings, 3 floors, 4 wallss, 307.3ms
# Speed: 2.5ms preprocess, 307.3ms inference, 12.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 401.54 cm
#
# 0: 800x608 1 750ml coke, 422.3ms
# Speed: 5.0ms preprocess, 422.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 4 wallss, 306.5ms
# Speed: 2.3ms preprocess, 306.5ms inference, 12.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 346.7ms
# Speed: 5.3ms preprocess, 346.7ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 79.67 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image48.jpeg: 640x480 1 ceiling, 3 floors, 3 wallss, 313.3ms
# Speed: 3.7ms preprocess, 313.3ms inference, 10.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 322.76 cm
#
# 0: 800x608 1 750ml coke, 341.1ms
# Speed: 4.5ms preprocess, 341.1ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 3 wallss, 340.3ms
# Speed: 3.1ms preprocess, 340.3ms inference, 9.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 371.0ms
# Speed: 4.2ms preprocess, 371.0ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 81.24 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image49.jpeg: 640x480 1 ceiling, 2 floors, 7 wallss, 333.3ms
# Speed: 4.2ms preprocess, 333.3ms inference, 17.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 408.67 cm
#
# 0: 800x608 1 750ml coke, 356.2ms
# Speed: 4.8ms preprocess, 356.2ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 7 wallss, 309.4ms
# Speed: 2.5ms preprocess, 309.4ms inference, 13.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 356.0ms
# Speed: 6.9ms preprocess, 356.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 88.11 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image46.jpeg: 640x480 2 ceilings, 3 floors, 6 wallss, 309.2ms
# Speed: 2.2ms preprocess, 309.2ms inference, 14.7ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 376.82 cm
#
# 0: 800x608 1 750ml coke, 325.9ms
# Speed: 4.0ms preprocess, 325.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 6 wallss, 300.5ms
# Speed: 2.1ms preprocess, 300.5ms inference, 15.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 356.5ms
# Speed: 5.2ms preprocess, 356.5ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 72.38 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image30.jpeg: 640x480 1 ceiling, 1 floor, 4 wallss, 299.6ms
# Speed: 2.0ms preprocess, 299.6ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 456.19 cm
#
# 0: 800x608 1 750ml coke, 442.1ms
# Speed: 7.3ms preprocess, 442.1ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 4 wallss, 301.6ms
# Speed: 2.1ms preprocess, 301.6ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 750ml cokes, 352.8ms
# Speed: 4.0ms preprocess, 352.8ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 76.08 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image51.jpeg: 640x480 2 ceilings, 2 floors, 6 wallss, 319.8ms
# Speed: 4.1ms preprocess, 319.8ms inference, 14.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 436.41 cm
#
# 0: 800x608 2 750ml cokes, 355.1ms
# Speed: 5.4ms preprocess, 355.1ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 6 wallss, 308.6ms
# Speed: 2.0ms preprocess, 308.6ms inference, 15.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 342.2ms
# Speed: 5.2ms preprocess, 342.2ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 73.63 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image5.jpeg: 640x480 1 ceiling, 3 floors, 2 wallss, 324.4ms
# Speed: 2.2ms preprocess, 324.4ms inference, 9.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 448.13 cm
#
# 0: 800x608 1 750ml coke, 335.6ms
# Speed: 3.8ms preprocess, 335.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 2 wallss, 316.3ms
# Speed: 2.1ms preprocess, 316.3ms inference, 8.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 328.0ms
# Speed: 6.0ms preprocess, 328.0ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 80.00 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image17.jpeg: 640x480 1 ceiling, 1 floor, 4 wallss, 303.7ms
# Speed: 2.2ms preprocess, 303.7ms inference, 9.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 415.34 cm
#
# 0: 800x608 1 750ml coke, 346.3ms
# Speed: 5.5ms preprocess, 346.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 4 wallss, 317.7ms
# Speed: 2.3ms preprocess, 317.7ms inference, 9.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 360.0ms
# Speed: 5.5ms preprocess, 360.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 73.30 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image45.jpeg: 640x480 3 ceilings, 3 floors, 4 wallss, 414.2ms
# Speed: 8.1ms preprocess, 414.2ms inference, 13.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 451.88 cm
#
# 0: 800x608 1 750ml coke, 360.6ms
# Speed: 3.6ms preprocess, 360.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 3 floors, 4 wallss, 345.3ms
# Speed: 2.0ms preprocess, 345.3ms inference, 13.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 330.6ms
# Speed: 4.4ms preprocess, 330.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 85.21 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image26.jpeg: 640x480 2 ceilings, 1 floor, 5 wallss, 317.7ms
# Speed: 3.8ms preprocess, 317.7ms inference, 11.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 337.45 cm
#
# 0: 800x608 1 750ml coke, 330.4ms
# Speed: 3.6ms preprocess, 330.4ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 5 wallss, 295.8ms
# Speed: 2.1ms preprocess, 295.8ms inference, 10.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 375.4ms
# Speed: 4.1ms preprocess, 375.4ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 74.43 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image22.jpeg: 640x480 3 ceilings, 4 floors, 8 wallss, 311.0ms
# Speed: 2.6ms preprocess, 311.0ms inference, 19.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 343.02 cm
#
# 0: 800x608 1 750ml coke, 365.8ms
# Speed: 5.6ms preprocess, 365.8ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 4 floors, 8 wallss, 326.2ms
# Speed: 2.2ms preprocess, 326.2ms inference, 23.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 357.4ms
# Speed: 4.0ms preprocess, 357.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 83.94 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image52.jpeg: 640x480 1 ceiling, 6 floors, 7 wallss, 322.1ms
# Speed: 2.3ms preprocess, 322.1ms inference, 21.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 384.07 cm
#
# 0: 800x608 1 750ml coke, 464.6ms
# Speed: 3.8ms preprocess, 464.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 6 floors, 7 wallss, 305.1ms
# Speed: 2.1ms preprocess, 305.1ms inference, 18.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 345.1ms
# Speed: 5.0ms preprocess, 345.1ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 65.91 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image8.jpeg: 640x480 3 floors, 1 walls, 308.4ms
# Speed: 2.0ms preprocess, 308.4ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 480)
# Skipping image8.jpeg: Ceiling or floor not detected.
#
# 0: 800x608 1 750ml coke, 348.8ms
# Speed: 3.5ms preprocess, 348.8ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 81.12 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image38.jpeg: 640x480 3 ceilings, 1 floor, 4 wallss, 341.5ms
# Speed: 2.0ms preprocess, 341.5ms inference, 12.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 393.57 cm
#
# 0: 800x608 1 750ml coke, 340.6ms
# Speed: 5.5ms preprocess, 340.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 4 wallss, 318.4ms
# Speed: 2.1ms preprocess, 318.4ms inference, 12.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 341.9ms
# Speed: 4.8ms preprocess, 341.9ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 80.77 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image27.jpeg: 640x480 4 ceilings, 2 floors, 4 wallss, 305.8ms
# Speed: 2.3ms preprocess, 305.8ms inference, 15.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 357.01 cm
#
# 0: 800x608 1 750ml coke, 356.7ms
# Speed: 5.9ms preprocess, 356.7ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 2 floors, 4 wallss, 303.3ms
# Speed: 2.2ms preprocess, 303.3ms inference, 12.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 750ml cokes, 435.5ms
# Speed: 5.4ms preprocess, 435.5ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 78.98 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image4.jpeg: 640x480 1 ceiling, 2 floors, 2 wallss, 325.0ms
# Speed: 2.2ms preprocess, 325.0ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 350.25 cm
#
# 0: 800x608 2 750ml cokes, 359.4ms
# Speed: 4.8ms preprocess, 359.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 2 wallss, 319.8ms
# Speed: 6.0ms preprocess, 319.8ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 352.3ms
# Speed: 5.8ms preprocess, 352.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 80.98 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image42.jpeg: 640x480 2 ceilings, 1 floor, 3 wallss, 322.4ms
# Speed: 2.2ms preprocess, 322.4ms inference, 9.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 410.32 cm
#
# 0: 800x608 1 750ml coke, 429.6ms
# Speed: 5.5ms preprocess, 429.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 3 wallss, 434.3ms
# Speed: 9.2ms preprocess, 434.3ms inference, 8.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 338.8ms
# Speed: 4.4ms preprocess, 338.8ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 77.33 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image40.jpeg: 640x480 2 ceilings, 1 floor, 8 wallss, 327.5ms
# Speed: 8.0ms preprocess, 327.5ms inference, 16.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 429.68 cm
#
# 0: 800x608 1 750ml coke, 343.6ms
# Speed: 5.6ms preprocess, 343.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 8 wallss, 310.5ms
# Speed: 2.2ms preprocess, 310.5ms inference, 14.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 750ml cokes, 447.6ms
# Speed: 4.7ms preprocess, 447.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 81.03 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image12.jpeg: 640x480 1 floor, 3 wallss, 316.2ms
# Speed: 3.3ms preprocess, 316.2ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 480)
# Skipping image12.jpeg: Ceiling or floor not detected.
#
# 0: 800x608 1 750ml coke, 354.2ms
# Speed: 5.7ms preprocess, 354.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 75.70 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image21.jpeg: 640x480 1 floor, 4 wallss, 305.5ms
# Speed: 3.4ms preprocess, 305.5ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 480)
# Skipping image21.jpeg: Ceiling or floor not detected.
#
# 0: 800x608 1 750ml coke, 354.5ms
# Speed: 4.5ms preprocess, 354.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 97.93 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image11.jpeg: 640x480 3 ceilings, 1 floor, 3 wallss, 326.2ms
# Speed: 1.9ms preprocess, 326.2ms inference, 9.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 271.60 cm
#
# 0: 800x608 1 750ml coke, 352.6ms
# Speed: 3.9ms preprocess, 352.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 3 wallss, 320.7ms
# Speed: 2.1ms preprocess, 320.7ms inference, 9.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 349.2ms
# Speed: 4.4ms preprocess, 349.2ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 87.76 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image41.jpeg: 640x480 5 ceilings, 1 floor, 6 wallss, 311.5ms
# Speed: 4.0ms preprocess, 311.5ms inference, 15.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 335.06 cm
#
# 0: 800x608 1 750ml coke, 345.6ms
# Speed: 4.8ms preprocess, 345.6ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 5 ceilings, 1 floor, 6 wallss, 404.6ms
# Speed: 2.8ms preprocess, 404.6ms inference, 16.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 354.9ms
# Speed: 3.5ms preprocess, 354.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 69.07 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image6.jpeg: 640x480 1 ceiling, 1 floor, 5 wallss, 304.6ms
# Speed: 1.9ms preprocess, 304.6ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 480.32 cm
#
# 0: 800x608 1 750ml coke, 365.1ms
# Speed: 10.8ms preprocess, 365.1ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 5 wallss, 309.1ms
# Speed: 2.6ms preprocess, 309.1ms inference, 9.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 357.3ms
# Speed: 3.8ms preprocess, 357.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 82.73 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image18.jpeg: 640x480 2 ceilings, 2 floors, 7 wallss, 343.4ms
# Speed: 1.9ms preprocess, 343.4ms inference, 14.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 374.31 cm
#
# 0: 800x608 1 750ml coke, 333.4ms
# Speed: 4.0ms preprocess, 333.4ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 7 wallss, 313.8ms
# Speed: 2.1ms preprocess, 313.8ms inference, 14.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 369.6ms
# Speed: 4.1ms preprocess, 369.6ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 84.07 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image28.jpeg: 640x480 4 ceilings, 3 floors, 10 wallss, 441.2ms
# Speed: 5.8ms preprocess, 441.2ms inference, 29.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 385.33 cm
#
# 0: 800x608 1 750ml coke, 336.3ms
# Speed: 4.4ms preprocess, 336.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 3 floors, 10 wallss, 318.7ms
# Speed: 2.1ms preprocess, 318.7ms inference, 23.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 750ml coke, 386.9ms
# Speed: 11.8ms preprocess, 386.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Detected Coca-Cola Bottle Height: 78.43 pixels
# Estimated Real-World Height: 26.00 cm
#
# image 1/1 /home/priyansh/Philipee OBADIA  Project/Input_test_folder(3m approx)/image1.jpeg: 640x480 2 ceilings, 2 floors, 4 wallss, 306.5ms
# Speed: 2.1ms preprocess, 306.5ms inference, 13.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height: 422.99 cm
#
# 0: 800x608 1 750ml coke, 361.4ms
# Speed: 5.5ms preprocess, 361.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 4 wallss, 345.3ms
# Speed: 2.1ms preprocess, 345.3ms inference, 13.7ms postprocess per image at shape (1, 3, 640, 480)
# Processing complete! Check the 'output_images' folder.

# %%
import numpy as np

# Predicted height (assumed constant for all images as per your requirement)
actual_height = 340  # cm

# Extract actual heights from the provided results
# image_heights = {
#     "image2.jpeg": 197.32,
#     "image5.jpeg": 210.09,
#     "image4.jpeg": 196.10,
#     "image1.jpeg": 120.91,
# }

# List to store actual heights dynamically
predicted_heights = []
real_heights = []

# Fetch actual heights using a loop
# Convert actual heights to a NumPy array
predicted_heights = np.array(list(image_heights.values()))

# Create an array of the actual height for comparison
real_heights = np.full_like(predicted_heights, actual_height)

# Convert to NumPy arrays for calculations
# actual_heights = np.array(actual_heights)
# predicted_heights = np.full_like(actual_heights, predicted_height)

# Compute evaluation metrics
mae = np.mean(np.abs(real_heights - predicted_heights))  # Mean Absolute Error
mse = np.mean((real_heights - predicted_heights) ** 2)  # Mean Squared Error
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Print results
formatted_heights = ", ".join(f"{h:.2f}" for h in predicted_heights)
print(f"Predicted Heights: [{formatted_heights}]")
print(f"MAE: {mae:.2f} cm")
print(f"MSE: {mse:.2f} cm²")
print(f"RMSE: {rmse:.2f} cm")
# Out:
# Predicted Heights: [412.45, 415.40, 431.77, 399.84, 437.79, 462.10, 409.17, 415.18, 455.41, 345.79, 298.62, 339.87, 429.54, 316.05, 474.73, 423.68, 434.88, 408.20, 449.94, 358.32, 419.99, 286.15, 276.17, 401.54, 322.76, 408.67, 376.82, 456.19, 436.41, 448.13, 415.34, 451.88, 337.45, 343.02, 384.07, 393.57, 357.01, 350.25, 410.32, 429.68, 271.60, 335.06, 480.32, 374.31, 385.33, 422.99]
# MAE: 65.35 cm
# MSE: 5688.21 cm²
# RMSE: 75.42 cm

# %%
# Calculate Mean Absolute Percentage Error (MAPE)
mape = np.mean(np.abs((real_heights - predicted_heights) / real_heights)) * 100

# Calculate Accuracy
accuracy = 100 - mape

# Print results
print(f"MAPE: {mape:.2f}%")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# MAPE: 19.22%
# Accuracy: 80.78%
