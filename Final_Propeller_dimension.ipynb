# %%
import cv2
import torch
from ultralytics import YOLO

# %%
def natural_sort_key(filename):
    """Extract numerical values from filenames for correct sorting."""
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', filename)]

# %%
def detect_objects(model, image_path):
    image = cv2.imread(image_path)
    results = model(image)  # Perform object detection
    return results, image

# %%
def get_ceiling_floor_coordinates(results, floor_model):
    ceiling_y = None  # Initialize
    floor_y = None  # Initialize
    best_ceiling = None
    best_floor = None

    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coords
            confidence = float(box.conf[0].cpu().numpy())  # Confidence score
            class_id = int(box.cls[0].cpu().numpy())  # Class ID
            
            class_name = floor_model.names.get(class_id, "Unknown")

            if class_name == "ceiling":
                if best_ceiling is None or confidence > best_ceiling[1]:
                    best_ceiling = ((x1, y1, x2, y2), confidence)

            if class_name == "floor":
                if best_floor is None or confidence > best_floor[1]:
                    best_floor = ((x1, y1, x2, y2), confidence)

    ceiling_mid, floor_mid = None, None  

    if best_ceiling:
        (_, ceiling_y1, _, ceiling_y2), _ = best_ceiling
        ceiling_y = (ceiling_y1 + ceiling_y2)// 2  # Midpoint

    if best_floor:
        (_, floor_y1, _, floor_y2), _ = best_floor
        floor_y = (floor_y1 + floor_y2)// 2  # Midpoint

    return ceiling_y, floor_y

# %%
def detect_height_bottle(image_path, model):
    """Detect Coca-Cola bottles and return their bounding box height in pixels."""
    image = cv2.imread(image_path)
    results = model(image)
    coke_boxes = []
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Bounding box coordinates
            height_pixels = y2 - y1  # Bottle height in pixels
            real_height_cm = 26  # Known height of Coca-Cola bottle
            coke_boxes.append((x1, y1, x2, y2))
            pixel_to_cm_ratio = real_height_cm / height_pixels
            estimated_real_height = height_pixels * pixel_to_cm_ratio
            
            return height_pixels, estimated_real_height
    

    return None, None  # If no bottle is detected

# %%
def get_floor_coordinates(results):
    """Extract the top Y-coordinate and bounding box of the floor"""
    floor_y_top = None
    floor_box = None
    
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls.cpu().numpy().item())  # Get class ID
            x_min, y_min, x_max, y_max = map(int, box.xyxy[0])  # Bounding box
            
            if class_id == 1:  # Assuming class 1 is "floor"
                floor_y_top = y_min  # Top Y-coordinate of floor
                floor_box = (x_min, y_min, x_max, y_max)
    
    return floor_y_top, floor_box

# %%
def get_propeller_coordinates(results):
    """Extract the bottom Y-coordinates and bounding boxes of propellers"""
    propeller_boxes = []  # Store bounding boxes of detected propellers
    propeller_y_bottoms = []  # Store Y-bottom of propellers
    
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls.cpu().numpy().item())  # Get class ID
            x_min, y_min, x_max, y_max = map(int, box.xyxy[0])  # Bounding box
            
            if class_id == 0:  # Assuming class 0 is "propeller"
                propeller_y_bottoms.append(y_max)  # Store bottom Y-coordinate
                propeller_boxes.append((x_min, y_min, x_max, y_max))
    
    return propeller_y_bottoms, propeller_boxes

# %%
def detect_height_bottle(image_path, model):
    """Detect Coca-Cola bottles and return their bounding box height in pixels."""
    image = cv2.imread(image_path)
    results = model(image)
    coke_boxes = []
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Bounding box coordinates
            height_pixels = y2 - y1  # Bottle height in pixels
            real_height_cm = 26  # Known height of Coca-Cola bottle
            coke_boxes.append((x1, y1, x2, y2))
            pixel_to_cm_ratio = real_height_cm / height_pixels
            estimated_real_height = height_pixels * pixel_to_cm_ratio
            
            return height_pixels, estimated_real_height
    

    return None, None  # If no bottle is detected

# %%
def calculate_height(ceiling_y, floor_y, calibration_obj):
    """Calculate ceiling height using a calibration object (Coca-Cola bottle)."""
    if ceiling_y is None or floor_y is None:
        print("Error: Ceiling or Floor not detected!")
        return None  # Avoid TypeError

    pixel_height = floor_y - ceiling_y

    if calibration_obj:
        real_height, obj_pixel_height = calibration_obj
        pixel_to_cm_ratio = real_height / obj_pixel_height
        return pixel_height * pixel_to_cm_ratio
    
    return pixel_height  # Return pixel height if no calibration object

# %%
def draw_detections(image, propeller_boxes, floor_box, calibration_obj, floor_results):
    best_ceiling = None
    best_floor = None  # Ensure variables are initialized

    for i, (x1, y1, x2, y2) in enumerate(propeller_boxes):  # Unpacking tuple directly
        x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])  # Ensure integer values
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
        
        # Calculate height from floor to propeller
        pixel_height = y1 - floor_box[1]
        real_height = calculate_height(y1, floor_box[1], calibration_obj)
        height_text = f"Height: {real_height:.2f} cm"
        
        # Draw text label
        cv2.putText(image, height_text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Label the calibration object
    if calibration_obj:
        real_height, obj_pixel_height = calibration_obj
        cal_text = f"Calibration: {real_height:.2f} cm ({obj_pixel_height} px)"
        cv2.putText(image, cal_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)
    
    # Process results
    for result in floor_results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coordinates
            confidence = float(box.conf[0].cpu().numpy())  # Confidence score
            class_id = int(box.cls[0].cpu().numpy())  # Class ID

            # Get class name correctly
            class_name = floor_model.names.get(class_id, "Unknown")  # Ensure we get the correct class label

            # Store the most confident "ceiling" and "floor" detection
            if class_name == "ceiling":
                if best_ceiling is None or confidence > best_ceiling[1]:
                    best_ceiling = ((x1, y1, x2, y2), confidence, class_name)

            if class_name == "floor":
                if best_floor is None or confidence > best_floor[1]:
                    best_floor = ((x1, y1, x2, y2), confidence, class_name)    # f.write("\nDetection Results (Ceiling Height and AC Height):\n")
    # for result in image_results:
    #     f.write(result + "\n")

    # Draw only the best detections on the image
    for best in [best_ceiling, best_floor]:
        if best is not None:  # Ensure best_ceiling and best_floor are not None
            (x1, y1, x2, y2), confidence, class_name = best
            label = f'{class_name}: {confidence:.2f}'
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    return image

# %%
def draw_annotations(image, coke_boxes, ceiling_y, floor_y, pixel_to_cm_ratio=None):
    """Draws bounding boxes, vertical line, and labels on the image."""
    annotated_image = image.copy()
    
    # Draw Coca-Cola bounding boxes
    for (x1, y1, x2, y2, height_pixels) in coke_boxes:
        cv2.rectangle(annotated_image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green box
        cv2.putText(annotated_image, f"{height_pixels}px", (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Draw vertical line from floor to ceiling
    if ceiling_y is not None and floor_y is not None:
        mid_x = image.shape[1] // 2  # Center x-coordinate
        cv2.line(annotated_image, (mid_x, ceiling_y), (mid_x, floor_y), (0, 0, 255), 2)  # Red line
        
        # Calculate real-world ceiling height if calibration object exists
        pixel_height = floor_y - ceiling_y
        if pixel_to_cm_ratio:
            real_ceiling_height = pixel_height * pixel_to_cm_ratio
            height_text = f"Height: {real_ceiling_height:.2f} cm"
        else:
            height_text = f"Height: {pixel_height} pixels"

        # Add text label
        cv2.putText(annotated_image, height_text, (mid_x + 10, (ceiling_y + floor_y) // 2),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    return annotated_image

# %%
import os
import re
import cv2
import numpy as np
from ultralytics import YOLO

def natural_sort_key(filename):
    """Extract numerical values from filenames for correct sorting."""
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', filename)]

# Define folders
image_folder = "Input Dataset folder"
output_folder = "Output_test_folder_combined2"
propeller_output_folder = "Output_test_folder_propeller_only1"
os.makedirs(output_folder, exist_ok=True)

# Load models
coke_model = YOLO("best (8).pt")          # For calibration (coca bottle)
box_propeller_model = YOLO("best (20).pt")  # For box propellers
round_propeller_model = YOLO("best (21).pt")  # For round propellers
floor_model = YOLO("best (5).pt")           # For floor detection

def calculate_pixel_to_cm_ratio(estimated_real_height, height_pixels):
    """Calculate pixel-to-cm ratio using the detected Coca-Cola bottle height."""
    return estimated_real_height / height_pixels if height_pixels else None

def detect_objects(model, image_path):
    """Run object detection using a given YOLO model."""
    image = cv2.imread(image_path)
    results = model(image)
    return results, image

def detect_and_measure_propellers(image_path, box_model, round_model, pixel_to_cm_ratio):
    """
    Detect and measure both round and box propellers in the image.
    Returns:
       measurements: list of tuples.
         For box: ("Box", width_cm, height_cm, vertical_height)
         For round: ("Round", diameter_cm, circumference_cm, vertical_height)
       image: the annotated image.
    Note: This function assumes that global variables `floor_y` and `calibration_obj` are set.
    """
    box_results, image = detect_objects(box_model, image_path)
    round_results, _ = detect_objects(round_model, image_path)
    
    measurements = []
    CONFIDENCE_THRESHOLD_BOX = 0.65
    CONFIDENCE_THRESHOLD_ROUND = 0.65

    # Process box propellers
    for result in box_results:
        for i, box in enumerate(result.boxes.xyxy):
            confidence = float(result.boxes.conf[i])
            if confidence < CONFIDENCE_THRESHOLD_BOX:
                continue
            x1, y1, x2, y2 = map(int, box.tolist())
            width_px = x2 - x1
            height_px = y2 - y1
            width_cm = width_px * pixel_to_cm_ratio if pixel_to_cm_ratio else 0
            height_cm = height_px * pixel_to_cm_ratio if pixel_to_cm_ratio else 0
            # Calculate vertical height from the bottom of the box (y2) to the floor
            propeller_height = calculate_height(y2, floor_y, calibration_obj) if calibration_obj else 0
            measurements.append(("Box", width_cm, height_cm, propeller_height))
            
            # Draw box and annotate
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 255), 2)
            label = f"W:{width_cm:.2f} cm, H:{height_cm:.2f} cm" if pixel_to_cm_ratio else "Box: Unknown"
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
            x_mid = (x1 + x2) // 2
            cv2.line(image, (x_mid, y2), (x_mid, floor_y), (0, 255, 255), 2)
            text_pos = (x_mid + 10, (y2 + floor_y) // 2)
            label_height = f"H: {propeller_height:.2f} cm" if calibration_obj else "Height: Unknown"
            cv2.putText(image, label_height, text_pos, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
    
    # Process round propellers
    for result in round_results:
        for i, box in enumerate(result.boxes.xyxy):
            confidence = float(result.boxes.conf[i])
            if confidence < CONFIDENCE_THRESHOLD_ROUND:
                continue
            x1, y1, x2, y2 = map(int, box.tolist())
            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2
            radius_px = max((x2 - x1), (y2 - y1)) // 2  # approximate radius
            diameter_px = 2 * radius_px
            diameter_cm = diameter_px * pixel_to_cm_ratio if pixel_to_cm_ratio else 0
            circumference_cm = np.pi * diameter_cm if pixel_to_cm_ratio else 0
            # Calculate vertical height from the bottom of the circle to the floor
            bottom_y = center_y + radius_px
            propeller_height = calculate_height(bottom_y, floor_y, calibration_obj) if calibration_obj else 0
            measurements.append(("Round", diameter_cm, circumference_cm, propeller_height))
            
            # Draw circle and annotate
            cv2.circle(image, (center_x, center_y), radius_px, (0, 0, 255), 2)
            cv2.line(image, (center_x, bottom_y), (center_x, floor_y), (0, 0, 255), 2)
            text_pos = (center_x + 10, (bottom_y + floor_y) // 2)
            label_height = f"H: {propeller_height:.2f} cm" if calibration_obj else "Height: Unknown"
            cv2.putText(image, label_height, text_pos, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
            circ_label = f"C: {circumference_cm:.2f} cm" if pixel_to_cm_ratio else "Circumference: Unknown"
            cv2.putText(image, circ_label, (x1, y1 - 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
    return measurements, image

# Dictionaries to store results (if needed)
ceil_heights = {}
Propeller_heights = {}
image_results = []

# Get and sort image filenames
image_files = sorted(
    [f for f in os.listdir(image_folder) if f.lower().endswith((".jpg", ".jpeg", ".png"))],
    key=natural_sort_key
)
j=0
for image_name in image_files:
    image_path = os.path.join(image_folder, image_name)
    # Detect Coca-Cola bottle for calibration.
    height_pixels, estimated_real_height = detect_height_bottle(image_path, coke_model)
    calibration_obj = (estimated_real_height, height_pixels) if height_pixels else None
    # Get floor (and ceiling) coordinates.
    floor_results, _ = detect_objects(floor_model, image_path)
    # (Assume get_ceiling_floor_coordinates returns (ceiling_y, floor_y))
    ceiling_y, floor_y = get_ceiling_floor_coordinates(floor_results, floor_model)
    if ceiling_y is None or floor_y is None:
        ceiling_height = "XXXXX"
        formatted_ceil_height = "XXXXX"
    elif calibration_obj:
        ceiling_height = calculate_height(ceiling_y, floor_y, calibration_obj)
    else:
        ceiling_height = "XXXXX"
        formatted_ceil_height = "XXXXX"
    print(f"Ceiling Height for {image_name}: {ceiling_height}")
    if ceiling_height != "XXXXX":
        if isinstance(ceiling_height, torch.Tensor):
            formatted_ceil_height = round(ceiling_height.item(), 2)  # Extract scalar if it's a tensor
        else:
            formatted_ceil_height = round(float(ceiling_height), 2)  # Convert string/float to rounded float
        ceil_heights[image_name] = ceiling_height
    pixel_to_cm_ratio = calculate_pixel_to_cm_ratio(estimated_real_height, height_pixels)
    # Detect and measure propellers.
    # Note: The function uses the global variables floor_y and calibration_obj.
    measurements, processed_image = detect_and_measure_propellers(image_path, box_propeller_model, round_propeller_model, pixel_to_cm_ratio)
    
    # Draw vertical reference line for ceiling height.
    if ceiling_y is not None and floor_y is not None and ceiling_height != "XXXXX":
        mid_x = processed_image.shape[1] // 2
        cv2.line(processed_image, (mid_x, ceiling_y), (mid_x, floor_y), (0, 255, 0), 3)
        text_position = (mid_x + 10, (ceiling_y + floor_y) // 2)
        cv2.putText(processed_image, f"{ceiling_height:.2f} cm", text_position, cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    coca_bottle_detected = 1 if calibration_obj else 0
    round_circumference = 0
    round_prop_height = 0
    box_length = 0
    box_width = 0
    box_prop_height = 0
    for meas in measurements:
        if meas[0] == "Round":
            round_circumference = int(meas[2])
            round_prop_height = int(meas[3]) 
        elif meas[0] == "Box":
            box_length = int(meas[1])
            box_width = int(meas[2])
            box_prop_height = int(meas[3])
    base_name = image_name.split('.')[0]
    if coca_bottle_detected:
        if round_circumference > 0:
            new_filename = f"{base_name}-{coca_bottle_detected}-{round_circumference}-{round_circumference}-{round_prop_height}.jpg"
        elif box_length > 0:
            new_filename = f"{base_name}-{coca_bottle_detected}-{box_length}-{box_width}-{box_prop_height}.jpg"
        else:
            new_filename = f"{base_name}-{coca_bottle_detected}-0-0-0.jpg"
    else:
        new_filename = f"{base_name}-2-0-0-0.jpg"
    output_path = os.path.join(output_folder, new_filename)
    cv2.imwrite(output_path, processed_image)
    print(f"Processed Image saved at: {output_path}")
    propeller_heights_details = []
    for idx, meas in enumerate(measurements):
        if meas[0] == "Box":
            print(f"Box Propeller {idx + 1} -> Length: {meas[1]} cm, Width: {meas[2]} cm, Height: {meas[3]} cm")
        else:
            print(f"Round Propeller {idx + 1} -> Diameter: {meas[1]} cm, Circumference: {meas[2]} cm, Height: {meas[3]} cm")   
        propeller_heights_details.append(f"P{idx + 1}: {meas[3]:.2f} cm")
    ac_height = ", ".join(propeller_heights_details) if propeller_heights_details else "YYYY"
    j = j+1
    image_results.append(f"Photo {j} | ID {new_filename} | Ceiling height {formatted_ceil_height}cm | AC Height {ac_height}")
# Print final results
print("\nFinal Results:")
for result in image_results:
    print(result)

results_txt = os.path.join(output_folder, "detect_results.txt")
# Write the results into a text file with separate sections.
with open(results_txt, "w") as f:
    f.write("\nDetection Results (Ceiling Height and AC Height):\n")
    for result in image_results:
        f.write(result + "\n")

print(f"Results saved to {results_txt}")
# print(f"\nDetection results saved at: {txt_output_path}")
# Out:
# /home/priyansh/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:129: UserWarning: CUDA initialization: CUDA driver initialization failed, you might not have a CUDA gpu. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# 0: 800x608 1 750ml coke, 231.6ms
# Speed: 4.1ms preprocess, 231.6ms inference, 5.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 4 wallss, 205.9ms
# Speed: 1.5ms preprocess, 205.9ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageA.jpeg: 307.6259460449219
#
# 0: 800x608 (no detections), 195.4ms
# Speed: 3.2ms preprocess, 195.4ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 196.3ms
# Speed: 2.5ms preprocess, 196.3ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageA-1-0-0-0.jpg
#
# 0: 608x800 (no detections), 179.2ms
# Speed: 3.0ms preprocess, 179.2ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 480x640 1 ceiling, 1 floor, 2 wallss, 192.7ms
# Speed: 1.2ms preprocess, 192.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Ceiling Height for imagea.jpg: XXXXX
#
# 0: 608x800 (no detections), 204.1ms
# Speed: 2.4ms preprocess, 204.1ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 178.2ms
# Speed: 2.8ms preprocess, 178.2ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 800)
# Processed Image saved at: Output_test_folder_combined/imagea-2-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 172.7ms
# Speed: 3.0ms preprocess, 172.7ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 2 floors, 4 wallss, 145.1ms
# Speed: 1.4ms preprocess, 145.1ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAA.jpeg: 294.5539855957031
#
# 0: 800x608 (no detections), 203.0ms
# Speed: 2.2ms preprocess, 203.0ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 5 round-propellers, 174.0ms
# Speed: 3.1ms preprocess, 174.0ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAA-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 194.0ms
# Speed: 2.7ms preprocess, 194.0ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 3 floors, 10 wallss, 168.0ms
# Speed: 1.7ms preprocess, 168.0ms inference, 11.7ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAB.jpeg: 301.8333740234375
#
# 0: 800x608 3 Box-Propellers, 173.7ms
# Speed: 2.9ms preprocess, 173.7ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 204.2ms
# Speed: 4.3ms preprocess, 204.2ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAB-1-35-10-232.jpg
# Box Propeller 1 -> Length: 34.63661575317383 cm, Width: 8.659153938293457 cm, Height: 221.11769104003906 cm
# Box Propeller 2 -> Length: 22.575653076171875 cm, Width: 20.101608276367188 cm, Height: 221.7362060546875 cm
# Box Propeller 3 -> Length: 35.255126953125 cm, Width: 10.205431938171387 cm, Height: 232.86940002441406 cm
#
# 0: 800x608 1 750ml coke, 176.6ms
# Speed: 2.7ms preprocess, 176.6ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 2 floors, 5 wallss, 158.6ms
# Speed: 1.8ms preprocess, 158.6ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAC.jpeg: 315.21002197265625
#
# 0: 800x608 2 Box-Propellers, 189.4ms
# Speed: 4.2ms preprocess, 189.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 196.0ms
# Speed: 2.5ms preprocess, 196.0ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAC-1-70-17-259.jpg
# Box Propeller 1 -> Length: 70.04666900634766 cm, Width: 17.511667251586914 cm, Height: 259.9280700683594 cm
#
# 0: 800x608 1 750ml coke, 170.8ms
# Speed: 2.8ms preprocess, 170.8ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 4 wallss, 157.5ms
# Speed: 1.7ms preprocess, 157.5ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAD.jpeg: 321.8470764160156
#
# 0: 800x608 2 Box-Propellers, 169.2ms
# Speed: 4.8ms preprocess, 169.2ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 170.3ms
# Speed: 2.7ms preprocess, 170.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAD-1-55-14-244.jpg
# Box Propeller 1 -> Length: 55.67667007446289 cm, Width: 14.727376937866211 cm, Height: 244.61814880371094 cm
#
# 0: 800x608 1 750ml coke, 168.0ms
# Speed: 2.6ms preprocess, 168.0ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 6 wallss, 157.3ms
# Speed: 2.1ms preprocess, 157.3ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAE.jpeg: 249.3293914794922
#
# 0: 800x608 4 Box-Propellers, 164.0ms
# Speed: 3.3ms preprocess, 164.0ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 8 round-propellers, 168.5ms
# Speed: 2.6ms preprocess, 168.5ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAE-1-63-18-297.jpg
# Box Propeller 1 -> Length: 29.054643630981445 cm, Width: 10.135340690612793 cm, Height: 188.85519409179688 cm
# Box Propeller 2 -> Length: 34.798004150390625 cm, Width: 22.973440170288086 cm, Height: 264.8702392578125 cm
# Box Propeller 3 -> Length: 63.51480484008789 cm, Width: 18.581459045410156 cm, Height: 297.3033447265625 cm
#
# 0: 800x608 1 750ml coke, 170.1ms
# Speed: 2.9ms preprocess, 170.1ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 5 wallss, 159.3ms
# Speed: 1.6ms preprocess, 159.3ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAF.jpeg: 245.54425048828125
#
# 0: 800x608 2 Box-Propellers, 163.7ms
# Speed: 2.6ms preprocess, 163.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 182.9ms
# Speed: 3.3ms preprocess, 182.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAF-1-39-11-239.jpg
# Box Propeller 1 -> Length: 39.368736267089844 cm, Width: 11.664810180664062 cm, Height: 239.71185302734375 cm
#
# 0: 800x608 1 750ml coke, 194.2ms
# Speed: 2.0ms preprocess, 194.2ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 4 floors, 5 wallss, 165.8ms
# Speed: 2.2ms preprocess, 165.8ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAG.jpeg: 290.0688171386719
#
# 0: 800x608 2 Box-Propellers, 172.7ms
# Speed: 3.3ms preprocess, 172.7ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 round-propellers, 174.6ms
# Speed: 2.9ms preprocess, 174.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAG-1-38-38-225.jpg
# Box Propeller 1 -> Length: 40.505104064941406 cm, Width: 15.026087760925293 cm, Height: 285.49566650390625 cm
# Round Propeller 2 -> Diameter: 12.41285514831543 cm, Circumference: 38.99613571166992 cm, Height: 225.7179718017578 cm
#
# 0: 800x608 1 750ml coke, 169.9ms
# Speed: 3.0ms preprocess, 169.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 floor, 1 walls, 150.4ms
# Speed: 1.7ms preprocess, 150.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAH.jpeg: XXXXX
#
# 0: 800x608 1 Box-Propeller, 182.2ms
# Speed: 3.8ms preprocess, 182.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 183.1ms
# Speed: 3.8ms preprocess, 183.1ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAH-1-87-20-288.jpg
# Box Propeller 1 -> Length: 87.67884826660156 cm, Width: 20.748430252075195 cm, Height: 288.1354675292969 cm
#
# 0: 800x608 1 750ml coke, 176.9ms
# Speed: 3.3ms preprocess, 176.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 2 floors, 10 wallss, 155.1ms
# Speed: 1.8ms preprocess, 155.1ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAI.jpeg: 343.8022155761719
#
# 0: 800x608 1 Box-Propeller, 166.1ms
# Speed: 3.2ms preprocess, 166.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 167.7ms
# Speed: 3.1ms preprocess, 167.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAI-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 169.7ms
# Speed: 2.7ms preprocess, 169.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 5 wallss, 150.3ms
# Speed: 1.8ms preprocess, 150.3ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAJ.jpeg: 252.3086395263672
#
# 0: 800x608 5 Box-Propellers, 159.4ms
# Speed: 2.7ms preprocess, 159.4ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 9 round-propellers, 157.5ms
# Speed: 2.7ms preprocess, 157.5ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAJ-1-49-23-304.jpg
# Box Propeller 1 -> Length: 29.967693328857422 cm, Width: 10.311464309692383 cm, Height: 196.884521484375 cm
# Box Propeller 2 -> Length: 27.389827728271484 cm, Width: 27.067594528198242 cm, Height: 240.708251953125 cm
# Box Propeller 3 -> Length: 55.10188674926758 cm, Width: 17.400596618652344 cm, Height: 310.63287353515625 cm
# Box Propeller 4 -> Length: 49.30168914794922 cm, Width: 23.200794219970703 cm, Height: 304.8326721191406 cm
#
# 0: 800x608 1 750ml coke, 162.8ms
# Speed: 2.8ms preprocess, 162.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 4 wallss, 146.7ms
# Speed: 1.4ms preprocess, 146.7ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAK.jpeg: 338.0289001464844
#
# 0: 800x608 2 Box-Propellers, 162.7ms
# Speed: 2.6ms preprocess, 162.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 round-propeller, 167.5ms
# Speed: 2.3ms preprocess, 167.5ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAK-1-193-193-221.jpg
# Box Propeller 1 -> Length: 59.916019439697266 cm, Width: 28.83658790588379 cm, Height: 283.88018798828125 cm
# Box Propeller 2 -> Length: 55.10992431640625 cm, Width: 25.632522583007812 cm, Height: 261.45172119140625 cm
# Round Propeller 3 -> Diameter: 61.51805114746094 cm, Circumference: 193.26466369628906 cm, Height: 221.7213134765625 cm
#
# 0: 800x608 1 750ml coke, 177.1ms
# Speed: 2.4ms preprocess, 177.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 4 wallss, 158.8ms
# Speed: 1.6ms preprocess, 158.8ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAL.jpeg: 294.5360107421875
#
# 0: 800x608 (no detections), 173.2ms
# Speed: 3.0ms preprocess, 173.2ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 174.3ms
# Speed: 3.5ms preprocess, 174.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAL-1-0-0-0.jpg
#
# 0: 800x608 2 750ml cokes, 166.9ms
# Speed: 2.6ms preprocess, 166.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 5 wallss, 152.4ms
# Speed: 2.5ms preprocess, 152.4ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAM.jpeg: 344.34552001953125
#
# 0: 800x608 (no detections), 167.8ms
# Speed: 2.9ms preprocess, 167.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 163.2ms
# Speed: 3.9ms preprocess, 163.2ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAM-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 178.9ms
# Speed: 2.3ms preprocess, 178.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 8 wallss, 142.7ms
# Speed: 1.3ms preprocess, 142.7ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAN.jpeg: 361.7624206542969
#
# 0: 800x608 (no detections), 165.6ms
# Speed: 3.9ms preprocess, 165.6ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 round-propellers, 171.6ms
# Speed: 2.2ms preprocess, 171.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAN-1-99-99-209.jpg
# Round Propeller 1 -> Diameter: 31.60378074645996 cm, Circumference: 99.28620910644531 cm, Height: 209.12289428710938 cm
#
# 0: 800x608 1 750ml coke, 169.4ms
# Speed: 4.2ms preprocess, 169.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 5 ceilings, 1 floor, 6 wallss, 149.1ms
# Speed: 1.6ms preprocess, 149.1ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAO.jpeg: 267.814208984375
#
# 0: 800x608 (no detections), 175.8ms
# Speed: 3.6ms preprocess, 175.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 3 round-propellers, 183.3ms
# Speed: 3.4ms preprocess, 183.3ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAO-1-46-46-190.jpg
# Round Propeller 1 -> Diameter: 13.627714157104492 cm, Circumference: 42.81272888183594 cm, Height: 198.78688049316406 cm
# Round Propeller 2 -> Diameter: 14.81273365020752 cm, Circumference: 46.53557586669922 cm, Height: 190.4917449951172 cm
#
# 0: 800x608 1 750ml coke, 176.5ms
# Speed: 3.0ms preprocess, 176.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 3 wallss, 159.5ms
# Speed: 2.1ms preprocess, 159.5ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAP.jpeg: 326.19915771484375
#
# 0: 800x608 1 Box-Propeller, 180.4ms
# Speed: 4.3ms preprocess, 180.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 181.7ms
# Speed: 3.3ms preprocess, 181.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAP-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 223.2ms
# Speed: 2.6ms preprocess, 223.2ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 1 walls, 156.4ms
# Speed: 1.3ms preprocess, 156.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAQ.jpeg: 314.77947998046875
#
# 0: 800x608 (no detections), 183.5ms
# Speed: 4.0ms preprocess, 183.5ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 187.7ms
# Speed: 3.3ms preprocess, 187.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAQ-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 186.5ms
# Speed: 3.5ms preprocess, 186.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 4 wallss, 155.0ms
# Speed: 1.4ms preprocess, 155.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAR.jpeg: 328.72503662109375
#
# 0: 800x608 (no detections), 168.8ms
# Speed: 2.7ms preprocess, 168.8ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 177.2ms
# Speed: 2.4ms preprocess, 177.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAR-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 187.7ms
# Speed: 3.2ms preprocess, 187.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 3 floors, 4 wallss, 175.0ms
# Speed: 1.5ms preprocess, 175.0ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAS.jpeg: 313.1964111328125
#
# 0: 800x608 1 Box-Propeller, 168.9ms
# Speed: 2.1ms preprocess, 168.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 round-propeller, 196.4ms
# Speed: 2.3ms preprocess, 196.4ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAS-1-25-17-259.jpg
# Box Propeller 1 -> Length: 25.18340301513672 cm, Width: 17.380096435546875 cm, Height: 259.9920349121094 cm
#
# 0: 800x608 1 750ml coke, 195.2ms
# Speed: 2.5ms preprocess, 195.2ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 6 wallss, 161.7ms
# Speed: 1.7ms preprocess, 161.7ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAT.jpeg: 262.62066650390625
#
# 0: 800x608 (no detections), 170.5ms
# Speed: 3.4ms preprocess, 170.5ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 round-propeller, 198.7ms
# Speed: 2.4ms preprocess, 198.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAT-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 171.7ms
# Speed: 3.3ms preprocess, 171.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 2 wallss, 180.7ms
# Speed: 2.2ms preprocess, 180.7ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAU.jpeg: 309.025390625
#
# 0: 800x608 (no detections), 176.3ms
# Speed: 3.4ms preprocess, 176.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 188.4ms
# Speed: 3.3ms preprocess, 188.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAU-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 175.4ms
# Speed: 2.2ms preprocess, 175.4ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 3 wallss, 153.3ms
# Speed: 1.5ms preprocess, 153.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAV.jpeg: 330.5956115722656
#
# 0: 800x608 (no detections), 158.4ms
# Speed: 3.7ms preprocess, 158.4ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 170.2ms
# Speed: 2.8ms preprocess, 170.2ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAV-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 166.3ms
# Speed: 3.3ms preprocess, 166.3ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 7 wallss, 148.2ms
# Speed: 1.6ms preprocess, 148.2ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAW.jpeg: 278.7380065917969
#
# 0: 800x608 (no detections), 174.5ms
# Speed: 3.3ms preprocess, 174.5ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 177.2ms
# Speed: 3.0ms preprocess, 177.2ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAW-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 177.5ms
# Speed: 3.8ms preprocess, 177.5ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 3 wallss, 153.9ms
# Speed: 1.4ms preprocess, 153.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAX.jpeg: 251.76600646972656
#
# 0: 800x608 1 Box-Propeller, 168.2ms
# Speed: 2.3ms preprocess, 168.2ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 9 round-propellers, 207.7ms
# Speed: 3.1ms preprocess, 207.7ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAX-1-36-36-171.jpg
# Round Propeller 1 -> Diameter: 11.520920753479004 cm, Circumference: 36.19404220581055 cm, Height: 171.4584197998047 cm
#
# 0: 800x608 2 750ml cokes, 174.5ms
# Speed: 3.5ms preprocess, 174.5ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 6 wallss, 177.3ms
# Speed: 1.4ms preprocess, 177.3ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAY.jpeg: 337.9875793457031
#
# 0: 800x608 2 Box-Propellers, 203.2ms
# Speed: 3.7ms preprocess, 203.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 round-propeller, 176.8ms
# Speed: 2.9ms preprocess, 176.8ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAY-1-39-10-231.jpg
# Box Propeller 1 -> Length: 39.30088424682617 cm, Width: 10.935897827148438 cm, Height: 231.3625946044922 cm
#
# 0: 800x608 1 750ml coke, 176.7ms
# Speed: 2.9ms preprocess, 176.7ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 6 floors, 7 wallss, 156.4ms
# Speed: 1.6ms preprocess, 156.4ms inference, 7.6ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageAZ.jpeg: 201.9465789794922
#
# 0: 800x608 2 Box-Propellers, 172.6ms
# Speed: 2.1ms preprocess, 172.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 173.6ms
# Speed: 2.9ms preprocess, 173.6ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageAZ-1-13-10-150.jpg
# Box Propeller 1 -> Length: 34.999942779541016 cm, Width: 7.433616638183594 cm, Height: 156.10594177246094 cm
# Box Propeller 2 -> Length: 13.318562507629395 cm, Width: 10.840690612792969 cm, Height: 150.84046936035156 cm
#
# 0: 800x608 1 750ml coke, 166.0ms
# Speed: 2.1ms preprocess, 166.0ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 5 floors, 2 wallss, 153.9ms
# Speed: 1.6ms preprocess, 153.9ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageB.jpeg: XXXXX
#
# 0: 800x608 1 Box-Propeller, 180.3ms
# Speed: 3.2ms preprocess, 180.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 7 round-propellers, 171.6ms
# Speed: 2.9ms preprocess, 171.6ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageB-1-0-0-0.jpg
#
# 0: 544x800 (no detections), 178.2ms
# Speed: 2.7ms preprocess, 178.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 448x640 2 ceilings, 1 floor, 6 wallss, 155.3ms
# Speed: 1.3ms preprocess, 155.3ms inference, 4.7ms postprocess per image at shape (1, 3, 448, 640)
# Ceiling Height for imageb.jpg: XXXXX
#
# 0: 544x800 (no detections), 170.6ms
# Speed: 2.6ms preprocess, 170.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 800)
#
# 0: 544x800 1 round-propeller, 175.4ms
# Speed: 2.8ms preprocess, 175.4ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 800)
# Processed Image saved at: Output_test_folder_combined/imageb-2-0-0-0.jpg
# Round Propeller 1 -> Diameter: 0 cm, Circumference: 0 cm, Height: 0 cm
#
# 0: 800x608 1 750ml coke, 171.9ms
# Speed: 2.7ms preprocess, 171.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 2 floors, 8 wallss, 170.5ms
# Speed: 1.2ms preprocess, 170.5ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageBA.jpeg: 257.3297119140625
#
# 0: 800x608 4 Box-Propellers, 167.7ms
# Speed: 2.3ms preprocess, 167.7ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 round-propeller, 178.8ms
# Speed: 2.4ms preprocess, 178.8ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageBA-1-17-8-210.jpg
# Box Propeller 1 -> Length: 34.027069091796875 cm, Width: 13.06396484375 cm, Height: 229.07510375976562 cm
# Box Propeller 2 -> Length: 17.31734848022461 cm, Width: 8.506767272949219 cm, Height: 210.54249572753906 cm
#
# 0: 800x608 1 750ml coke, 185.4ms
# Speed: 2.5ms preprocess, 185.4ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 floors, 8 wallss, 150.5ms
# Speed: 2.0ms preprocess, 150.5ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageBB.jpeg: XXXXX
#
# 0: 800x608 3 Box-Propellers, 207.8ms
# Speed: 3.6ms preprocess, 207.8ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 168.4ms
# Speed: 2.3ms preprocess, 168.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageBB-1-33-6-175.jpg
# Box Propeller 1 -> Length: 33.3795051574707 cm, Width: 6.675900936126709 cm, Height: 175.31495666503906 cm
#
# 0: 800x608 (no detections), 171.4ms
# Speed: 2.7ms preprocess, 171.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 floors, 1 walls, 179.5ms
# Speed: 1.9ms preprocess, 179.5ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageBC.jpeg: XXXXX
#
# 0: 800x608 (no detections), 165.2ms
# Speed: 2.4ms preprocess, 165.2ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 170.6ms
# Speed: 2.3ms preprocess, 170.6ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageBC-2-0-0-0.jpg
#
# 0: 800x608 2 750ml cokes, 169.4ms
# Speed: 3.0ms preprocess, 169.4ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 1 walls, 144.7ms
# Speed: 1.4ms preprocess, 144.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageC.jpeg: 304.51629638671875
#
# 0: 800x608 6 Box-Propellers, 168.5ms
# Speed: 2.4ms preprocess, 168.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 16 round-propellers, 170.1ms
# Speed: 3.3ms preprocess, 170.1ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageC-1-70-70-172.jpg
# Box Propeller 1 -> Length: 16.166086196899414 cm, Width: 4.9488019943237305 cm, Height: 178.81671142578125 cm
# Box Propeller 2 -> Length: 17.485767364501953 cm, Width: 5.608642578125 cm, Height: 177.8269500732422 cm
# Round Propeller 3 -> Diameter: 22.4345703125 cm, Circumference: 70.48028564453125 cm, Height: 172.87815856933594 cm
#
# 0: 800x800 1 750ml coke, 242.0ms
# Speed: 3.3ms preprocess, 242.0ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 640x640 1 floor, 1 walls, 227.1ms
# Speed: 1.4ms preprocess, 227.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Ceiling Height for imagec.jpg: XXXXX
#
# 0: 800x800 (no detections), 210.1ms
# Speed: 2.1ms preprocess, 210.1ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 2 round-propellers, 213.3ms
# Speed: 2.0ms preprocess, 213.3ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 800)
# Processed Image saved at: Output_test_folder_combined/imagec-1-11-11-4.jpg
# Round Propeller 1 -> Diameter: 3.6401822566986084 cm, Circumference: 11.435970306396484 cm, Height: 4.680234432220459 cm
#
# 0: 800x608 2 750ml cokes, 174.8ms
# Speed: 3.5ms preprocess, 174.8ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 2 wallss, 157.7ms
# Speed: 1.6ms preprocess, 157.7ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageD.jpeg: 328.1935119628906
#
# 0: 800x608 (no detections), 175.3ms
# Speed: 2.9ms preprocess, 175.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 round-propeller, 175.2ms
# Speed: 3.9ms preprocess, 175.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageD-1-148-148-221.jpg
# Round Propeller 1 -> Diameter: 47.402069091796875 cm, Circumference: 148.91799926757812 cm, Height: 221.53884887695312 cm
#
# 0: 800x800 (no detections), 232.0ms
# Speed: 2.7ms preprocess, 232.0ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 640x640 2 ceilings, 2 floors, 7 wallss, 195.0ms
# Speed: 2.5ms preprocess, 195.0ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 640)
# Ceiling Height for imaged.jpg: XXXXX
#
# 0: 800x800 (no detections), 217.5ms
# Speed: 1.9ms preprocess, 217.5ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x800 (no detections), 222.3ms
# Speed: 1.8ms preprocess, 222.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 800)
# Processed Image saved at: Output_test_folder_combined/imaged-2-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 172.4ms
# Speed: 3.5ms preprocess, 172.4ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 2 wallss, 156.9ms
# Speed: 1.5ms preprocess, 156.9ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageE.jpeg: 368.6772766113281
#
# 0: 800x608 3 Box-Propellers, 172.5ms
# Speed: 2.8ms preprocess, 172.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 5 round-propellers, 183.6ms
# Speed: 3.1ms preprocess, 183.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageE-1-99-99-206.jpg
# Box Propeller 1 -> Length: 18.71637535095215 cm, Width: 18.71637535095215 cm, Height: 268.7388916015625 cm
# Box Propeller 2 -> Length: 39.198448181152344 cm, Width: 38.845306396484375 cm, Height: 293.811767578125 cm
# Round Propeller 3 -> Diameter: 31.78252410888672 cm, Circumference: 99.84774780273438 cm, Height: 206.2332763671875 cm
#
# 0: 800x608 1 750ml coke, 175.4ms
# Speed: 2.5ms preprocess, 175.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 5 wallss, 152.2ms
# Speed: 1.7ms preprocess, 152.2ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageF.jpeg: 351.9576721191406
#
# 0: 800x608 (no detections), 165.4ms
# Speed: 2.3ms preprocess, 165.4ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 round-propellers, 169.7ms
# Speed: 2.4ms preprocess, 169.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageF-1-234-234-264.jpg
# Round Propeller 1 -> Diameter: 74.53221130371094 cm, Circumference: 234.1498565673828 cm, Height: 264.62701416015625 cm
#
# 0: 800x608 1 750ml coke, 208.3ms
# Speed: 3.2ms preprocess, 208.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 5 wallss, 152.2ms
# Speed: 1.6ms preprocess, 152.2ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageG.jpeg: 321.4752502441406
#
# 0: 800x608 1 Box-Propeller, 202.3ms
# Speed: 2.4ms preprocess, 202.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 round-propellers, 178.9ms
# Speed: 3.2ms preprocess, 178.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageG-1-57-57-169.jpg
# Round Propeller 1 -> Diameter: 18.38947296142578 cm, Circumference: 57.77223587036133 cm, Height: 169.2512664794922 cm
#
# 0: 800x608 1 750ml coke, 195.4ms
# Speed: 3.1ms preprocess, 195.4ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 floors, 1 walls, 166.9ms
# Speed: 1.6ms preprocess, 166.9ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageH.jpeg: XXXXX
#
# 0: 800x608 1 Box-Propeller, 185.0ms
# Speed: 3.0ms preprocess, 185.0ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 round-propeller, 206.1ms
# Speed: 2.3ms preprocess, 206.1ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageH-1-69-69-180.jpg
# Box Propeller 1 -> Length: 26.82312774658203 cm, Width: 29.584331512451172 cm, Height: 300.5768127441406 cm
# Round Propeller 2 -> Diameter: 22.08963394165039 cm, Circumference: 69.39663696289062 cm, Height: 180.26719665527344 cm
#
# 0: 800x608 2 750ml cokes, 174.1ms
# Speed: 3.4ms preprocess, 174.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 4 floors, 1 walls, 175.9ms
# Speed: 1.7ms preprocess, 175.9ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageI.jpeg: 298.9192199707031
#
# 0: 800x608 2 Box-Propellers, 178.7ms
# Speed: 3.0ms preprocess, 178.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 3 round-propellers, 169.3ms
# Speed: 2.2ms preprocess, 169.3ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageI-1-54-54-157.jpg
# Box Propeller 1 -> Length: 26.034900665283203 cm, Width: 13.820996284484863 cm, Height: 195.42245483398438 cm
# Round Propeller 2 -> Diameter: 17.356599807739258 cm, Circumference: 54.527366638183594 cm, Height: 157.1736602783203 cm
#
# 0: 800x608 1 750ml coke, 186.1ms
# Speed: 2.5ms preprocess, 186.1ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 2 wallss, 151.8ms
# Speed: 1.7ms preprocess, 151.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageJ.jpeg: 379.2301330566406
#
# 0: 800x608 5 Box-Propellers, 175.3ms
# Speed: 3.8ms preprocess, 175.3ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 10 round-propellers, 169.3ms
# Speed: 3.8ms preprocess, 169.3ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageJ-1-68-68-239.jpg
# Box Propeller 1 -> Length: 34.37677764892578 cm, Width: 10.493963241577148 cm, Height: 258.73046875 cm
# Box Propeller 2 -> Length: 22.797231674194336 cm, Width: 7.599077224731445 cm, Height: 253.6644287109375 cm
# Round Propeller 3 -> Diameter: 13.750710487365723 cm, Circumference: 43.19913101196289 cm, Height: 208.79368591308594 cm
# Round Propeller 4 -> Diameter: 11.579545974731445 cm, Circumference: 36.37821578979492 cm, Height: 214.58346557617188 cm
# Round Propeller 5 -> Diameter: 21.71164894104004 cm, Circumference: 68.20915985107422 cm, Height: 239.91371154785156 cm
#
# 0: 800x608 1 750ml coke, 176.8ms
# Speed: 2.6ms preprocess, 176.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 3 wallss, 171.4ms
# Speed: 1.6ms preprocess, 171.4ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageK.jpeg: 314.8735656738281
#
# 0: 800x608 (no detections), 169.4ms
# Speed: 2.7ms preprocess, 169.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 round-propellers, 171.7ms
# Speed: 3.4ms preprocess, 171.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageK-1-95-95-187.jpg
# Round Propeller 1 -> Diameter: 28.14215660095215 cm, Circumference: 88.41119384765625 cm, Height: 195.4021453857422 cm
# Round Propeller 2 -> Diameter: 30.266094207763672 cm, Circumference: 95.083740234375 cm, Height: 187.702880859375 cm
#
# 0: 800x608 2 750ml cokes, 174.5ms
# Speed: 2.8ms preprocess, 174.5ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 floor, 3 wallss, 176.9ms
# Speed: 1.6ms preprocess, 176.9ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageL.jpeg: XXXXX
#
# 0: 800x608 3 Box-Propellers, 168.0ms
# Speed: 3.2ms preprocess, 168.0ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 197.9ms
# Speed: 2.4ms preprocess, 197.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageL-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 170.8ms
# Speed: 2.2ms preprocess, 170.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 floors, 3 wallss, 166.7ms
# Speed: 1.5ms preprocess, 166.7ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageM.jpeg: XXXXX
#
# 0: 800x608 1 Box-Propeller, 168.9ms
# Speed: 2.1ms preprocess, 168.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 198.2ms
# Speed: 3.1ms preprocess, 198.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageM-1-16-7-151.jpg
# Box Propeller 1 -> Length: 16.149269104003906 cm, Width: 7.649653911590576 cm, Height: 151.57647705078125 cm
#
# 0: 800x608 1 750ml coke, 181.8ms
# Speed: 2.3ms preprocess, 181.8ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 5 floors, 3 wallss, 161.3ms
# Speed: 1.5ms preprocess, 161.3ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageN.jpeg: 299.755859375
#
# 0: 800x608 3 Box-Propellers, 160.8ms
# Speed: 2.1ms preprocess, 160.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 173.7ms
# Speed: 3.1ms preprocess, 173.7ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageN-1-17-9-248.jpg
# Box Propeller 1 -> Length: 41.90899658203125 cm, Width: 14.561600685119629 cm, Height: 265.3052673339844 cm
# Box Propeller 2 -> Length: 17.75804901123047 cm, Width: 9.589346885681152 cm, Height: 248.61268615722656 cm
#
# 0: 800x608 2 750ml cokes, 179.8ms
# Speed: 4.2ms preprocess, 179.8ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 6 wallss, 172.8ms
# Speed: 1.7ms preprocess, 172.8ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageO.jpeg: 300.988525390625
#
# 0: 800x608 (no detections), 192.2ms
# Speed: 2.7ms preprocess, 192.2ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 169.7ms
# Speed: 3.0ms preprocess, 169.7ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageO-1-0-0-0.jpg
#
# 0: 800x608 2 750ml cokes, 188.8ms
# Speed: 3.5ms preprocess, 188.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 5 wallss, 160.1ms
# Speed: 1.3ms preprocess, 160.1ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageP.jpeg: 322.65887451171875
#
# 0: 800x608 (no detections), 190.7ms
# Speed: 2.0ms preprocess, 190.7ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 round-propeller, 171.6ms
# Speed: 2.8ms preprocess, 171.6ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageP-1-0-0-0.jpg
#
# 0: 800x608 (no detections), 170.2ms
# Speed: 2.7ms preprocess, 170.2ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 floors, 1 walls, 146.9ms
# Speed: 1.9ms preprocess, 146.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageq.jpeg: XXXXX
#
# 0: 800x608 (no detections), 169.8ms
# Speed: 2.2ms preprocess, 169.8ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 180.8ms
# Speed: 2.2ms preprocess, 180.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageq-2-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 175.1ms
# Speed: 3.0ms preprocess, 175.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 4 wallss, 150.7ms
# Speed: 1.6ms preprocess, 150.7ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageQ.jpeg: 305.1661376953125
#
# 0: 800x608 1 Box-Propeller, 175.0ms
# Speed: 2.7ms preprocess, 175.0ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 round-propeller, 186.5ms
# Speed: 3.1ms preprocess, 186.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageQ-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 175.0ms
# Speed: 3.3ms preprocess, 175.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 7 wallss, 153.2ms
# Speed: 2.3ms preprocess, 153.2ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageR.jpeg: 285.68414306640625
#
# 0: 800x608 1 Box-Propeller, 169.6ms
# Speed: 3.2ms preprocess, 169.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 round-propellers, 181.5ms
# Speed: 3.0ms preprocess, 181.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageR-1-0-0-0.jpg
#
# 0: 608x800 (no detections), 175.5ms
# Speed: 2.1ms preprocess, 175.5ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 480x640 2 ceilings, 6 floors, 4 wallss, 154.0ms
# Speed: 1.9ms preprocess, 154.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Ceiling Height for imager.jpg: XXXXX
#
# 0: 608x800 (no detections), 176.0ms
# Speed: 2.9ms preprocess, 176.0ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 169.9ms
# Speed: 3.2ms preprocess, 169.9ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 800)
# Processed Image saved at: Output_test_folder_combined/imager-2-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 207.9ms
# Speed: 2.6ms preprocess, 207.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 2 wallss, 152.9ms
# Speed: 1.7ms preprocess, 152.9ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageS.jpeg: 264.6062927246094
#
# 0: 800x608 2 Box-Propellers, 191.9ms
# Speed: 3.4ms preprocess, 191.9ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 11 round-propellers, 171.3ms
# Speed: 2.2ms preprocess, 171.3ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageS-1-42-8-225.jpg
# Box Propeller 1 -> Length: 30.44143295288086 cm, Width: 10.035636901855469 cm, Height: 232.15773010253906 cm
# Box Propeller 2 -> Length: 42.14967727661133 cm, Width: 8.028509140014648 cm, Height: 225.46731567382812 cm
#
# 0: 800x608 1 750ml coke, 167.6ms
# Speed: 2.4ms preprocess, 167.6ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 4 wallss, 146.0ms
# Speed: 1.5ms preprocess, 146.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageT.jpeg: 289.513427734375
#
# 0: 800x608 1 Box-Propeller, 171.6ms
# Speed: 2.5ms preprocess, 171.6ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 round-propellers, 172.3ms
# Speed: 3.4ms preprocess, 172.3ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageT-1-0-0-0.jpg
#
# 0: 576x800 (no detections), 168.2ms
# Speed: 2.3ms preprocess, 168.2ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 800)
#
# 0: 480x640 2 ceilings, 2 floors, 14 wallss, 154.3ms
# Speed: 2.0ms preprocess, 154.3ms inference, 12.4ms postprocess per image at shape (1, 3, 480, 640)
# Ceiling Height for imaget.jpg: XXXXX
#
# 0: 576x800 (no detections), 164.7ms
# Speed: 2.8ms preprocess, 164.7ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 800)
#
# 0: 576x800 1 round-propeller, 158.1ms
# Speed: 1.9ms preprocess, 158.1ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 800)
# Processed Image saved at: Output_test_folder_combined/imaget-2-0-0-0.jpg
# Round Propeller 1 -> Diameter: 0 cm, Circumference: 0 cm, Height: 0 cm
#
# 0: 800x608 1 750ml coke, 168.0ms
# Speed: 2.2ms preprocess, 168.0ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 floor, 4 wallss, 140.7ms
# Speed: 1.4ms preprocess, 140.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageU.jpeg: XXXXX
#
# 0: 800x608 1 Box-Propeller, 169.7ms
# Speed: 2.9ms preprocess, 169.7ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 round-propellers, 182.8ms
# Speed: 3.1ms preprocess, 182.8ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageU-1-57-11-246.jpg
# Box Propeller 1 -> Length: 57.70199966430664 cm, Width: 11.334321022033691 cm, Height: 246.95082092285156 cm
#
# 0: 800x608 1 750ml coke, 173.8ms
# Speed: 3.6ms preprocess, 173.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 4 floors, 8 wallss, 144.8ms
# Speed: 1.3ms preprocess, 144.8ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageV.jpeg: 273.50665283203125
#
# 0: 800x608 (no detections), 168.9ms
# Speed: 3.8ms preprocess, 168.9ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 11 round-propellers, 167.8ms
# Speed: 2.6ms preprocess, 167.8ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageV-1-0-0-0.jpg
#
# 0: 800x704 (no detections), 203.8ms
# Speed: 2.2ms preprocess, 203.8ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 704)
#
# 0: 640x576 3 wallss, 205.2ms
# Speed: 2.1ms preprocess, 205.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 576)
# Ceiling Height for imagev.jpg: XXXXX
#
# 0: 800x704 (no detections), 195.3ms
# Speed: 2.5ms preprocess, 195.3ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 704)
#
# 0: 800x704 (no detections), 197.4ms
# Speed: 3.3ms preprocess, 197.4ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 704)
# Processed Image saved at: Output_test_folder_combined/imagev-2-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 168.5ms
# Speed: 2.7ms preprocess, 168.5ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 9 wallss, 154.0ms
# Speed: 1.3ms preprocess, 154.0ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageW.jpeg: 323.05523681640625
#
# 0: 800x608 (no detections), 193.0ms
# Speed: 3.8ms preprocess, 193.0ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 round-propeller, 182.9ms
# Speed: 2.6ms preprocess, 182.9ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageW-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 210.1ms
# Speed: 2.9ms preprocess, 210.1ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 3 wallss, 176.7ms
# Speed: 1.8ms preprocess, 176.7ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageX.jpeg: 272.6295166015625
#
# 0: 800x608 2 Box-Propellers, 188.7ms
# Speed: 3.0ms preprocess, 188.7ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 round-propeller, 196.5ms
# Speed: 2.7ms preprocess, 196.5ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageX-1-17-30-249.jpg
# Box Propeller 1 -> Length: 25.19234848022461 cm, Width: 15.184429168701172 cm, Height: 219.82913208007812 cm
# Box Propeller 2 -> Length: 17.945234298706055 cm, Width: 30.713960647583008 cm, Height: 249.50778198242188 cm
#
# 0: 800x608 (no detections), 191.2ms
# Speed: 2.3ms preprocess, 191.2ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 161.5ms
# Speed: 2.5ms preprocess, 161.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imagex.jpeg: XXXXX
#
# 0: 800x608 1 Box-Propeller, 192.0ms
# Speed: 2.3ms preprocess, 192.0ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 (no detections), 188.7ms
# Speed: 2.0ms preprocess, 188.7ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imagex-2-0-0-0.jpg
#
# 0: 800x608 2 750ml cokes, 182.5ms
# Speed: 4.0ms preprocess, 182.5ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 floors, 4 wallss, 166.5ms
# Speed: 1.8ms preprocess, 166.5ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageY.jpeg: XXXXX
#
# 0: 800x608 1 Box-Propeller, 192.8ms
# Speed: 3.9ms preprocess, 192.8ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 round-propellers, 192.6ms
# Speed: 3.5ms preprocess, 192.6ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageY-1-26-20-258.jpg
# Box Propeller 1 -> Length: 26.44621467590332 cm, Width: 20.963462829589844 cm, Height: 258.9794006347656 cm
#
# 0: 608x800 (no detections), 190.0ms
# Speed: 2.5ms preprocess, 190.0ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 480x640 3 ceilings, 1 floor, 5 wallss, 156.5ms
# Speed: 1.6ms preprocess, 156.5ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
# Ceiling Height for imagey.jpg: XXXXX
#
# 0: 608x800 (no detections), 193.4ms
# Speed: 2.9ms preprocess, 193.4ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 11 round-propellers, 187.8ms
# Speed: 3.3ms preprocess, 187.8ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
# Processed Image saved at: Output_test_folder_combined/imagey-2-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 201.5ms
# Speed: 4.3ms preprocess, 201.5ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 5 wallss, 181.4ms
# Speed: 2.0ms preprocess, 181.4ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for imageZ.jpeg: 274.9057312011719
#
# 0: 800x608 (no detections), 189.6ms
# Speed: 3.9ms preprocess, 189.6ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 4 round-propellers, 191.1ms
# Speed: 2.6ms preprocess, 191.1ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Processed Image saved at: Output_test_folder_combined/imageZ-1-0-0-0.jpg
#
# Final Results:
# Photo 1 | ID imageA-1-0-0-0.jpg | Ceiling height 307.63cm | AC Height YYYY
# Photo 2 | ID imagea-2-0-0-0.jpg | Ceiling height XXXXXcm | AC Height YYYY
# Photo 3 | ID imageAA-1-0-0-0.jpg | Ceiling height 294.55cm | AC Height YYYY
# Photo 4 | ID imageAB-1-35-10-232.jpg | Ceiling height 301.83cm | AC Height P1: 221.12 cm, P2: 221.74 cm, P3: 232.87 cm
# Photo 5 | ID imageAC-1-70-17-259.jpg | Ceiling height 315.21cm | AC Height P1: 259.93 cm
# Photo 6 | ID imageAD-1-55-14-244.jpg | Ceiling height 321.85cm | AC Height P1: 244.62 cm
# Photo 7 | ID imageAE-1-63-18-297.jpg | Ceiling height 249.33cm | AC Height P1: 188.86 cm, P2: 264.87 cm, P3: 297.30 cm
# Photo 8 | ID imageAF-1-39-11-239.jpg | Ceiling height 245.54cm | AC Height P1: 239.71 cm
# Photo 9 | ID imageAG-1-38-38-225.jpg | Ceiling height 290.07cm | AC Height P1: 285.50 cm, P2: 225.72 cm
# Photo 10 | ID imageAH-1-87-20-288.jpg | Ceiling height XXXXXcm | AC Height P1: 288.14 cm
# Photo 11 | ID imageAI-1-0-0-0.jpg | Ceiling height 343.8cm | AC Height YYYY
# Photo 12 | ID imageAJ-1-49-23-304.jpg | Ceiling height 252.31cm | AC Height P1: 196.88 cm, P2: 240.71 cm, P3: 310.63 cm, P4: 304.83 cm
# Photo 13 | ID imageAK-1-193-193-221.jpg | Ceiling height 338.03cm | AC Height P1: 283.88 cm, P2: 261.45 cm, P3: 221.72 cm
# Photo 14 | ID imageAL-1-0-0-0.jpg | Ceiling height 294.54cm | AC Height YYYY
# Photo 15 | ID imageAM-1-0-0-0.jpg | Ceiling height 344.35cm | AC Height YYYY
# Photo 16 | ID imageAN-1-99-99-209.jpg | Ceiling height 361.76cm | AC Height P1: 209.12 cm
# Photo 17 | ID imageAO-1-46-46-190.jpg | Ceiling height 267.81cm | AC Height P1: 198.79 cm, P2: 190.49 cm
# Photo 18 | ID imageAP-1-0-0-0.jpg | Ceiling height 326.2cm | AC Height YYYY
# Photo 19 | ID imageAQ-1-0-0-0.jpg | Ceiling height 314.78cm | AC Height YYYY
# Photo 20 | ID imageAR-1-0-0-0.jpg | Ceiling height 328.73cm | AC Height YYYY
# Photo 21 | ID imageAS-1-25-17-259.jpg | Ceiling height 313.2cm | AC Height P1: 259.99 cm
# Photo 22 | ID imageAT-1-0-0-0.jpg | Ceiling height 262.62cm | AC Height YYYY
# Photo 23 | ID imageAU-1-0-0-0.jpg | Ceiling height 309.03cm | AC Height YYYY
# Photo 24 | ID imageAV-1-0-0-0.jpg | Ceiling height 330.6cm | AC Height YYYY
# Photo 25 | ID imageAW-1-0-0-0.jpg | Ceiling height 278.74cm | AC Height YYYY
# Photo 26 | ID imageAX-1-36-36-171.jpg | Ceiling height 251.77cm | AC Height P1: 171.46 cm
# Photo 27 | ID imageAY-1-39-10-231.jpg | Ceiling height 337.99cm | AC Height P1: 231.36 cm
# Photo 28 | ID imageAZ-1-13-10-150.jpg | Ceiling height 201.95cm | AC Height P1: 156.11 cm, P2: 150.84 cm
# Photo 29 | ID imageB-1-0-0-0.jpg | Ceiling height XXXXXcm | AC Height YYYY
# Photo 30 | ID imageb-2-0-0-0.jpg | Ceiling height XXXXXcm | AC Height P1: 0.00 cm
# Photo 31 | ID imageBA-1-17-8-210.jpg | Ceiling height 257.33cm | AC Height P1: 229.08 cm, P2: 210.54 cm
# Photo 32 | ID imageBB-1-33-6-175.jpg | Ceiling height XXXXXcm | AC Height P1: 175.31 cm
# Photo 33 | ID imageBC-2-0-0-0.jpg | Ceiling height XXXXXcm | AC Height YYYY
# Photo 34 | ID imageC-1-70-70-172.jpg | Ceiling height 304.52cm | AC Height P1: 178.82 cm, P2: 177.83 cm, P3: 172.88 cm
# Photo 35 | ID imagec-1-11-11-4.jpg | Ceiling height XXXXXcm | AC Height P1: 4.68 cm
# Photo 36 | ID imageD-1-148-148-221.jpg | Ceiling height 328.19cm | AC Height P1: 221.54 cm
# Photo 37 | ID imaged-2-0-0-0.jpg | Ceiling height XXXXXcm | AC Height YYYY
# Photo 38 | ID imageE-1-99-99-206.jpg | Ceiling height 368.68cm | AC Height P1: 268.74 cm, P2: 293.81 cm, P3: 206.23 cm
# Photo 39 | ID imageF-1-234-234-264.jpg | Ceiling height 351.96cm | AC Height P1: 264.63 cm
# Photo 40 | ID imageG-1-57-57-169.jpg | Ceiling height 321.48cm | AC Height P1: 169.25 cm
# Photo 41 | ID imageH-1-69-69-180.jpg | Ceiling height XXXXXcm | AC Height P1: 300.58 cm, P2: 180.27 cm
# Photo 42 | ID imageI-1-54-54-157.jpg | Ceiling height 298.92cm | AC Height P1: 195.42 cm, P2: 157.17 cm
# Photo 43 | ID imageJ-1-68-68-239.jpg | Ceiling height 379.23cm | AC Height P1: 258.73 cm, P2: 253.66 cm, P3: 208.79 cm, P4: 214.58 cm, P5: 239.91 cm
# Photo 44 | ID imageK-1-95-95-187.jpg | Ceiling height 314.87cm | AC Height P1: 195.40 cm, P2: 187.70 cm
# Photo 45 | ID imageL-1-0-0-0.jpg | Ceiling height XXXXXcm | AC Height YYYY
# Photo 46 | ID imageM-1-16-7-151.jpg | Ceiling height XXXXXcm | AC Height P1: 151.58 cm
# Photo 47 | ID imageN-1-17-9-248.jpg | Ceiling height 299.76cm | AC Height P1: 265.31 cm, P2: 248.61 cm
# Photo 48 | ID imageO-1-0-0-0.jpg | Ceiling height 300.99cm | AC Height YYYY
# Photo 49 | ID imageP-1-0-0-0.jpg | Ceiling height 322.66cm | AC Height YYYY
# Photo 50 | ID imageq-2-0-0-0.jpg | Ceiling height XXXXXcm | AC Height YYYY
# Photo 51 | ID imageQ-1-0-0-0.jpg | Ceiling height 305.17cm | AC Height YYYY
# Photo 52 | ID imageR-1-0-0-0.jpg | Ceiling height 285.68cm | AC Height YYYY
# Photo 53 | ID imager-2-0-0-0.jpg | Ceiling height XXXXXcm | AC Height YYYY
# Photo 54 | ID imageS-1-42-8-225.jpg | Ceiling height 264.61cm | AC Height P1: 232.16 cm, P2: 225.47 cm
# Photo 55 | ID imageT-1-0-0-0.jpg | Ceiling height 289.51cm | AC Height YYYY
# Photo 56 | ID imaget-2-0-0-0.jpg | Ceiling height XXXXXcm | AC Height P1: 0.00 cm
# Photo 57 | ID imageU-1-57-11-246.jpg | Ceiling height XXXXXcm | AC Height P1: 246.95 cm
# Photo 58 | ID imageV-1-0-0-0.jpg | Ceiling height 273.51cm | AC Height YYYY
# Photo 59 | ID imagev-2-0-0-0.jpg | Ceiling height XXXXXcm | AC Height YYYY
# Photo 60 | ID imageW-1-0-0-0.jpg | Ceiling height 323.06cm | AC Height YYYY
# Photo 61 | ID imageX-1-17-30-249.jpg | Ceiling height 272.63cm | AC Height P1: 219.83 cm, P2: 249.51 cm
# Photo 62 | ID imagex-2-0-0-0.jpg | Ceiling height XXXXXcm | AC Height YYYY
# Photo 63 | ID imageY-1-26-20-258.jpg | Ceiling height XXXXXcm | AC Height P1: 258.98 cm
# Photo 64 | ID imagey-2-0-0-0.jpg | Ceiling height XXXXXcm | AC Height YYYY
# Photo 65 | ID imageZ-1-0-0-0.jpg | Ceiling height 274.91cm | AC Height YYYY
# Results saved to Output_test_folder_combined/detect_results.txt

# %%
import os

output_folder = "Output_test_folder_combined"
results_txt = os.path.join(output_folder, "results.txt")

# Prepare groups
only_coke = []    # Only Coca-Cola bottle detection: coca_flag == "1" and measurements are 0-0-0
round_prop = []   # Coca-Cola bottle + round propeller: coca_flag == "1" and m1==m2 != 0
box_prop = []     # Coca-Cola bottle + box propeller: coca_flag == "1" and m1 != m2
unknown = []      # Unknown detection: coca_flag == "2"

# Iterate over files in the output folder
for filename in os.listdir(output_folder):
    if not filename.lower().endswith((".jpg", ".jpeg", ".png")):
        continue

    base = os.path.splitext(filename)[0]
    parts = base.split('-')
    
    # Expecting format: <imageName>-<coca_flag>-<m1>-<m2>-<m3>
    if len(parts) < 5:
        continue

    image_id = parts[0]      # e.g., imageA
    coca_flag = parts[1]     # "1" for detected coke, "2" for unknown
    try:
        m1 = int(parts[2])
        m2 = int(parts[3])
        m3 = int(parts[4])
    except ValueError:
        continue

    # Group the file based on the coca_flag and measurement values.
    if coca_flag == "1":
        if m1 == 0 and m2 == 0 and m3 == 0:
            only_coke.append(f"{image_id} {coca_flag}-{m1}-{m2}-{m3}")
        elif m1 == m2 and m1 != 0:
            round_prop.append(f"{image_id} {coca_flag}-{m1}-{m2}-{m3}")
        elif m1 != m2:
            box_prop.append(f"{image_id} {coca_flag}-{m1}-{m2}-{m3}")
    elif coca_flag == "2":
        unknown.append(f"{image_id} {coca_flag}-{m1}-{m2}-{m3}")

# Write the results into a text file with separate sections.
with open(results_txt, "w") as f:
    f.write("For only Coca-Cola bottle detection:\n")
    for line in only_coke:
        f.write(line + "\n")
    
    f.write("\nFor Coca-Cola bottle + round propeller:\n")
    for line in round_prop:
        f.write(line + "\n")
    
    f.write("\nFor Coca-Cola bottle + box propeller:\n")
    for line in box_prop:
        f.write(line + "\n")

    f.write("\nFor unknown detection (no valid coke bottle):\n")
    for line in unknown:
        f.write(line + "\n")

print(f"Results saved to {results_txt}")
# Out:
# Results saved to Output_test_folder_combined/results.txt
