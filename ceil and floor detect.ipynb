# %%
'''from ultralytics import YOLO
import cv2
import torch

# Load the trained YOLOv8 model
model = YOLO('best (5).pt')

# Load the image
image_path = 'Dataset/WhatsApp Image 2025-02-18 at 10.13.01.jpeg'
image = cv2.imread(image_path)

# Perform inference
results = model(image)

# Process results
for result in results:
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates
        confidence = box.conf[0].item()  # Confidence score
        class_id = int(box.cls[0].item())  # Class ID

        # Draw bounding box and label on image
        label = f'{model.names[class_id]}: {confidence:.2f}'
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Save or display the image
cv2.imwrite('output.jpeg', image)
cv2.imshow('Detection', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
'''
# Out:
# "from ultralytics import YOLO\nimport cv2\nimport torch\n\n# Load the trained YOLOv8 model\nmodel = YOLO('best (5).pt')\n\n# Load the image\nimage_path = 'Dataset/WhatsApp Image 2025-02-18 at 10.13.01.jpeg'\nimage = cv2.imread(image_path)\n\n# Perform inference\nresults = model(image)\n\n# Process results\nfor result in results:\n    for box in result.boxes:\n        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates\n        confidence = box.conf[0].item()  # Confidence score\n        class_id = int(box.cls[0].item())  # Class ID\n\n        # Draw bounding box and label on image\n        label = f'{model.names[class_id]}: {confidence:.2f}'\n        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)\n        cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)\n\n# Save or display the image\ncv2.imwrite('output.jpeg', image)\ncv2.imshow('Detection', image)\ncv2.waitKey(0)\ncv2.destroyAllWindows()\n"

# %%
'''from ultralytics import YOLO
import cv2
import torch

# Load the trained YOLOv8 model
model = YOLO('best (5).pt')

# Define allowed classes
allowed_classes = {"ceiling", "floor"}  # Only detect ceilings and floors

# Load the image
image_path = 'Dataset/WhatsApp Image 2025-02-18 at 10.13.17 (2).jpeg'
image = cv2.imread(image_path)

# Check if image is loaded correctly
if image is None:
    print("Error: Could not read the image. Check the path.")
    exit()

# Perform inference
results = model(image)

# Process results
for result in results:
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coordinates
        confidence = float(box.conf[0].cpu().numpy())  # Confidence score
        class_id = int(box.cls[0].cpu().numpy())  # Class ID
        
        # Get class name correctly
        class_name = result.names[class_id]

        # Filter only "ceiling" and "floor"
        if class_name in allowed_classes:
            # Draw bounding box and label on image
            label = f'{class_name}: {confidence:.2f}'
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Save or display the image
cv2.imwrite('output.jpeg', image)
cv2.imshow('Detection', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
'''
# Out:
# 'from ultralytics import YOLO\nimport cv2\nimport torch\n\n# Load the trained YOLOv8 model\nmodel = YOLO(\'best (5).pt\')\n\n# Define allowed classes\nallowed_classes = {"ceiling", "floor"}  # Only detect ceilings and floors\n\n# Load the image\nimage_path = \'Dataset/WhatsApp Image 2025-02-18 at 10.13.17 (2).jpeg\'\nimage = cv2.imread(image_path)\n\n# Check if image is loaded correctly\nif image is None:\n    print("Error: Could not read the image. Check the path.")\n    exit()\n\n# Perform inference\nresults = model(image)\n\n# Process results\nfor result in results:\n    for box in result.boxes:\n        x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coordinates\n        confidence = float(box.conf[0].cpu().numpy())  # Confidence score\n        class_id = int(box.cls[0].cpu().numpy())  # Class ID\n        \n        # Get class name correctly\n        class_name = result.names[class_id]\n\n        # Filter only "ceiling" and "floor"\n        if class_name in a
# ...

# %%
'''from ultralytics import YOLO
import cv2
import torch

# Load the trained YOLOv8 model
model = YOLO('best (5).pt')

# Define allowed classes
allowed_classes = {"ceiling", "floor"}  # Only detect ceilings and floors

# Load the image
image_path = 'New dataset/IMG_3081.JPEG'
image = cv2.imread(image_path)

# Check if the image is loaded correctly
if image is None:
    print("Error: Could not read the image. Check the path.")
    exit()

# Perform inference
results = model(image)

# Process results
for result in results:
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coordinates
        confidence = float(box.conf[0].cpu().numpy())  # Confidence score
        class_id = int(box.cls[0].cpu().numpy())  # Class ID
        
        # Get class name correctly
        class_name = model.names.get(class_id, "Unknown")  # Ensure we get the correct class label

        # Filter only "ceiling" and "floor"
        if class_name in allowed_classes:
            # Draw bounding box and label on image
            label = f'{class_name}: {confidence:.2f}'
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Save or display the image
cv2.imwrite('output.jpeg', image)
cv2.imshow('Detection', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
'''
# Out:
# 'from ultralytics import YOLO\nimport cv2\nimport torch\n\n# Load the trained YOLOv8 model\nmodel = YOLO(\'best (5).pt\')\n\n# Define allowed classes\nallowed_classes = {"ceiling", "floor"}  # Only detect ceilings and floors\n\n# Load the image\nimage_path = \'New dataset/IMG_3081.JPEG\'\nimage = cv2.imread(image_path)\n\n# Check if the image is loaded correctly\nif image is None:\n    print("Error: Could not read the image. Check the path.")\n    exit()\n\n# Perform inference\nresults = model(image)\n\n# Process results\nfor result in results:\n    for box in result.boxes:\n        x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coordinates\n        confidence = float(box.conf[0].cpu().numpy())  # Confidence score\n        class_id = int(box.cls[0].cpu().numpy())  # Class ID\n        \n        # Get class name correctly\n        class_name = model.names.get(class_id, "Unknown")  # Ensure we get the correct class label\n\n        # Filter only "ceiling" and "floo
# ...

# %%
'''import os
import cv2
import torch
from ultralytics import YOLO

# Load the trained YOLOv8 model
model = YOLO('best (5).pt')

# Define allowed classes
allowed_classes = {"ceiling", "floor"}  # Only detect ceilings and floors

# Define input and output folders
input_folder = "Test_images"  # Folder containing images
output_folder = "Test_ceil_floor"  # Folder to save results

# Create output directory if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Process all images in the input folder
for filename in os.listdir(input_folder):
    if filename.lower().endswith((".jpg", ".jpeg", ".png")):  # Process only image files
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path)

        # Check if the image is loaded correctly
        if image is None:
            print(f"Error: Could not read {filename}. Skipping.")
            continue

        # Perform inference
        results = model(image)

        # Process results
        for result in results:
            for box in result.boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coordinates
                confidence = float(box.conf[0].cpu().numpy())  # Confidence score
                class_id = int(box.cls[0].cpu().numpy())  # Class ID
                
                # Get class name correctly
                class_name = model.names.get(class_id, "Unknown")  # Ensure we get the correct class label

                # Filter only "ceiling" and "floor"
                if class_name in allowed_classes:
                    # Draw bounding box and label on image
                    label = f'{class_name}: {confidence:.2f}'
                    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        # Save the output image
        output_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_path, image)

print("Processing complete. Check 'detect_ceil_floor' folder for results.")
'''
# Out:
# 'import os\nimport cv2\nimport torch\nfrom ultralytics import YOLO\n\n# Load the trained YOLOv8 model\nmodel = YOLO(\'best (5).pt\')\n\n# Define allowed classes\nallowed_classes = {"ceiling", "floor"}  # Only detect ceilings and floors\n\n# Define input and output folders\ninput_folder = "Test_images"  # Folder containing images\noutput_folder = "Test_ceil_floor"  # Folder to save results\n\n# Create output directory if it doesn\'t exist\nos.makedirs(output_folder, exist_ok=True)\n\n# Process all images in the input folder\nfor filename in os.listdir(input_folder):\n    if filename.lower().endswith((".jpg", ".jpeg", ".png")):  # Process only image files\n        image_path = os.path.join(input_folder, filename)\n        image = cv2.imread(image_path)\n\n        # Check if the image is loaded correctly\n        if image is None:\n            print(f"Error: Could not read {filename}. Skipping.")\n            continue\n\n        # Perform inference\n        results = model(image)\n\n   
# ...

# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
# ...

# %%
import os
import cv2
import torch
from ultralytics import YOLO

# Load the trained YOLOv8 model
model = YOLO("best (5).pt")

# model = YOLO("best_10.pt")

# Define allowed classes
allowed_classes = {"ceiling", "floor"}  # Only detect ceilings and floors

# Define input and output folders
input_folder = "Input_test_folder(3m approx)"  # Folder containing images
output_folder = "OUTPUT2"  # Folder to save results

# Create output directory if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Process all images in the input folder
for filename in os.listdir(input_folder):
    if filename.lower().endswith((".jpg", ".jpeg", ".png")):  # Process only image files
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path)

        # Check if the image is loaded correctly
        if image is None:
            print(f"Error: Could not read {filename}. Skipping.")
            continue

        # Perform inference
        results = model(image)

        # Store the best detection for ceiling and floor
        best_ceiling = None
        best_floor = None

        # Process results
        for result in results:
            for box in result.boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coordinates
                confidence = float(box.conf[0].cpu().numpy())  # Confidence score
                class_id = int(box.cls[0].cpu().numpy())  # Class ID
                
                # Get class name correctly
                class_name = model.names.get(class_id, "Unknown")  # Ensure we get the correct class label

                # Store the most confident "ceiling" and "floor" detection
                if class_name == "ceiling":
                    if best_ceiling is None or confidence > best_ceiling[1]:
                        best_ceiling = ((x1, y1, x2, y2), confidence, class_name)

                if class_name == "floor":
                    if best_floor is None or confidence > best_floor[1]:
                        best_floor = ((x1, y1, x2, y2), confidence, class_name)

        # Draw only the best detections on the image
        for best in [best_ceiling, best_floor]:
            if best is not None:
                (x1, y1, x2, y2), confidence, class_name = best
                label = f'{class_name}: {confidence:.2f}'
                cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        # Save the output image
        output_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_path, image)

print("Processing complete. Check 'Test_ceil_floor' folder for results.")
# Out:
# 0: 640x480 1 ceiling, 1 floor, 2 wallss, 42.8ms
# Speed: 2.4ms preprocess, 42.8ms inference, 358.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 ceilings, 2 floors, 8 wallss, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 4 ceilings, 2 floors, 4 wallss, 6.1ms
# Speed: 1.3ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 ceilings, 2 floors, 6 wallss, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ceiling, 2 floors, 1 walls, 6.1ms
# Speed: 1.3ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 ceiling, 3 floors, 5 wallss, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 ceilings, 3 floors, 4 wallss, 6.2ms
# ...
