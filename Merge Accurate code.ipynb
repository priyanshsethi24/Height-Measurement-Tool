# %%
import cv2
import torch
from ultralytics import YOLO
# Out:
# C:\Users\Priyansh Sethi\anaconda3\anaconda_3\Lib\site-packages\torch\utils\_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(

# %%
def natural_sort_key(filename):
    """Extract numerical values from filenames for correct sorting."""
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', filename)]

# %%
def detect_objects(model, image_path):
    image = cv2.imread(image_path)
    results = model(image)  # Perform object detection
    return results, image

# %%
def get_ceiling_floor_coordinates(results, floor_model):
    ceiling_y = None  # Initialize
    floor_y = None  # Initialize
    best_ceiling = None
    best_floor = None

    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coords
            confidence = float(box.conf[0].cpu().numpy())  # Confidence score
            class_id = int(box.cls[0].cpu().numpy())  # Class ID
            
            class_name = floor_model.names.get(class_id, "Unknown")

            if class_name == "ceiling":
                if best_ceiling is None or confidence > best_ceiling[1]:
                    best_ceiling = ((x1, y1, x2, y2), confidence)

            if class_name == "floor":
                if best_floor is None or confidence > best_floor[1]:
                    best_floor = ((x1, y1, x2, y2), confidence)

    ceiling_mid, floor_mid = None, None  

    if best_ceiling:
        (_, ceiling_y1, _, ceiling_y2), _ = best_ceiling
        ceiling_y = (ceiling_y1 + ceiling_y2)// 2  # Midpoint

    if best_floor:
        (_, floor_y1, _, floor_y2), _ = best_floor
        floor_y = (floor_y1 + floor_y2)// 2  # Midpoint

    return ceiling_y, floor_y

# %%
def get_floor_coordinates(results):
    """Extract the top Y-coordinate and bounding box of the floor"""
    floor_y_top = None
    floor_box = None
    
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls.cpu().numpy().item())  # Get class ID
            x_min, y_min, x_max, y_max = map(int, box.xyxy[0])  # Bounding box
            
            if class_id == 1:  # Assuming class 1 is "floor"
                floor_y_top = y_min  # Top Y-coordinate of floor
                floor_box = (x_min, y_min, x_max, y_max)
    
    return floor_y_top, floor_box

# %%
def get_propeller_coordinates(results):
    """Extract the bottom Y-coordinates and bounding boxes of propellers"""
    propeller_boxes = []  # Store bounding boxes of detected propellers
    propeller_y_bottoms = []  # Store Y-bottom of propellers
    
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls.cpu().numpy().item())  # Get class ID
            x_min, y_min, x_max, y_max = map(int, box.xyxy[0])  # Bounding box
            
            if class_id == 0:  # Assuming class 0 is "propeller"
                propeller_y_bottoms.append(y_max)  # Store bottom Y-coordinate
                propeller_boxes.append((x_min, y_min, x_max, y_max))
    
    return propeller_y_bottoms, propeller_boxes

# %%
def detect_height_bottle(image_path, model):
    """Detect Coca-Cola bottles and return their bounding box height in pixels."""
    image = cv2.imread(image_path)
    results = model(image)
    coke_boxes = []
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Bounding box coordinates
            height_pixels = y2 - y1  # Bottle height in pixels
            real_height_cm = 26.3  # Known height of Coca-Cola bottle
            coke_boxes.append((x1, y1, x2, y2))
            pixel_to_cm_ratio = real_height_cm / height_pixels
            estimated_real_height = height_pixels * pixel_to_cm_ratio
            
            return height_pixels, estimated_real_height
    

    return None, None  # If no bottle is detected

# %%
def calculate_height(ceiling_y, floor_y, calibration_obj):
    """Calculate ceiling height using a calibration object (Coca-Cola bottle)."""
    if ceiling_y is None or floor_y is None:
        print("Error: Ceiling or Floor not detected!")
        return None  # Avoid TypeError

    pixel_height = floor_y - ceiling_y

    if calibration_obj:
        real_height, obj_pixel_height = calibration_obj
        pixel_to_cm_ratio = real_height / obj_pixel_height
        return pixel_height * pixel_to_cm_ratio
    
    return pixel_height  # Return pixel height if no calibration object

# %%
def draw_detections(image, propeller_boxes, floor_box, calibration_obj, floor_results):
    best_ceiling = None
    best_floor = None  # Ensure variables are initialized
    for i, (x1, y1, x2, y2) in enumerate(propeller_boxes):  # Unpacking tuple directly
        x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])  # Ensure integer values
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)     
        # Calculate height from floor to propeller
        pixel_height = y1 - floor_box[1]
        real_height = calculate_height(y1, floor_box[1], calibration_obj)
        height_text = f"Height: {real_height:.2f} cm"
        # Draw text label
        cv2.putText(image, height_text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    # Label the calibration object
    if calibration_obj:
        real_height, obj_pixel_height = calibration_obj
        cal_text = f"Calibration: {real_height:.2f} cm ({obj_pixel_height} px)"
        cv2.putText(image, cal_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)
    # Process results
    for result in floor_results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coordinates
            confidence = float(box.conf[0].cpu().numpy())  # Confidence score
            class_id = int(box.cls[0].cpu().numpy())  # Class ID

            # Get class name correctly
            class_name = floor_model.names.get(class_id, "Unknown")  # Ensure we get the correct class label

            # Store the most confident "ceiling" and "floor" detection
            if class_name == "ceiling":
                if best_ceiling is None or confidence > best_ceiling[1]:
                    best_ceiling = ((x1, y1, x2, y2), confidence, class_name)

            if class_name == "floor":
                if best_floor is None or confidence > best_floor[1]:
                    best_floor = ((x1, y1, x2, y2), confidence, class_name)
    # Draw only the best detections on the image
    for best in [best_ceiling, best_floor]:
        if best is not None:  # Ensure best_ceiling and best_floor are not None
            (x1, y1, x2, y2), confidence, class_name = best
            label = f'{class_name}: {confidence:.2f}'
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    return image

# %%
def draw_annotations(image, coke_boxes, ceiling_y, floor_y, pixel_to_cm_ratio=None):
    """Draws bounding boxes, vertical line, and labels on the image."""
    annotated_image = image.copy()
    
    # Draw Coca-Cola bounding boxes
    for (x1, y1, x2, y2, height_pixels) in coke_boxes:
        cv2.rectangle(annotated_image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green box
        cv2.putText(annotated_image, f"{height_pixels}px", (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Draw vertical line from floor to ceiling
    if ceiling_y is not None and floor_y is not None:
        mid_x = image.shape[1] // 2  # Center x-coordinate
        cv2.line(annotated_image, (mid_x, ceiling_y), (mid_x, floor_y), (0, 0, 255), 2)  # Red line
        
        # Calculate real-world ceiling height if calibration object exists
        pixel_height = floor_y - ceiling_y
        if pixel_to_cm_ratio:
            real_ceiling_height = pixel_height * pixel_to_cm_ratio
            height_text = f"Height: {real_ceiling_height:.2f} cm"
        else:
            height_text = f"Height: {pixel_height} pixels"

        # Add text label
        cv2.putText(annotated_image, height_text, (mid_x + 10, (ceiling_y + floor_y) // 2),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    return annotated_image

# %%
import os
import re
import cv2
import numpy as np

def natural_sort_key(filename):
    """Extract numerical values from filenames for correct sorting."""
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', filename)]

# Define folders
image_folder = "Input_test_folder(3m approx)"
output_folder = "Output_test_folder_combined1"
propeller_output_folder = "Output_test_folder_propeller_only2"

os.makedirs(output_folder, exist_ok=True)
os.makedirs(propeller_output_folder, exist_ok=True)

# Load models
coke_model = YOLO("best (8).pt")
floor_model = YOLO("best (5).pt")
propeller_model = YOLO("best (9).pt")

ceil_heights = {}  # Store detected ceiling heights
Propeller_heights = {}
image_results = []

# Get and sort image filenames
image_files = sorted(
    [f for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))],
    key=natural_sort_key
)
i = 0
for image_name in image_files:
    image_path = os.path.join(image_folder, image_name)
    # Detect Coca-Cola bottle height (for calibration)
    height_pixels, estimated_real_height = detect_height_bottle(image_path, coke_model)
    calibration_obj = (estimated_real_height, height_pixels) if height_pixels else None
    # Detect ceiling and floor
    floor_results, image = detect_objects(floor_model, image_path)
    # Perform inference
    ceiling_y, floor_y = get_ceiling_floor_coordinates(floor_results,floor_model)
    if ceiling_y is None or floor_y is None:
        ceiling_height = "XXXXX"
    elif calibration_obj:
        ceiling_height = calculate_height(ceiling_y, floor_y, calibration_obj)
    else:
        ceiling_height = "XXXXX"
    
    print(f"Ceiling Height for {image_name}: {ceiling_height}")
    
    if ceiling_height != "XXXXX":
        ceil_heights[image_name] = ceiling_height
    # Read the image
    image = cv2.imread(image_path)
    # Detect propellers (AC)
    propeller_results, _ = detect_objects(propeller_model, image_path)
    propeller_y_bottoms, propeller_boxes = get_propeller_coordinates(propeller_results)
    propeller_heights_details = []
    propeller_heights_d = []
    if propeller_boxes and calibration_obj:
        for idx, propeller_y_bottom in enumerate(propeller_y_bottoms):
            real_height = calculate_height(propeller_y_bottom, floor_y, calibration_obj)
            propeller_heights_details.append(
                f"P{idx + 1}: {real_height:.2f} cm"
            )
            propeller_heights_d.append(real_height.item())
    if propeller_heights_d != []:
        Propeller_heights[image_name] = propeller_heights_d
    ac_height = ", ".join(propeller_heights_details) if propeller_heights_details else "YYYY"
    print(f"AC Height for {image_name}: {ac_height}")
    if ceiling_y is not None and floor_y is not None and ceiling_height != "XXXXX":
        mid_x = image.shape[1] // 2
        cv2.line(image, (mid_x, ceiling_y), (mid_x, floor_y), (0, 255, 0), 3)
        text_position = (mid_x + 10, (ceiling_y + floor_y) // 2)
        cv2.putText(image, f"{ceiling_height:.2f} cm", text_position, cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
    # Draw propeller detections
    if calibration_obj:
        for idx, (box, real_height) in enumerate(zip(propeller_boxes, propeller_heights_d)):
            x1, y1, x2, y2 = box
            label = f"P{idx + 1}: {real_height:.2f} cm"
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Draw bounding box
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)  # Draw correct label
    
        output_path = os.path.join(output_folder, image_name)
        cv2.imwrite(output_path, image)
        print(f"Output saved at: {output_path}")

        # If propellers are detected, save in a separate folder
        if propeller_boxes:
            propeller_output_path = os.path.join(propeller_output_folder, image_name)
            cv2.imwrite(propeller_output_path, image)
            print(f"Propeller Output saved at: {propeller_output_path}")
    image_results.append(f"Photo {i+1} | ID {image_name} | Ceiling height {ceiling_height} | AC Height {ac_height}")
    i += 1

# Print final results
print("\nFinal Results:")
for result in image_results:
    print(result)
# Out:
# 0: 800x608 1 750ml coke, 969.4ms
# Speed: 13.1ms preprocess, 969.4ms inference, 14.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 4 wallss, 793.5ms
# Speed: 14.0ms preprocess, 793.5ms inference, 29.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image1.jpeg: 311.1754455566406
#
# 0: 800x608 (no detections), 915.0ms
# Speed: 11.9ms preprocess, 915.0ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image1.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image1.jpeg
#
# 0: 800x608 1 750ml coke, 863.9ms
# Speed: 12.8ms preprocess, 863.9ms inference, 3.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 5 floors, 2 wallss, 767.1ms
# Speed: 8.9ms preprocess, 767.1ms inference, 12.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image2.jpeg: XXXXX
#
# 0: 800x608 (no detections), 905.3ms
# Speed: 9.3ms preprocess, 905.3ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image2.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image2.jpeg
#
# 0: 800x608 2 750ml cokes, 905.6ms
# Speed: 8.5ms preprocess, 905.6ms inference, 3.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 1 walls, 706.6ms
# Speed: 5.0ms preprocess, 706.6ms inference, 19.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image3.jpeg: 308.0299377441406
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 959.2ms
# Speed: 9.4ms preprocess, 959.2ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image3.jpeg: P1: 175.87 cm
# Output saved at: Output_test_folder_combined\image3.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image3.jpeg
#
# 0: 800x608 2 750ml cokes, 792.0ms
# Speed: 9.5ms preprocess, 792.0ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 2 wallss, 792.9ms
# Speed: 3.3ms preprocess, 792.9ms inference, 11.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image4.jpeg: 331.9803466796875
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 885.0ms
# Speed: 10.2ms preprocess, 885.0ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image4.jpeg: P1: 219.10 cm
# Output saved at: Output_test_folder_combined\image4.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image4.jpeg
#
# 0: 800x608 1 750ml coke, 824.2ms
# Speed: 8.2ms preprocess, 824.2ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 2 wallss, 763.1ms
# Speed: 4.1ms preprocess, 763.1ms inference, 10.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image5.jpeg: 372.9312438964844
#
# 0: 800x608 4 Propellers detection - v1 2025-02-20 11-43ams, 939.5ms
# Speed: 9.7ms preprocess, 939.5ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image5.jpeg: P1: 204.68 cm, P2: 269.34 cm, P3: 298.27 cm, P4: 253.62 cm
# Output saved at: Output_test_folder_combined\image5.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image5.jpeg
#
# 0: 800x608 1 750ml coke, 823.3ms
# Speed: 14.9ms preprocess, 823.3ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 5 wallss, 770.5ms
# Speed: 3.8ms preprocess, 770.5ms inference, 12.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image6.jpeg: 356.0187072753906
#
# 0: 800x608 (no detections), 906.4ms
# Speed: 11.8ms preprocess, 906.4ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image6.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image6.jpeg
#
# 0: 800x608 1 750ml coke, 815.4ms
# Speed: 11.2ms preprocess, 815.4ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 5 wallss, 758.8ms
# Speed: 3.8ms preprocess, 758.8ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image7.jpeg: 325.1845703125
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 870.9ms
# Speed: 8.5ms preprocess, 870.9ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image7.jpeg: P1: 207.72 cm, P2: 168.10 cm
# Output saved at: Output_test_folder_combined\image7.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image7.jpeg
#
# 0: 800x608 1 750ml coke, 865.9ms
# Speed: 11.8ms preprocess, 865.9ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 floors, 1 walls, 747.0ms
# Speed: 4.0ms preprocess, 747.0ms inference, 10.7ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image8.jpeg: XXXXX
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 783.0ms
# Speed: 8.9ms preprocess, 783.0ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image8.jpeg: P1: 303.25 cm
# Output saved at: Output_test_folder_combined\image8.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image8.jpeg
#
# 0: 800x608 2 750ml cokes, 851.6ms
# Speed: 9.3ms preprocess, 851.6ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 4 floors, 1 walls, 808.6ms
# Speed: 3.8ms preprocess, 808.6ms inference, 11.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image9.jpeg: 302.3682861328125
#
# 0: 800x608 3 Propellers detection - v1 2025-02-20 11-43ams, 882.8ms
# Speed: 9.4ms preprocess, 882.8ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image9.jpeg: P1: 195.73 cm, P2: 157.04 cm, P3: 212.31 cm
# Output saved at: Output_test_folder_combined\image9.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image9.jpeg
#
# 0: 800x608 1 750ml coke, 815.2ms
# Speed: 8.5ms preprocess, 815.2ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 2 wallss, 761.9ms
# Speed: 2.8ms preprocess, 761.9ms inference, 11.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image10.jpeg: 383.6058654785156
#
# 0: 800x608 5 Propellers detection - v1 2025-02-20 11-43ams, 806.6ms
# Speed: 10.1ms preprocess, 806.6ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image10.jpeg: P1: 259.89 cm, P2: 254.76 cm, P3: 236.09 cm, P4: 240.85 cm, P5: 225.84 cm
# Output saved at: Output_test_folder_combined\image10.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image10.jpeg
#
# 0: 800x608 1 750ml coke, 864.7ms
# Speed: 7.9ms preprocess, 864.7ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 3 wallss, 714.5ms
# Speed: 3.5ms preprocess, 714.5ms inference, 37.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image11.jpeg: 318.5067443847656
#
# 0: 800x608 4 Propellers detection - v1 2025-02-20 11-43ams, 805.3ms
# Speed: 10.3ms preprocess, 805.3ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image11.jpeg: P1: 190.67 cm, P2: 194.97 cm, P3: 194.43 cm, P4: 67.94 cm
# Output saved at: Output_test_folder_combined\image11.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image11.jpeg
#
# 0: 800x608 2 750ml cokes, 813.6ms
# Speed: 8.7ms preprocess, 813.6ms inference, 3.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 floor, 3 wallss, 746.0ms
# Speed: 3.1ms preprocess, 746.0ms inference, 12.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image12.jpeg: XXXXX
#
# 0: 800x608 (no detections), 822.1ms
# Speed: 9.5ms preprocess, 822.1ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image12.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image12.jpeg
#
# 0: 800x608 1 750ml coke, 823.7ms
# Speed: 10.4ms preprocess, 823.7ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 floors, 3 wallss, 724.1ms
# Speed: 3.5ms preprocess, 724.1ms inference, 16.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image13.jpeg: XXXXX
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 890.8ms
# Speed: 8.7ms preprocess, 890.8ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image13.jpeg: P1: 163.07 cm
# Output saved at: Output_test_folder_combined\image13.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image13.jpeg
#
# 0: 800x608 1 750ml coke, 902.9ms
# Speed: 9.5ms preprocess, 902.9ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 5 floors, 3 wallss, 738.0ms
# Speed: 3.4ms preprocess, 738.0ms inference, 13.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image14.jpeg: 303.2145690917969
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 811.1ms
# Speed: 8.1ms preprocess, 811.1ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image14.jpeg: P1: 265.49 cm
# Output saved at: Output_test_folder_combined\image14.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image14.jpeg
#
# 0: 800x608 2 750ml cokes, 793.3ms
# Speed: 7.2ms preprocess, 793.3ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 6 wallss, 689.1ms
# Speed: 4.9ms preprocess, 689.1ms inference, 12.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image15.jpeg: 304.4614562988281
#
# 0: 800x608 (no detections), 844.2ms
# Speed: 8.2ms preprocess, 844.2ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image15.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image15.jpeg
#
# 0: 800x608 2 750ml cokes, 871.8ms
# Speed: 9.5ms preprocess, 871.8ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 5 wallss, 661.3ms
# Speed: 3.9ms preprocess, 661.3ms inference, 21.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image16.jpeg: 326.3818664550781
#
# 0: 800x608 (no detections), 817.9ms
# Speed: 10.3ms preprocess, 817.9ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image16.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image16.jpeg
#
# 0: 800x608 1 750ml coke, 825.1ms
# Speed: 7.8ms preprocess, 825.1ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 4 wallss, 732.7ms
# Speed: 4.5ms preprocess, 732.7ms inference, 33.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image17.jpeg: 308.68731689453125
#
# 0: 800x608 (no detections), 805.4ms
# Speed: 10.7ms preprocess, 805.4ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image17.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image17.jpeg
#
# 0: 800x608 1 750ml coke, 799.9ms
# Speed: 9.8ms preprocess, 799.9ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 7 wallss, 738.7ms
# Speed: 3.3ms preprocess, 738.7ms inference, 21.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image18.jpeg: 288.9804992675781
#
# 0: 800x608 (no detections), 875.6ms
# Speed: 10.1ms preprocess, 875.6ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image18.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image18.jpeg
#
# 0: 800x608 1 750ml coke, 898.1ms
# Speed: 10.9ms preprocess, 898.1ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 2 wallss, 665.5ms
# Speed: 3.1ms preprocess, 665.5ms inference, 12.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image19.jpeg: 267.659423828125
#
# 0: 800x608 (no detections), 811.2ms
# Speed: 9.5ms preprocess, 811.2ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image19.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image19.jpeg
#
# 0: 800x608 1 750ml coke, 816.8ms
# Speed: 9.3ms preprocess, 816.8ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 4 wallss, 678.4ms
# Speed: 4.0ms preprocess, 678.4ms inference, 17.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image20.jpeg: 292.85394287109375
#
# 0: 800x608 (no detections), 819.1ms
# Speed: 8.2ms preprocess, 819.1ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image20.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image20.jpeg
#
# 0: 800x608 1 750ml coke, 823.1ms
# Speed: 9.4ms preprocess, 823.1ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 floor, 4 wallss, 672.0ms
# Speed: 3.7ms preprocess, 672.0ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image21.jpeg: XXXXX
#
# 0: 800x608 (no detections), 812.6ms
# Speed: 10.2ms preprocess, 812.6ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image21.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image21.jpeg
#
# 0: 800x608 1 750ml coke, 790.0ms
# Speed: 9.7ms preprocess, 790.0ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 4 floors, 8 wallss, 688.4ms
# Speed: 3.5ms preprocess, 688.4ms inference, 19.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image22.jpeg: 276.6624755859375
#
# 0: 800x608 (no detections), 802.2ms
# Speed: 9.8ms preprocess, 802.2ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image22.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image22.jpeg
#
# 0: 800x608 1 750ml coke, 815.6ms
# Speed: 12.3ms preprocess, 815.6ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 9 wallss, 760.9ms
# Speed: 3.7ms preprocess, 760.9ms inference, 37.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image23.jpeg: 326.78277587890625
#
# 0: 800x608 (no detections), 825.3ms
# Speed: 9.3ms preprocess, 825.3ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image23.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image23.jpeg
#
# 0: 800x608 1 750ml coke, 795.0ms
# Speed: 9.6ms preprocess, 795.0ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 3 wallss, 713.5ms
# Speed: 3.2ms preprocess, 713.5ms inference, 28.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image24.jpeg: 275.7752380371094
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 815.6ms
# Speed: 9.1ms preprocess, 815.6ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image24.jpeg: P1: 220.62 cm, P2: 249.59 cm
# Output saved at: Output_test_folder_combined\image24.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image24.jpeg
#
# 0: 800x608 2 750ml cokes, 839.4ms
# Speed: 9.1ms preprocess, 839.4ms inference, 3.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 floors, 4 wallss, 856.9ms
# Speed: 7.1ms preprocess, 856.9ms inference, 28.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image25.jpeg: XXXXX
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 867.6ms
# Speed: 9.0ms preprocess, 867.6ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image25.jpeg: P1: 259.68 cm
# Output saved at: Output_test_folder_combined\image25.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image25.jpeg
#
# 0: 800x608 1 750ml coke, 792.6ms
# Speed: 7.4ms preprocess, 792.6ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 5 wallss, 724.9ms
# Speed: 3.4ms preprocess, 724.9ms inference, 29.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image26.jpeg: 278.0777282714844
#
# 0: 800x608 (no detections), 882.2ms
# Speed: 9.3ms preprocess, 882.2ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image26.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image26.jpeg
#
# 0: 800x608 1 750ml coke, 896.9ms
# Speed: 9.0ms preprocess, 896.9ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 2 floors, 4 wallss, 664.3ms
# Speed: 3.7ms preprocess, 664.3ms inference, 15.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image27.jpeg: 297.95269775390625
#
# 0: 800x608 (no detections), 819.9ms
# Speed: 7.0ms preprocess, 819.9ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image27.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image27.jpeg
#
# 0: 800x608 1 750ml coke, 892.5ms
# Speed: 11.2ms preprocess, 892.5ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 3 floors, 10 wallss, 678.0ms
# Speed: 3.7ms preprocess, 678.0ms inference, 29.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image28.jpeg: 305.3160705566406
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 815.3ms
# Speed: 7.9ms preprocess, 815.3ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image28.jpeg: P1: 222.73 cm
# Output saved at: Output_test_folder_combined\image28.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image28.jpeg
#
# 0: 800x608 1 750ml coke, 883.2ms
# Speed: 9.8ms preprocess, 883.2ms inference, 3.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 2 floors, 5 wallss, 1720.1ms
# Speed: 3.4ms preprocess, 1720.1ms inference, 92.0ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image29.jpeg: 318.8470153808594
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 1237.8ms
# Speed: 64.3ms preprocess, 1237.8ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image29.jpeg: P1: 276.13 cm, P2: 261.19 cm
# Output saved at: Output_test_folder_combined\image29.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image29.jpeg
#
# 0: 800x608 1 750ml coke, 947.7ms
# Speed: 15.5ms preprocess, 947.7ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 4 wallss, 757.5ms
# Speed: 3.5ms preprocess, 757.5ms inference, 15.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image30.jpeg: 325.5606994628906
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 893.6ms
# Speed: 22.3ms preprocess, 893.6ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image30.jpeg: P1: 243.81 cm
# Output saved at: Output_test_folder_combined\image30.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image30.jpeg
#
# 0: 800x608 1 750ml coke, 857.2ms
# Speed: 9.4ms preprocess, 857.2ms inference, 3.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 6 wallss, 731.4ms
# Speed: 2.8ms preprocess, 731.4ms inference, 18.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image31.jpeg: 252.20626831054688
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 732.4ms
# Speed: 10.0ms preprocess, 732.4ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image31.jpeg: P1: 296.63 cm, P2: 267.58 cm
# Output saved at: Output_test_folder_combined\image31.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image31.jpeg
#
# 0: 800x608 1 750ml coke, 874.6ms
# Speed: 9.1ms preprocess, 874.6ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 5 wallss, 796.8ms
# Speed: 2.6ms preprocess, 796.8ms inference, 25.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image32.jpeg: 248.37744140625
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 929.2ms
# Speed: 8.9ms preprocess, 929.2ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image32.jpeg: P1: 239.82 cm
# Output saved at: Output_test_folder_combined\image32.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image32.jpeg
#
# 0: 800x608 1 750ml coke, 811.8ms
# Speed: 7.7ms preprocess, 811.8ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 4 floors, 5 wallss, 763.8ms
# Speed: 3.4ms preprocess, 763.8ms inference, 19.4ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image33.jpeg: 293.4157409667969
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 869.1ms
# Speed: 9.4ms preprocess, 869.1ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image33.jpeg: P1: 286.15 cm
# Output saved at: Output_test_folder_combined\image33.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image33.jpeg
#
# 0: 800x608 1 750ml coke, 778.8ms
# Speed: 7.6ms preprocess, 778.8ms inference, 3.2ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 floor, 1 walls, 802.4ms
# Speed: 7.1ms preprocess, 802.4ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image34.jpeg: XXXXX
#
# 0: 800x608 (no detections), 873.2ms
# Speed: 8.9ms preprocess, 873.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image34.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image34.jpeg
#
# 0: 800x608 1 750ml coke, 850.1ms
# Speed: 8.7ms preprocess, 850.1ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 2 floors, 10 wallss, 772.0ms
# Speed: 2.6ms preprocess, 772.0ms inference, 63.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image35.jpeg: 347.7691650390625
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 870.6ms
# Speed: 28.3ms preprocess, 870.6ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image35.jpeg: P1: 303.51 cm, P2: 264.21 cm
# Output saved at: Output_test_folder_combined\image35.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image35.jpeg
#
# 0: 800x608 1 750ml coke, 891.1ms
# Speed: 10.1ms preprocess, 891.1ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 5 wallss, 668.2ms
# Speed: 4.2ms preprocess, 668.2ms inference, 13.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image36.jpeg: 255.2198944091797
#
# 0: 800x608 3 Propellers detection - v1 2025-02-20 11-43ams, 778.7ms
# Speed: 9.3ms preprocess, 778.7ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image36.jpeg: P1: 306.72 cm, P2: 245.12 cm, P3: 196.22 cm
# Output saved at: Output_test_folder_combined\image36.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image36.jpeg
#
# 0: 800x608 1 750ml coke, 906.0ms
# Speed: 8.5ms preprocess, 906.0ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 4 wallss, 762.7ms
# Speed: 3.7ms preprocess, 762.7ms inference, 19.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image37.jpeg: 341.9292297363281
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 861.4ms
# Speed: 7.6ms preprocess, 861.4ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image37.jpeg: P1: 263.50 cm, P2: 284.89 cm
# Output saved at: Output_test_folder_combined\image37.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image37.jpeg
#
# 0: 800x608 1 750ml coke, 798.3ms
# Speed: 6.8ms preprocess, 798.3ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 4 wallss, 756.9ms
# Speed: 3.5ms preprocess, 756.9ms inference, 15.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image38.jpeg: 297.9344787597656
#
# 0: 800x608 (no detections), 893.6ms
# Speed: 9.1ms preprocess, 893.6ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image38.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image38.jpeg
#
# 0: 800x608 2 750ml cokes, 797.8ms
# Speed: 9.7ms preprocess, 797.8ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 5 wallss, 678.6ms
# Speed: 3.0ms preprocess, 678.6ms inference, 23.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image39.jpeg: 348.3186950683594
#
# 0: 800x608 (no detections), 866.9ms
# Speed: 8.1ms preprocess, 866.9ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image39.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image39.jpeg
#
# 0: 800x608 1 750ml coke, 819.0ms
# Speed: 8.5ms preprocess, 819.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 8 wallss, 741.3ms
# Speed: 3.4ms preprocess, 741.3ms inference, 19.7ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image40.jpeg: 365.9366149902344
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 890.2ms
# Speed: 9.2ms preprocess, 890.2ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image40.jpeg: P1: 207.11 cm, P2: 208.48 cm
# Output saved at: Output_test_folder_combined\image40.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image40.jpeg
#
# 0: 800x608 1 750ml coke, 866.4ms
# Speed: 9.6ms preprocess, 866.4ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 5 ceilings, 1 floor, 6 wallss, 742.7ms
# Speed: 2.9ms preprocess, 742.7ms inference, 26.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image41.jpeg: 270.9043884277344
#
# 0: 800x608 (no detections), 873.9ms
# Speed: 8.6ms preprocess, 873.9ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image41.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image41.jpeg
#
# 0: 800x608 1 750ml coke, 861.0ms
# Speed: 7.7ms preprocess, 861.0ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 3 wallss, 732.8ms
# Speed: 3.3ms preprocess, 732.8ms inference, 29.3ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image42.jpeg: 329.9629821777344
#
# 0: 800x608 (no detections), 807.0ms
# Speed: 9.2ms preprocess, 807.0ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image42.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image42.jpeg
#
# 0: 800x608 1 750ml coke, 882.7ms
# Speed: 8.6ms preprocess, 882.7ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 1 walls, 747.3ms
# Speed: 3.9ms preprocess, 747.3ms inference, 13.7ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image43.jpeg: 318.4115295410156
#
# 0: 800x608 (no detections), 863.6ms
# Speed: 8.5ms preprocess, 863.6ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image43.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image43.jpeg
#
# 0: 800x608 1 750ml coke, 809.6ms
# Speed: 10.4ms preprocess, 809.6ms inference, 3.2ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 4 wallss, 539.2ms
# Speed: 3.3ms preprocess, 539.2ms inference, 11.2ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image44.jpeg: 332.5180358886719
#
# 0: 800x608 (no detections), 362.2ms
# Speed: 7.7ms preprocess, 362.2ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image44.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image44.jpeg
#
# 0: 800x608 1 750ml coke, 372.6ms
# Speed: 7.0ms preprocess, 372.6ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 3 floors, 4 wallss, 400.7ms
# Speed: 2.1ms preprocess, 400.7ms inference, 17.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image45.jpeg: 316.8102111816406
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 819.1ms
# Speed: 10.1ms preprocess, 819.1ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image45.jpeg: P1: 261.20 cm
# Output saved at: Output_test_folder_combined\image45.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image45.jpeg
#
# 0: 800x608 1 750ml coke, 820.2ms
# Speed: 9.2ms preprocess, 820.2ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 6 wallss, 755.0ms
# Speed: 3.2ms preprocess, 755.0ms inference, 19.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image46.jpeg: 265.65087890625
#
# 0: 800x608 (no detections), 887.2ms
# Speed: 9.0ms preprocess, 887.2ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image46.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image46.jpeg
#
# 0: 800x608 1 750ml coke, 918.4ms
# Speed: 9.6ms preprocess, 918.4ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 2 wallss, 750.4ms
# Speed: 3.2ms preprocess, 750.4ms inference, 12.1ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image47.jpeg: 312.5910339355469
#
# 0: 800x608 (no detections), 863.0ms
# Speed: 9.0ms preprocess, 863.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image47.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image47.jpeg
#
# 0: 800x608 1 750ml coke, 878.0ms
# Speed: 10.4ms preprocess, 878.0ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 3 wallss, 693.9ms
# Speed: 4.2ms preprocess, 693.9ms inference, 11.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image48.jpeg: 334.4101257324219
#
# 0: 800x608 (no detections), 823.5ms
# Speed: 11.1ms preprocess, 823.5ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image48.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image48.jpeg
#
# 0: 800x608 1 750ml coke, 817.4ms
# Speed: 10.0ms preprocess, 817.4ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 7 wallss, 687.3ms
# Speed: 3.7ms preprocess, 687.3ms inference, 14.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image49.jpeg: 281.9542236328125
#
# 0: 800x608 (no detections), 813.1ms
# Speed: 8.0ms preprocess, 813.1ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image49.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image49.jpeg
#
# 0: 800x608 1 750ml coke, 811.7ms
# Speed: 10.3ms preprocess, 811.7ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 3 wallss, 679.6ms
# Speed: 3.9ms preprocess, 679.6ms inference, 10.8ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image50.jpeg: 254.67098999023438
#
# 0: 800x608 (no detections), 805.6ms
# Speed: 8.9ms preprocess, 805.6ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image50.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image50.jpeg
#
# 0: 800x608 2 750ml cokes, 800.0ms
# Speed: 9.9ms preprocess, 800.0ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 6 wallss, 683.1ms
# Speed: 3.9ms preprocess, 683.1ms inference, 14.6ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image51.jpeg: 341.887451171875
#
# 0: 800x608 (no detections), 817.9ms
# Speed: 8.1ms preprocess, 817.9ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image51.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image51.jpeg
#
# 0: 800x608 1 750ml coke, 833.7ms
# Speed: 9.2ms preprocess, 833.7ms inference, 3.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 6 floors, 7 wallss, 779.5ms
# Speed: 3.4ms preprocess, 779.5ms inference, 24.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image52.jpeg: 204.27671813964844
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 886.6ms
# Speed: 8.9ms preprocess, 886.6ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image52.jpeg: P1: 150.39 cm
# Output saved at: Output_test_folder_combined\image52.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image52.jpeg
#
# 0: 800x608 1 750ml coke, 871.4ms
# Speed: 9.3ms preprocess, 871.4ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 2 floors, 8 wallss, 694.7ms
# Speed: 3.5ms preprocess, 694.7ms inference, 16.5ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image53.jpeg: 260.29888916015625
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 888.5ms
# Speed: 9.5ms preprocess, 888.5ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image53.jpeg: P1: 228.65 cm
# Output saved at: Output_test_folder_combined\image53.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only\image53.jpeg
#
# 0: 800x608 1 750ml coke, 817.2ms
# Speed: 9.3ms preprocess, 817.2ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 floors, 8 wallss, 734.3ms
# Speed: 3.6ms preprocess, 734.3ms inference, 37.9ms postprocess per image at shape (1, 3, 640, 480)
# Ceiling Height for image54.jpeg: XXXXX
#
# 0: 800x608 (no detections), 794.1ms
# Speed: 9.6ms preprocess, 794.1ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 608)
# AC Height for image54.jpeg: YYYY
# Output saved at: Output_test_folder_combined\image54.jpeg
#
# Final Results:
# Photo 1 | ID image1.jpeg | Ceiling height 311.1754455566406 | AC Height YYYY
# Photo 2 | ID image2.jpeg | Ceiling height XXXXX | AC Height YYYY
# Photo 3 | ID image3.jpeg | Ceiling height 308.0299377441406 | AC Height P1: 175.87 cm
# Photo 4 | ID image4.jpeg | Ceiling height 331.9803466796875 | AC Height P1: 219.10 cm
# Photo 5 | ID image5.jpeg | Ceiling height 372.9312438964844 | AC Height P1: 204.68 cm, P2: 269.34 cm, P3: 298.27 cm, P4: 253.62 cm
# Photo 6 | ID image6.jpeg | Ceiling height 356.0187072753906 | AC Height YYYY
# Photo 7 | ID image7.jpeg | Ceiling height 325.1845703125 | AC Height P1: 207.72 cm, P2: 168.10 cm
# Photo 8 | ID image8.jpeg | Ceiling height XXXXX | AC Height P1: 303.25 cm
# Photo 9 | ID image9.jpeg | Ceiling height 302.3682861328125 | AC Height P1: 195.73 cm, P2: 157.04 cm, P3: 212.31 cm
# Photo 10 | ID image10.jpeg | Ceiling height 383.6058654785156 | AC Height P1: 259.89 cm, P2: 254.76 cm, P3: 236.09 cm, P4: 240.85 cm, P5: 225.84 cm
# Photo 11 | ID image11.jpeg | Ceiling height 318.5067443847656 | AC Height P1: 190.67 cm, P2: 194.97 cm, P3: 194.43 cm, P4: 67.94 cm
# Photo 12 | ID image12.jpeg | Ceiling height XXXXX | AC Height YYYY
# Photo 13 | ID image13.jpeg | Ceiling height XXXXX | AC Height P1: 163.07 cm
# Photo 14 | ID image14.jpeg | Ceiling height 303.2145690917969 | AC Height P1: 265.49 cm
# Photo 15 | ID image15.jpeg | Ceiling height 304.4614562988281 | AC Height YYYY
# Photo 16 | ID image16.jpeg | Ceiling height 326.3818664550781 | AC Height YYYY
# Photo 17 | ID image17.jpeg | Ceiling height 308.68731689453125 | AC Height YYYY
# Photo 18 | ID image18.jpeg | Ceiling height 288.9804992675781 | AC Height YYYY
# Photo 19 | ID image19.jpeg | Ceiling height 267.659423828125 | AC Height YYYY
# Photo 20 | ID image20.jpeg | Ceiling height 292.85394287109375 | AC Height YYYY
# Photo 21 | ID image21.jpeg | Ceiling height XXXXX | AC Height YYYY
# Photo 22 | ID image22.jpeg | Ceiling height 276.6624755859375 | AC Height YYYY
# Photo 23 | ID image23.jpeg | Ceiling height 326.78277587890625 | AC Height YYYY
# Photo 24 | ID image24.jpeg | Ceiling height 275.7752380371094 | AC Height P1: 220.62 cm, P2: 249.59 cm
# Photo 25 | ID image25.jpeg | Ceiling height XXXXX | AC Height P1: 259.68 cm
# Photo 26 | ID image26.jpeg | Ceiling height 278.0777282714844 | AC Height YYYY
# Photo 27 | ID image27.jpeg | Ceiling height 297.95269775390625 | AC Height YYYY
# Photo 28 | ID image28.jpeg | Ceiling height 305.3160705566406 | AC Height P1: 222.73 cm
# Photo 29 | ID image29.jpeg | Ceiling height 318.8470153808594 | AC Height P1: 276.13 cm, P2: 261.19 cm
# Photo 30 | ID image30.jpeg | Ceiling height 325.5606994628906 | AC Height P1: 243.81 cm
# Photo 31 | ID image31.jpeg | Ceiling height 252.20626831054688 | AC Height P1: 296.63 cm, P2: 267.58 cm
# Photo 32 | ID image32.jpeg | Ceiling height 248.37744140625 | AC Height P1: 239.82 cm
# Photo 33 | ID image33.jpeg | Ceiling height 293.4157409667969 | AC Height P1: 286.15 cm
# Photo 34 | ID image34.jpeg | Ceiling height XXXXX | AC Height YYYY
# Photo 35 | ID image35.jpeg | Ceiling height 347.7691650390625 | AC Height P1: 303.51 cm, P2: 264.21 cm
# Photo 36 | ID image36.jpeg | Ceiling height 255.2198944091797 | AC Height P1: 306.72 cm, P2: 245.12 cm, P3: 196.22 cm
# Photo 37 | ID image37.jpeg | Ceiling height 341.9292297363281 | AC Height P1: 263.50 cm, P2: 284.89 cm
# Photo 38 | ID image38.jpeg | Ceiling height 297.9344787597656 | AC Height YYYY
# Photo 39 | ID image39.jpeg | Ceiling height 348.3186950683594 | AC Height YYYY
# Photo 40 | ID image40.jpeg | Ceiling height 365.9366149902344 | AC Height P1: 207.11 cm, P2: 208.48 cm
# Photo 41 | ID image41.jpeg | Ceiling height 270.9043884277344 | AC Height YYYY
# Photo 42 | ID image42.jpeg | Ceiling height 329.9629821777344 | AC Height YYYY
# Photo 43 | ID image43.jpeg | Ceiling height 318.4115295410156 | AC Height YYYY
# Photo 44 | ID image44.jpeg | Ceiling height 332.5180358886719 | AC Height YYYY
# Photo 45 | ID image45.jpeg | Ceiling height 316.8102111816406 | AC Height P1: 261.20 cm
# Photo 46 | ID image46.jpeg | Ceiling height 265.65087890625 | AC Height YYYY
# Photo 47 | ID image47.jpeg | Ceiling height 312.5910339355469 | AC Height YYYY
# Photo 48 | ID image48.jpeg | Ceiling height 334.4101257324219 | AC Height YYYY
# Photo 49 | ID image49.jpeg | Ceiling height 281.9542236328125 | AC Height YYYY
# Photo 50 | ID image50.jpeg | Ceiling height 254.67098999023438 | AC Height YYYY
# Photo 51 | ID image51.jpeg | Ceiling height 341.887451171875 | AC Height YYYY
# Photo 52 | ID image52.jpeg | Ceiling height 204.27671813964844 | AC Height P1: 150.39 cm
# Photo 53 | ID image53.jpeg | Ceiling height 260.29888916015625 | AC Height P1: 228.65 cm
# Photo 54 | ID image54.jpeg | Ceiling height XXXXX | AC Height YYYY

# %%
print("\nFinal Dictionary:")
for key, value in Propeller_heights.items():
    print(f"{key}: {value}")
# Out:
# Final Dictionary:
# image3.jpeg: [175.87408447265625]
# image4.jpeg: [219.10037231445312]
# image5.jpeg: [204.6835174560547, 269.3392333984375, 298.2735290527344, 253.62181091308594]
# image7.jpeg: [207.71853637695312, 168.1038818359375]
# image8.jpeg: [303.2469787597656]
# image9.jpeg: [195.7265625, 157.0364227294922, 212.30804443359375]
# image10.jpeg: [259.8856506347656, 254.76113891601562, 236.09329223632812, 240.8517608642578, 225.8442840576172]
# image11.jpeg: [190.6743621826172, 194.9712371826172, 194.4341278076172, 67.94452667236328]
# image13.jpeg: [163.06947326660156]
# image14.jpeg: [265.4924011230469]
# image24.jpeg: [220.6201934814453, 249.59405517578125]
# image25.jpeg: [259.6839599609375]
# image28.jpeg: [222.73057556152344]
# image29.jpeg: [276.1257019042969, 261.1905822753906]
# image30.jpeg: [243.8071746826172]
# image31.jpeg: [296.6328430175781, 267.5846862792969]
# image32.jpeg: [239.8228759765625]
# image33.jpeg: [286.1464538574219]
# image35.jpeg: [303.5136413574219, 264.21209716796875]
# image36.jpeg: [306.72021484375, 245.1154022216797, 196.2227020263672]
# image37.jpeg: [263.4961853027344, 284.8869934082031]
# image40.jpeg: [207.11468505859375, 208.4750518798828]
# image45.jpeg: [261.197998046875]
# image52.jpeg: [150.3877716064453]
# image53.jpeg: [228.64508056640625]

# %%
Actual_P_heights = {
    "image3.jpeg": [250],
    "image4.jpeg": [200],
    "image5.jpeg": [200, 280, 280, 280],
    "image7.jpeg": [280, 180],
    "image8.jpeg": [280],
    "image9.jpeg": [280, 180, 280],
    "image10.jpeg": [280, 280, 200, 200, 180],
    "image11.jpeg": [230, 230, 230, 80],
    "image13.jpeg": [280],
    "image14.jpeg": [280],
    "image24.jpeg": [280, 280],
    "image25.jpeg": [280],
    "image28.jpeg": [280],
    "image29.jpeg": [280, 280],
    "image30.jpeg": [280],
    "image31.jpeg": [280, 280],
    "image32.jpeg": [280],
    "image33.jpeg": [280],
    "image35.jpeg": [280, 280],
    "image36.jpeg": [280, 280, 280],
    "image37.jpeg": [280, 280],
    "image40.jpeg": [200, 200],
    "image45.jpeg": [280],
    "image52.jpeg": [280],
    "image53.jpeg": [280]
}

# %%
# Flatten the lists to compare elements one by one
predicted_P_heights = []
real_P_heights = []

for img in Propeller_heights:
    if img in Actual_P_heights:
        predicted_P_heights.extend(Propeller_heights[img])
        real_P_heights.extend(Actual_P_heights[img])

# Convert to NumPy arrays
predicted_P_heights = np.array(predicted_P_heights)
real_heights = np.array(real_P_heights)

# Compute evaluation metrics
mae = np.mean(np.abs(real_P_heights - predicted_P_heights))  # Mean Absolute Error
mse = np.mean((real_P_heights - predicted_P_heights) ** 2)  # Mean Squared Error
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Print results
formatted_P_heights = ", ".join(f"{h:.2f}" for h in predicted_P_heights)
form_real_P_heights = ", ".join(f"{h:.2f}" for h in real_P_heights)
print("\n")
print(f"Predicted Heights: [{formatted_P_heights}]")
print("\n")
print(f"Actual Heights: [{form_real_P_heights}]")
print(f"MAE: {mae:.2f} cm")
print(f"MSE: {mse:.2f} cm²")
print(f"RMSE: {rmse:.2f} cm")
# Out:
# Predicted Heights: [175.87, 219.10, 204.68, 269.34, 298.27, 253.62, 207.72, 168.10, 303.25, 195.73, 157.04, 212.31, 259.89, 254.76, 236.09, 240.85, 225.84, 190.67, 194.97, 194.43, 67.94, 163.07, 265.49, 220.62, 249.59, 259.68, 222.73, 276.13, 261.19, 243.81, 296.63, 267.58, 239.82, 286.15, 303.51, 264.21, 306.72, 245.12, 196.22, 263.50, 284.89, 207.11, 208.48, 261.20, 150.39, 228.65]
#
#
# Actual Heights: [250.00, 200.00, 200.00, 280.00, 280.00, 280.00, 280.00, 180.00, 280.00, 280.00, 180.00, 280.00, 280.00, 280.00, 200.00, 200.00, 180.00, 230.00, 230.00, 230.00, 80.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 280.00, 200.00, 200.00, 280.00, 280.00, 280.00]
# MAE: 34.35 cm
# MSE: 1982.39 cm²
# RMSE: 44.52 cm

# %%
# Calculate Mean Absolute Percentage Error (MAPE)
mape = np.mean(np.abs((real_P_heights - predicted_P_heights) / real_P_heights)) * 100

# Calculate Accuracy
accuracy = 100 - mape

# Print results
print(f"MAPE: {mape:.2f}%")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# MAPE: 13.47%
# Accuracy: 86.53%

# %%
import numpy as np
import torch

# Predicted height (assumed constant for all images as per your requirement)
actual_height = 340  # cm

# Ensure all predicted heights are converted to CPU NumPy arrays
predicted_heights = [
    h.detach().cpu().numpy() if isinstance(h, torch.Tensor) else np.array(h, dtype=np.float32)
    for h in ceil_heights.values()
]

# Convert to NumPy array
predicted_heights = np.array(predicted_heights, dtype=np.float32)

# Create an array of the actual height for comparison
real_heights = np.full_like(predicted_heights, actual_height)

# Compute evaluation metrics
mae = np.mean(np.abs(real_heights - predicted_heights))  # Mean Absolute Error
mse = np.mean((real_heights - predicted_heights) ** 2)  # Mean Squared Error
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Print results
formatted_heights = ", ".join(f"{h:.2f}" for h in predicted_heights)
print(f"Predicted Heights: [{formatted_heights}]")
print(f"MAE: {mae:.2f} cm")
print(f"MSE: {mse:.2f} cm²")
print(f"RMSE: {rmse:.2f} cm")
# Out:
# Predicted Heights: [311.18, 308.03, 331.98, 372.93, 356.02, 325.18, 302.37, 383.61, 318.51, 303.21, 304.46, 326.38, 308.69, 288.98, 267.66, 292.85, 276.66, 326.78, 275.78, 278.08, 297.95, 305.32, 318.85, 325.56, 252.21, 248.38, 293.42, 347.77, 255.22, 341.93, 297.93, 348.32, 365.94, 270.90, 329.96, 318.41, 332.52, 316.81, 265.65, 312.59, 334.41, 281.95, 254.67, 341.89, 204.28, 260.30]
# MAE: 39.88 cm
# MSE: 2447.36 cm²
# RMSE: 49.47 cm

# %%
# # Find the accuracy of the propellers

# import numpy as np

# # Predicted height (assumed constant for all images as per your requirement)
# actual_height = 340  # cm

# # Extract actual heights from the provided results
# # image_heights = {
# #     "image2.jpeg": 197.32,
# #     "image5.jpeg": 210.09,
# #     "image4.jpeg": 196.10,
# #     "image1.jpeg": 120.91,
# # }

# # List to store actual heights dynamically
# predicted_heights = []
# real_heights = []

# # Fetch actual heights using a loop
# # Convert actual heights to a NumPy array
# predicted_heights = np.array(list(ceil_heights.values()))

# # Create an array of the actual height for comparison
# real_heights = np.full_like(predicted_heights, actual_height)

# # Convert to NumPy arrays for calculations
# # actual_heights = np.array(actual_heights)
# # predicted_heights = np.full_like(actual_heights, predicted_height)

# # Compute evaluation metrics
# mae = np.mean(np.abs(real_heights - predicted_heights))  # Mean Absolute Error
# mse = np.mean((real_heights - predicted_heights) ** 2)  # Mean Squared Error
# rmse = np.sqrt(mse)  # Root Mean Squared Error

# # Print results
# formatted_heights = ", ".join(f"{h:.2f}" for h in predicted_heights)
# print(f"Predicted Heights: [{formatted_heights}]")
# print(f"MAE: {mae:.2f} cm")
# print(f"MSE: {mse:.2f} cm²")
# print(f"RMSE: {rmse:.2f} cm")

# %%
# Calculate Mean Absolute Percentage Error (MAPE)
mape = np.mean(np.abs((real_heights - predicted_heights) / real_heights)) * 100

# Calculate Accuracy
accuracy = 100 - mape

# Print results
print(f"MAPE: {mape:.2f}%")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# MAPE: 11.73%
# Accuracy: 88.27%

# %%
import numpy as np
import os

# Define actual height (constant for all images)
actual_height = 340  # cm

# Ensure all predicted heights are converted to CPU NumPy arrays
# predicted_heights = [
#     h.detach().cpu().numpy() if isinstance(h, torch.Tensor) else np.array(h, dtype=np.float32)
#     for h in ceil_heights.values()
# ]

# # Convert to NumPy array
# predicted_heights = np.array(predicted_heights, dtype=np.float32)
# # Convert predicted heights to NumPy array
# predicted_heights = np.array(list(ceil_heights.values()))

# Create an array of actual height values
real_heights = np.full_like(predicted_heights, actual_height)

# Calculate metrics
mae = np.mean(np.abs(real_heights - predicted_heights))  # Mean Absolute Error
mse = np.mean((real_heights - predicted_heights) ** 2)  # Mean Squared Error
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Define folder and file path
folder_path = "Output_test_folder_combined"
os.makedirs(folder_path, exist_ok=True)
file_path = os.path.join(folder_path, "Ceiling_Height_file.txt")

# Save results to a text file
with open(file_path, "w") as file:
    file.write("Image Name | Actual Height (cm) | Predicted Height (cm) | Error (cm)\n")
    file.write("-" * 70 + "\n")
    
    for image_name, predicted_height in ceil_heights.items():
        error = abs(actual_height - predicted_height)
        file.write(f"{image_name} |     {actual_height} cm     |     {predicted_height:.2f} cm     |     {error:.2f} cm    \n")
    


print(f"Results saved in: {file_path}")
# Out:
# Results saved in: Output_test_folder_combined\Ceiling_Height_file.txt

# %%
# import os

# # Define folder and file path
# folder_path1 = "Output_test_folder_propeller_only"
# os.makedirs(folder_path1, exist_ok=True)
# file_path = os.path.join(folder_path1, "propeller_Height_file.txt")




# # Write to file
# with open(file_path, "w") as file:
#     # Header
#     file.write("Image Name |AC_Prop1|AC_Prop2|AC_Prop3|AC_Prop4|AC_Prop5\n")
#     file.write("-" * 75 + "\n")
    
#     for image_name, heights in sorted(Propeller_heights.items()):
#         formatted_heights = [f"{h:.2f}cm" for h in heights]  # Format to 2 decimal places
#         while len(formatted_heights) < 5:
#             formatted_heights.append("YYYYYYYY")  # Fill missing columns with '-'
        
#         file.write(f"{image_name}|" + "|".join(formatted_heights)+"\n")

# print(f"✅ Formatted propeller heights saved in: {file_path}")

# %%
import os
import re

# Define folder and file path
folder_path1 = "Output_test_folder_propeller_only"
os.makedirs(folder_path1, exist_ok=True)
file_path = os.path.join(folder_path1, "propeller_Height_file.txt")

# Function to sort image names in human-readable order (image1, image2, ..., image50)
def sort_key(image_name):
    match = re.search(r'(\d+)', image_name)
    return int(match.group(1)) if match else float('inf')

# Sort image names properly
sorted_image_names = sorted(Propeller_heights.keys(), key=sort_key)

with open(file_path, "w") as file:
    # Header
    file.write("Image Name | AC_Prop1 | AC_P_Prop1 | AC_Prop2 | AC_P_Prop2 | AC_Prop3 | AC_P_Prop3 | AC_Prop4 | AC_P_Prop4 | AC_Prop5 | AC_P_Prop5 \n")
    file.write("-" * 95 + "\n")
    
    for image_name in sorted_image_names:
        actual_heights = Actual_P_heights.get(image_name, [])
        predicted_heights = Propeller_heights.get(image_name, [])
        
        formatted_actual = [f"{h:.2f}cm" for h in actual_heights]
        formatted_predicted = [f"{h:.2f}cm" for h in predicted_heights]
        
        while len(formatted_actual) < 5:
            formatted_actual.append("YYYYYYYY")  # Placeholder for missing values
        while len(formatted_predicted) < 5:
            formatted_predicted.append("YYYYYYYY")
        
        row_values = [val for pair in zip(formatted_actual, formatted_predicted) for val in pair]
        file.write(f"{image_name}| " + " | ".join(row_values) + "\n")

# Print results
print(f"✅ Formatted propeller heights saved in: {file_path}")
print(f"MAE: {mae:.2f} cm")
print(f"MSE: {mse:.2f} cm²")
print(f"RMSE: {rmse:.2f} cm")
# Out:
# ✅ Formatted propeller heights saved in: Output_test_folder_propeller_only\propeller_Height_file.txt
# MAE: 39.88 cm
# MSE: 2447.36 cm²
# RMSE: 49.47 cm

# %%
# Write to file
import os

# Define folder and file path
folder_path1 = "Output_test_folder_propeller_only"
os.makedirs(folder_path1, exist_ok=True)
file_path = os.path.join(folder_path1, "propeller_Height_file.txt")
with open(file_path, "w") as file:
    # Header
    file.write("Image Name | AC_Prop1 | AC_P_Prop1 | AC_Prop2 | AC_P_Prop2 | AC_Prop3 | AC_P_Prop3 | AC_Prop4 | AC_P_Prop4 | AC_Prop5 | AC_P_Prop5 \n")
    file.write("-" * 95 + "\n")
    
    
    for image_name in sorted(Propeller_heights.keys()):
        actual_heights = Actual_P_heights.get(image_name, [])
        predicted_heights = Propeller_heights.get(image_name, [])
        
        formatted_actual = [f"{h:.2f}cm" for h in actual_heights]
        formatted_predicted = [f"{h:.2f}cm" for h in predicted_heights]
        
        while len(formatted_actual) < 5:
            formatted_actual.append("YYYYYYYY")  # Placeholder for missing values
        while len(formatted_predicted) < 5:
            formatted_predicted.append("YYYYYYYY")
        
        row_values = [val for pair in zip(formatted_actual, formatted_predicted) for val in pair]
        file.write(f"{image_name}| " + " | ".join(row_values) + "\n")



# Print results
print(f"✅ Formatted propeller heights saved in: {file_path}")
print(f"MAE: {mae:.2f} cm")
print(f"MSE: {mse:.2f} cm²")
print(f"RMSE: {rmse:.2f} cm")
# Out:
# ✅ Formatted propeller heights saved in: Output_test_folder_propeller_only\propeller_Height_file.txt
# MAE: 39.88 cm
# MSE: 2447.36 cm²
# RMSE: 49.47 cm
