# %%
import cv2
import torch
from ultralytics import YOLO

# %%
def natural_sort_key(filename):
    """Extract numerical values from filenames for correct sorting."""
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', filename)]

# %%
def detect_objects(model, image_path):
    image = cv2.imread(image_path)
    results = model(image)  # Perform object detection
    return results, image

# %%
def get_ceiling_floor_coordinates(results, floor_model):
    ceiling_y = None  # Initialize
    floor_y = None  # Initialize
    best_ceiling = None
    best_floor = None

    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coords
            confidence = float(box.conf[0].cpu().numpy())  # Confidence score
            class_id = int(box.cls[0].cpu().numpy())  # Class ID
            
            class_name = floor_model.names.get(class_id, "Unknown")

            if class_name == "ceiling":
                if best_ceiling is None or confidence > best_ceiling[1]:
                    best_ceiling = ((x1, y1, x2, y2), confidence)

            if class_name == "floor":
                if best_floor is None or confidence > best_floor[1]:
                    best_floor = ((x1, y1, x2, y2), confidence)

    ceiling_mid, floor_mid = None, None  

    if best_ceiling:
        (_, ceiling_y1, _, ceiling_y2), _ = best_ceiling
        ceiling_y = (ceiling_y1 + ceiling_y2)// 2  # Midpoint

    if best_floor:
        (_, floor_y1, _, floor_y2), _ = best_floor
        floor_y = (floor_y1 + floor_y2)// 2  # Midpoint

    return ceiling_y, floor_y

# %%
def get_floor_coordinates(results):
    """Extract the top Y-coordinate and bounding box of the floor"""
    floor_y_top = None
    floor_box = None
    
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls.cpu().numpy().item())  # Get class ID
            x_min, y_min, x_max, y_max = map(int, box.xyxy[0])  # Bounding box
            
            if class_id == 1:  # Assuming class 1 is "floor"
                floor_y_top = y_min  # Top Y-coordinate of floor
                floor_box = (x_min, y_min, x_max, y_max)
    
    return floor_y_top, floor_box

# %%
def get_propeller_coordinates(results):
    """Extract the bottom Y-coordinates and bounding boxes of propellers"""
    propeller_boxes = []  # Store bounding boxes of detected propellers
    propeller_y_bottoms = []  # Store Y-bottom of propellers
    
    for result in results:
        for box in result.boxes:
            class_id = int(box.cls.cpu().numpy().item())  # Get class ID
            x_min, y_min, x_max, y_max = map(int, box.xyxy[0])  # Bounding box
            
            if class_id == 0:  # Assuming class 0 is "propeller"
                propeller_y_bottoms.append(y_max)  # Store bottom Y-coordinate
                propeller_boxes.append((x_min, y_min, x_max, y_max))
    
    return propeller_y_bottoms, propeller_boxes

# %%
def detect_height_bottle(image_path, model):
    """Detect Coca-Cola bottles and return their bounding box height in pixels."""
    image = cv2.imread(image_path)
    results = model(image)
    coke_boxes = []
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Bounding box coordinates
            height_pixels = y2 - y1  # Bottle height in pixels
            real_height_cm = 26  # Known height of Coca-Cola bottle
            coke_boxes.append((x1, y1, x2, y2))
            pixel_to_cm_ratio = real_height_cm / height_pixels
            estimated_real_height = height_pixels * pixel_to_cm_ratio
            
            return height_pixels, estimated_real_height
    

    return None, None  # If no bottle is detected

# %%
def calculate_height(ceiling_y, floor_y, calibration_obj):
    """Calculate ceiling height using a calibration object (Coca-Cola bottle)."""
    if ceiling_y is None or floor_y is None:
        print("Error: Ceiling or Floor not detected!")
        return None  # Avoid TypeError

    pixel_height = floor_y - ceiling_y

    if calibration_obj:
        real_height, obj_pixel_height = calibration_obj
        pixel_to_cm_ratio = real_height / obj_pixel_height
        return pixel_height * pixel_to_cm_ratio
    
    return pixel_height  # Return pixel height if no calibration object

# %%
def draw_detections(image, propeller_boxes, floor_box, calibration_obj, floor_results):
    best_ceiling = None
    best_floor = None  # Ensure variables are initialized

    for i, (x1, y1, x2, y2) in enumerate(propeller_boxes):  # Unpacking tuple directly
        x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])  # Ensure integer values
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
        
        # Calculate height from floor to propeller
        pixel_height = y1 - floor_box[1]
        real_height = calculate_height(y1, floor_box[1], calibration_obj)
        height_text = f"Height: {real_height:.2f} cm"
        
        # Draw text label
        cv2.putText(image, height_text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Label the calibration object
    if calibration_obj:
        real_height, obj_pixel_height = calibration_obj
        cal_text = f"Calibration: {real_height:.2f} cm ({obj_pixel_height} px)"
        cv2.putText(image, cal_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)
    
    # Process results
    for result in floor_results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coordinates
            confidence = float(box.conf[0].cpu().numpy())  # Confidence score
            class_id = int(box.cls[0].cpu().numpy())  # Class ID

            # Get class name correctly
            class_name = floor_model.names.get(class_id, "Unknown")  # Ensure we get the correct class label

            # Store the most confident "ceiling" and "floor" detection
            if class_name == "ceiling":
                if best_ceiling is None or confidence > best_ceiling[1]:
                    best_ceiling = ((x1, y1, x2, y2), confidence, class_name)

            if class_name == "floor":
                if best_floor is None or confidence > best_floor[1]:
                    best_floor = ((x1, y1, x2, y2), confidence, class_name)

    # Draw only the best detections on the image
    for best in [best_ceiling, best_floor]:
        if best is not None:  # Ensure best_ceiling and best_floor are not None
            (x1, y1, x2, y2), confidence, class_name = best
            label = f'{class_name}: {confidence:.2f}'
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    return image

# %%
def draw_annotations(image, coke_boxes, ceiling_y, floor_y, pixel_to_cm_ratio=None):
    """Draws bounding boxes, vertical line, and labels on the image."""
    annotated_image = image.copy()
    
    # Draw Coca-Cola bounding boxes
    for (x1, y1, x2, y2, height_pixels) in coke_boxes:
        cv2.rectangle(annotated_image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green box
        cv2.putText(annotated_image, f"{height_pixels}px", (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Draw vertical line from floor to ceiling
    if ceiling_y is not None and floor_y is not None:
        mid_x = image.shape[1] // 2  # Center x-coordinate
        cv2.line(annotated_image, (mid_x, ceiling_y), (mid_x, floor_y), (0, 0, 255), 2)  # Red line
        
        # Calculate real-world ceiling height if calibration object exists
        pixel_height = floor_y - ceiling_y
        if pixel_to_cm_ratio:
            real_ceiling_height = pixel_height * pixel_to_cm_ratio
            height_text = f"Height: {real_ceiling_height:.2f} cm"
        else:
            height_text = f"Height: {pixel_height} pixels"

        # Add text label
        cv2.putText(annotated_image, height_text, (mid_x + 10, (ceiling_y + floor_y) // 2),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

    return annotated_image

# %%
# import os
# import re
# import cv2
# import numpy as np

# def natural_sort_key(filename):
#     """Extract numerical values from filenames for correct sorting."""
#     return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', filename)]

# # Define folders
# image_folder = "Input Dataset folder"
# output_folder = "Output_test_folder_combined"
# propeller_output_folder = "Output_test_folder_propeller_only"

# os.makedirs(output_folder, exist_ok=True)
# os.makedirs(propeller_output_folder, exist_ok=True)

# # Load models
# coke_model = YOLO("best (8).pt")
# floor_model = YOLO("best (5).pt")
# propeller_model = YOLO("best (9).pt")



# ceil_heights = {}  # Store detected ceiling heights
# Propeller_heights = {}
# image_results = []

# # Get and sort image filenames
# image_files = sorted(
#     [f for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))],
#     key=natural_sort_key
# )

# i = 0
# for image_name in image_files:
#     image_path = os.path.join(image_folder, image_name)
    
#     # Detect Coca-Cola bottle height (for calibration)
#     height_pixels, estimated_real_height = detect_height_bottle(image_path, coke_model)
#     calibration_obj = (estimated_real_height, height_pixels) if height_pixels else None
    
#     # Detect ceiling and floor
#     floor_results, image = detect_objects(floor_model, image_path)
#     # Perform inference
        

#     # Store the best detection for ceiling and floor
#     # best_ceiling = None
#     # best_floor = None

#     # # Process results
#     # for result in floor_results:
#     #     for box in result.boxes:
#     #         x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())  # Bounding box coordinates
#     #         confidence = float(box.conf[0].cpu().numpy())  # Confidence score
#     #         class_id = int(box.cls[0].cpu().numpy())  # Class ID
                
#     #         # Get class name correctly
#     #         class_name = floor_model.names.get(class_id, "Unknown")  # Ensure we get the correct class label

#     #         # Store the most confident "ceiling" and "floor" detection
#     #         if class_name == "ceiling":
#     #             if best_ceiling is None or confidence > best_ceiling[1]:
#     #                 best_ceiling = ((x1, y1, x2, y2), confidence, class_name)

#     #         if class_name == "floor":
#     #             if best_floor is None or confidence > best_floor[1]:
#     #                 best_floor = ((x1, y1, x2, y2), confidence, class_name)

#     #     # Draw only the best detections on the image
#     # for best in [best_ceiling, best_floor]:
#     #     if best is not None:
#     #         (x1, y1, x2, y2), confidence, class_name = best
#     #         label = f'{class_name}: {confidence:.2f}'
#     #         cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
#     #         cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)



    
#     ceiling_y, floor_y = get_ceiling_floor_coordinates(floor_results,floor_model)
    
#     if ceiling_y is None or floor_y is None:
#         ceiling_height = "XXXXX"
#     elif calibration_obj:
#         ceiling_height = calculate_height(ceiling_y, floor_y, calibration_obj)
#     else:
#         ceiling_height = "XXXXX"
    
#     print(f"Ceiling Height for {image_name}: {ceiling_height}")
    
#     if ceiling_height != "XXXXX":
#         ceil_heights[image_name] = ceiling_height
    
#     # Read the image
#     image = cv2.imread(image_path)
    
#     # Detect propellers (AC)
#     propeller_results, _ = detect_objects(propeller_model, image_path)
#     propeller_y_bottoms, propeller_boxes = get_propeller_coordinates(propeller_results)

#     propeller_heights_details = []

#     propeller_heights_d = []
    
#     if propeller_boxes and calibration_obj:
#         for idx, propeller_y_bottom in enumerate(propeller_y_bottoms):
#             real_height = calculate_height(propeller_y_bottom, floor_y, calibration_obj)
#             propeller_heights_details.append(
#                 f"P{idx + 1}: {real_height:.2f} cm"
#             )
#             propeller_heights_d.append(real_height.item())

#     if propeller_heights_d != []:
#         Propeller_heights[image_name] = propeller_heights_d

    

    
#     # if propeller_boxes and calibration_obj:
#     #     propeller_heights = [f"{calculate_height(y, floor_y, calibration_obj):.2f} cm" for y in propeller_y_bottoms]
#     # else:
#     #     propeller_heights = []
    
#     ac_height = ", ".join(propeller_heights_details) if propeller_heights_details else "YYYY"
#     print(f"AC Height for {image_name}: {ac_height}")

#     # ac_height = "\n".join(propeller_heights_details) if propeller_heights_details else "YYYY"
#     # print(f"AC Height for {image_name}:\n{ac_height}")
    
    
#     # Draw vertical reference line
#     if ceiling_y is not None and floor_y is not None and ceiling_height != "XXXXX":
#         mid_x = image.shape[1] // 2
#         cv2.line(image, (mid_x, ceiling_y), (mid_x, floor_y), (0, 255, 0), 3)
#         text_position = (mid_x + 10, (ceiling_y + floor_y) // 2)
#         cv2.putText(image, f"{ceiling_height:.2f} cm", text_position, cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    



#     # If propellers are detected, save in a separate folder
#     # if propeller_boxes:
#     #     propeller_output_path = os.path.join(propeller_output_folder, image_name)
#     #     cv2.imwrite(propeller_output_path, image)
#     #     print(f"Propeller Output saved at: {propeller_output_path}")

#     # Draw propeller detections
#     if calibration_obj:
#         for idx, (box, real_height) in enumerate(zip(propeller_boxes, propeller_heights_d)):
#             x1, y1, x2, y2 = box
#             label = f"P{idx + 1}: {real_height:.2f} cm"
#             cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Draw bounding box
#             cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)  # Draw correct label
    
#         output_path = os.path.join(output_folder, image_name)
#         cv2.imwrite(output_path, image)
#         print(f"Output saved at: {output_path}")

#         # If propellers are detected, save in a separate folder
#         if propeller_boxes:
#             propeller_output_path = os.path.join(propeller_output_folder, image_name)
#             cv2.imwrite(propeller_output_path, image)
#             print(f"Propeller Output saved at: {propeller_output_path}")
        
#     # # Draw propeller detections
#     # if calibration_obj:
#     #     output_image = draw_detections(image, propeller_boxes, (floor_y, floor_y), calibration_obj,floor_results)
#     #     output_path = os.path.join(output_folder, image_name)
#     #     cv2.imwrite(output_path, output_image)
#     #     print(f"Output saved at: {output_path}")

#     #     # If propellers are detected, save in a separate folder
#     #     if propeller_boxes:
#     #         propeller_output_path = os.path.join(propeller_output_folder, image_name)
#     #         cv2.imwrite(propeller_output_path, output_image)
#     #         print(f"Propeller Output saved at: {propeller_output_path}")
    
#     # Store results
#     image_results.append(f"Photo {i+1} | ID {image_name} | Ceiling height {ceiling_height} | AC Height {ac_height}")
#     i += 1

# # Print final results
# print("\nFinal Results:")
# for result in image_results:
#     print(result)

# %%
# import os
# import re
# import cv2
# import numpy as np
# from ultralytics import YOLO

# def natural_sort_key(filename):
#     """Extract numerical values from filenames for correct sorting."""
#     return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', filename)]

# # Define folders
# image_folder = "Input Dataset folder"
# output_folder = "Output_test_folder_combined"
# propeller_output_folder = "Output_test_folder_propeller_only"

# os.makedirs(output_folder, exist_ok=True)
# os.makedirs(propeller_output_folder, exist_ok=True)

# # Load models
# coke_model = YOLO("best (8).pt")
# floor_model = YOLO("best (5).pt")
# propeller_model = YOLO("best (9).pt")

# ceil_heights = {}  # Store detected ceiling heights
# Propeller_heights = {}
# image_results = []

# # Get and sort image filenames
# image_files = sorted(
#     [f for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))],
#     key=natural_sort_key
# )

# i = 0
# for image_name in image_files:
#     if not image_name.lower().endswith(('.jpg', '.jpeg', '.png')):
#         continue
    
#     image_path = os.path.join(image_folder, image_name)

#     # Detect Coca-Cola bottle height (for calibration)
#     height_pixels, estimated_real_height = detect_height_bottle(image_path, coke_model)
#     calibration_obj = (estimated_real_height, height_pixels) if height_pixels else None
    
#     # Detect ceiling and floor
#     floor_results, image = detect_objects(floor_model, image_path)
#     ceiling_y, floor_y = get_ceiling_floor_coordinates(floor_results, floor_model)
#     coke_detected = height_pixels is not None

#     if ceiling_y is None or floor_y is None:
#         ceiling_height = "XXXXX"
#     elif calibration_obj:
#         ceiling_height = calculate_height(ceiling_y, floor_y, calibration_obj)
#     else:
#         ceiling_height = "XXXXX"
    
#     print(f"Ceiling Height for {image_name}: {ceiling_height}")
    
#     if ceiling_height != "XXXXX":
#         ceil_heights[image_name] = ceiling_height
    
#     # Detect propellers (AC)
#     propeller_results, _ = detect_objects(propeller_model, image_path)
#     propeller_y_bottoms, propeller_boxes = get_propeller_coordinates(propeller_results)

#     propeller_heights_details = []
#     propeller_heights = []
#     propeller_heights_d = []
    
#     if propeller_boxes and calibration_obj:
#         for idx, propeller_y_bottom in enumerate(propeller_y_bottoms):
#             real_height = calculate_height(propeller_y_bottom, floor_y, calibration_obj)
#             propeller_heights_details.append(
#                 f"P{idx + 1}: {real_height:.2f} cm"
#             )
#             propeller_heights_d.append(real_height.item())

#     if propeller_heights_d != []:
#         Propeller_heights[image_name] = propeller_heights_d

#     ac_height = ", ".join(propeller_heights_details) if propeller_heights_details else "YYYY"
#     print(f"AC Height for {image_name}: {ac_height}")

#     # ac_height = "\n".join(propeller_heights_details) if propeller_heights_details else "YYYY"
#     # print(f"AC Height for {image_name}:\n{ac_height}")
    
    
#     # Draw vertical reference line
#     if ceiling_y is not None and floor_y is not None and ceiling_height != "XXXXX":
#         mid_x = image.shape[1] // 2
#         cv2.line(image, (mid_x, ceiling_y), (mid_x, floor_y), (0, 255, 0), 3)
#         text_position = (mid_x + 10, (ceiling_y + floor_y) // 2)
#         cv2.putText(image, f"{ceiling_height:.2f} cm", text_position, cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    



#     # If propellers are detected, save in a separate folder
#     # if propeller_boxes:
#     #     propeller_output_path = os.path.join(propeller_output_folder, image_name)
#     #     cv2.imwrite(propeller_output_path, image)
#     #     print(f"Propeller Output saved at: {propeller_output_path}")

#     # Draw propeller detections
#     if calibration_obj:
#         for idx, (box, real_height) in enumerate(zip(propeller_boxes, propeller_heights_d)):
#             x1, y1, x2, y2 = box
#             label = f"P{idx + 1}: {real_height:.2f} cm"
#             cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Draw bounding box
#             cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)  # Draw correct label
    
#         output_path = os.path.join(output_folder, image_name)
#         cv2.imwrite(output_path, image)
#         print(f"Output saved at: {output_path}")

#         # If propellers are detected, save in a separate folder
#         if propeller_boxes:
#             propeller_output_path = os.path.join(propeller_output_folder, image_name)
#             cv2.imwrite(propeller_output_path, image)
#             print(f"Propeller Output saved at: {propeller_output_path}")
        
#     # # Draw propeller detections
#     # if calibration_obj:
#     #     output_image = draw_detections(image, propeller_boxes, (floor_y, floor_y), calibration_obj,floor_results)
#     #     output_path = os.path.join(output_folder, image_name)
#     #     cv2.imwrite(output_path, output_image)
#     #     print(f"Output saved at: {output_path}")

#     #     # If propellers are detected, save in a separate folder
#     #     if propeller_boxes:
#     #         propeller_output_path = os.path.join(propeller_output_folder, image_name)
#     #         cv2.imwrite(propeller_output_path, output_image)
#     #         print(f"Propeller Output saved at: {propeller_output_path}")

#     # Determine the new filename
#     if not coke_detected and not propeller_boxes:
#         new_filename = f"{image_name.split('.')[0]}-2-0-0-0.jpg"
#     elif coke_detected and not propeller_boxes:
#         new_filename = f"{image_name.split('.')[0]}-1-0-0-0.jpg"
#     elif not coke_detected and propeller_boxes:
#         new_filename = f"{image_name.split('.')[0]}-0-0-0-0.jpg"
#     else:  # Both coke bottle and propeller detected
#         propeller_height_cm = max(propeller_heights) if propeller_heights else 0
#         new_filename = f"{image_name.split('.')[0]}-1-0-0-{int(propeller_height_cm)}.jpg"
    
#     # # Save the image with the new filename
#     # output_path = os.path.join(output_folder, new_filename)
#     # cv2.imwrite(output_path, image)
#     # print(f"Output saved at: {output_path}")


#     # Store results
#     image_results.append(f"Photo {i+1} | ID {new_filename} | Ceiling height {ceiling_height} | AC Height {ac_height}")
#     # i += 1



    
#     # Determine the new filename
#     if not coke_detected and not propeller_boxes:
#         new_filename = f"{image_name.split('.')[0]}-2-0-0-0.jpg"
#     elif coke_detected and not propeller_boxes:
#         new_filename = f"{image_name.split('.')[0]}-1-0-0-0.jpg"
#     elif not coke_detected and propeller_boxes:
#         new_filename = f"{image_name.split('.')[0]}-0-0-0-0.jpg"
#     else:  # Both coke bottle and propeller detected
#         propeller_height_cm = max(propeller_heights) if propeller_heights else 0
#         new_filename = f"{image_name.split('.')[0]}-1-0-0-{int(propeller_height_cm)}.jpg"

# # Draw propeller detections
#     if calibration_obj:
#         for idx, (box, real_height) in enumerate(zip(propeller_boxes, propeller_heights_d)):
#             x1, y1, x2, y2 = box
#             label = f"P{idx + 1}: {real_height:.2f} cm"
#             cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Draw bounding box
#             cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)  # Draw correct label
    
#         output_path = os.path.join(output_folder, new_filename)
#         cv2.imwrite(output_path, image)
#         print(f"Output saved at: {output_path}")

#         # If propellers are detected, save in a separate folder
#         if propeller_boxes:
#             propeller_output_path = os.path.join(propeller_output_folder, image_name)
#             cv2.imwrite(propeller_output_path, image)
#             print(f"Propeller Output saved at: {propeller_output_path}")
#     i += 1


    
# # Print final results
# print("\nFinal Results:")
# for result in image_results:
#     print(result)

# %%
def detect_and_measure_propellers(image_path, box_model, round_model, pixel_to_cm_ratio):
    """Detect and measure both round and box propellers in the image."""
    box_results, image = detect_objects(box_model, image_path)
    round_results, _ = detect_objects(round_model, image_path)
    
    measurements = []
    CONFIDENCE_THRESHOLD = 0.58
    
    # Process box propellers
    for result in box_results:
        for i, box in enumerate(result.boxes.xyxy):
            confidence = float(result.boxes.conf[i])
            if confidence < CONFIDENCE_THRESHOLD:
                continue
            x1, y1, x2, y2 = map(int, box.tolist())
            width_px = x2 - x1
            height_px = y2 - y1
            width_cm = width_px * pixel_to_cm_ratio if pixel_to_cm_ratio else "Unknown"
            height_cm = height_px * pixel_to_cm_ratio if pixel_to_cm_ratio else "Unknown"
            measurements.append(("Box", width_cm, height_cm))
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            label = f"W:{width_cm:.2f} cm, H:{height_cm:.2f}cm" if pixel_to_cm_ratio else "Box: Unknown"
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    
    # Process round propellers
    for result in round_results:
        for i, box in enumerate(result.boxes.xyxy):
            confidence = float(result.boxes.conf[i])
            if confidence < CONFIDENCE_THRESHOLD:
                continue
            x1, y1, x2, y2 = map(int, box.tolist())
            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2
            radius_px = max((x2 - x1), (y2 - y1)) // 2
            diameter_px = 2 * radius_px
            diameter_cm = diameter_px * pixel_to_cm_ratio if pixel_to_cm_ratio else "Unknown"
            circumference_cm = np.pi * diameter_cm if pixel_to_cm_ratio else "Unknown"
            measurements.append(("Round", diameter_cm, circumference_cm))
            cv2.circle(image, (center_x, center_y), radius_px, (0, 0, 255), 2)
            label = f"C:{circumference_cm:.2f}cm" if pixel_to_cm_ratio else "Round: Unknown"
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    
    return measurements, image

# %%
import os
import re
import cv2
import numpy as np
from ultralytics import YOLO

def natural_sort_key(filename):
    """Extract numerical values from filenames for correct sorting."""
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', filename)]

# Define folders
image_folder = "Input Dataset folder"
output_folder = "Output_test_folder_combined"
propeller_output_folder = "Output_test_folder_propeller_only"

os.makedirs(output_folder, exist_ok=True)
os.makedirs(propeller_output_folder, exist_ok=True)

# Load models
coke_model = YOLO("best (8).pt")
floor_model = YOLO("best (5).pt")
propeller_model = YOLO("best (9).pt")

ceil_heights = {}  # Store detected ceiling heights
propeller_heights = {}
image_results = []
txt_output_path = os.path.join(output_folder, "detection_results.txt")

# Get and sort image filenames
image_files = sorted(
    [f for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))],
    key=natural_sort_key
)

with open(txt_output_path, "w") as txt_file:
    for i, image_name in enumerate(image_files):
        image_path = os.path.join(image_folder, image_name)

        # Detect Coca-Cola bottle height (for calibration)
        height_pixels, estimated_real_height = detect_height_bottle(image_path, coke_model)
        calibration_obj = (estimated_real_height, height_pixels) if height_pixels else None
        coke_detected = height_pixels is not None

        # Detect ceiling and floor
        floor_results, image = detect_objects(floor_model, image_path)
        ceiling_y, floor_y = get_ceiling_floor_coordinates(floor_results, floor_model)

        if ceiling_y is None or floor_y is None:
            ceiling_height = "XXXXX"
        elif calibration_obj:
            ceiling_height = calculate_height(ceiling_y, floor_y, calibration_obj)
        else:
            ceiling_height = "XXXXX"

        if ceiling_height != "XXXXX":
            ceil_heights[image_name] = ceiling_height

        # Detect propellers (AC)
        propeller_results, _ = detect_objects(propeller_model, image_path)
        propeller_y_bottoms, propeller_boxes = get_propeller_coordinates(propeller_results)

        propeller_heights_details = []
        propeller_heights_d = []
        
        if propeller_boxes and calibration_obj:
            for idx, propeller_y_bottom in enumerate(propeller_y_bottoms):
                real_height = calculate_height(propeller_y_bottom, floor_y, calibration_obj)
                propeller_heights_details.append(f"P{idx + 1}: {real_height:.2f} cm")
                propeller_heights_d.append(real_height.item())

        if propeller_heights_d:
            propeller_heights[image_name] = propeller_heights_d

        ac_height = ", ".join(propeller_heights_details) if propeller_heights_details else "YYYY"

            # Draw vertical reference line
        if ceiling_y is not None and floor_y is not None and ceiling_height != "XXXXX":
            mid_x = image.shape[1] // 2
            cv2.line(image, (mid_x, ceiling_y), (mid_x, floor_y), (0, 255, 0), 3)
            text_position = (mid_x + 10, (ceiling_y + floor_y) // 2)
            cv2.putText(image, f"{ceiling_height:.2f} cm", text_position, cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    



    # If propellers are detected, save in a separate folder
    # if propeller_boxes:
    #     propeller_output_path = os.path.join(propeller_output_folder, image_name)
    #     cv2.imwrite(propeller_output_path, image)
    #     print(f"Propeller Output saved at: {propeller_output_path}")

    # Draw propeller detections
        if calibration_obj:
            for idx, (box, real_height) in enumerate(zip(propeller_boxes, propeller_heights_d)):
                
                x1, y1, x2, y2 = box
                label = f"P{idx + 1}: {real_height:.2f} cm"
                cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Draw bounding box
                cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)  # Draw correct label
    
                output_path = os.path.join(output_folder, image_name)
                cv2.imwrite(output_path, image)
                print(f"Output saved at: {output_path}")

        # If propellers are detected, save in a separate folder
        if propeller_boxes:
            propeller_output_path = os.path.join(propeller_output_folder, image_name)
            cv2.imwrite(propeller_output_path, image)
            print(f"Propeller Output saved at: {propeller_output_path}")

        # Determine the new filename
        new_filename = f"{image_name.split('.')[0]}-1-0-0-0.jpg" if coke_detected else f"{image_name.split('.')[0]}-2-0-0-0.jpg"
        if propeller_boxes:
            propeller_height_cm = max(propeller_heights_d) if propeller_heights_d else 0
            new_filename = f"{image_name.split('.')[0]}-1-0-0-{int(propeller_height_cm)}.jpg"
        
        # Save the image with the modified filename (ensuring only 55 images)
        output_path = os.path.join(output_folder, new_filename)
        cv2.imwrite(output_path, image)
        print(f"Output saved at: {output_path}")

        # Save only propeller images separately
        if propeller_boxes:
            propeller_output_path = os.path.join(propeller_output_folder, new_filename)
            cv2.imwrite(propeller_output_path, image)
            print(f"Propeller Output saved at: {propeller_output_path}")

        # Write only the new filenames to the text file
        txt_file.write(new_filename + "\n")

        # Store results for final output
        image_results.append(f"Photo {i+1} | ID {new_filename} | Ceiling height {ceiling_height} | AC Height {ac_height}")

# Print final results
print("\nFinal Results:")
for result in image_results:
    print(result)

print(f"\nDetection results saved at: {txt_output_path}")
# Out:
# 0: 800x608 1 750ml coke, 29.6ms
# Speed: 2.2ms preprocess, 29.6ms inference, 59.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 4 wallss, 38.8ms
# Speed: 1.0ms preprocess, 38.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageA-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 2 floors, 4 wallss, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAA-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 3 floors, 10 wallss, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAB.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAB.jpeg
# Output saved at: Output_test_folder_combined/imageAB-1-0-0-220.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAB-1-0-0-220.jpg
#
# 0: 800x608 1 750ml coke, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 2 floors, 5 wallss, 6.3ms
# Speed: 1.1ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAC.jpeg
# Output saved at: Output_test_folder_combined/imageAC.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAC.jpeg
# Output saved at: Output_test_folder_combined/imageAC-1-0-0-272.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAC-1-0-0-272.jpg
#
# 0: 800x608 1 750ml coke, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 4 wallss, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAD.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAD.jpeg
# Output saved at: Output_test_folder_combined/imageAD-1-0-0-241.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAD-1-0-0-241.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 6 wallss, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAE.jpeg
# Output saved at: Output_test_folder_combined/imageAE.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAE.jpeg
# Output saved at: Output_test_folder_combined/imageAE-1-0-0-293.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAE-1-0-0-293.jpg
#
# 0: 800x608 1 750ml coke, 7.3ms
# Speed: 3.3ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 5 wallss, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAF.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAF.jpeg
# Output saved at: Output_test_folder_combined/imageAF-1-0-0-237.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAF-1-0-0-237.jpg
#
# 0: 800x608 1 750ml coke, 7.5ms
# Speed: 3.6ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 4 floors, 5 wallss, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 7.0ms
# Speed: 3.3ms preprocess, 7.0ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAG.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAG.jpeg
# Output saved at: Output_test_folder_combined/imageAG-1-0-0-282.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAG-1-0-0-282.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 floor, 1 walls, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAH-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.9ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 ceilings, 2 floors, 10 wallss, 6.2ms
# Speed: 1.4ms preprocess, 6.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAI.jpeg
# Output saved at: Output_test_folder_combined/imageAI.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAI.jpeg
# Output saved at: Output_test_folder_combined/imageAI-1-0-0-300.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAI-1-0-0-300.jpg
#
# 0: 800x608 1 750ml coke, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 5 wallss, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 3 Propellers detection - v1 2025-02-20 11-43ams, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAJ.jpeg
# Output saved at: Output_test_folder_combined/imageAJ.jpeg
# Output saved at: Output_test_folder_combined/imageAJ.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAJ.jpeg
# Output saved at: Output_test_folder_combined/imageAJ-1-0-0-303.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAJ-1-0-0-303.jpg
#
# 0: 800x608 1 750ml coke, 7.0ms
# Speed: 3.2ms preprocess, 7.0ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 4 wallss, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAK.jpeg
# Output saved at: Output_test_folder_combined/imageAK.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAK.jpeg
# Output saved at: Output_test_folder_combined/imageAK-1-0-0-281.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAK-1-0-0-281.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 4 wallss, 6.2ms
# Speed: 1.4ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 9.4ms
# Speed: 4.1ms preprocess, 9.4ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAL-1-0-0-0.jpg
#
# 0: 800x608 2 750ml cokes, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 5 wallss, 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAM-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 8 wallss, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAN.jpeg
# Output saved at: Output_test_folder_combined/imageAN.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAN.jpeg
# Output saved at: Output_test_folder_combined/imageAN-1-0-0-206.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAN-1-0-0-206.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 5 ceilings, 1 floor, 6 wallss, 6.3ms
# Speed: 1.1ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAO-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 7.5ms
# Speed: 3.1ms preprocess, 7.5ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 3 wallss, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 8.0ms
# Speed: 3.1ms preprocess, 8.0ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAP-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 1 walls, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAQ-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 4 wallss, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAR-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 3 floors, 4 wallss, 6.2ms
# Speed: 2.4ms preprocess, 6.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAS.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAS.jpeg
# Output saved at: Output_test_folder_combined/imageAS-1-0-0-258.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAS-1-0-0-258.jpg
#
# 0: 800x608 1 750ml coke, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 6 wallss, 8.1ms
# Speed: 1.6ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAT-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 2 wallss, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAU-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 3 wallss, 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAV-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.8ms
# Speed: 2.2ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 7 wallss, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 3.1ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAW-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 3.1ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 3 wallss, 6.3ms
# Speed: 1.3ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 7.0ms
# Speed: 3.5ms preprocess, 7.0ms inference, 0.3ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAX-1-0-0-0.jpg
#
# 0: 800x608 2 750ml cokes, 6.8ms
# Speed: 2.1ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 6 wallss, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAY-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 3.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 6 floors, 7 wallss, 12.1ms
# Speed: 2.4ms preprocess, 12.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageAZ.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAZ.jpeg
# Output saved at: Output_test_folder_combined/imageAZ-1-0-0-148.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageAZ-1-0-0-148.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 5 floors, 2 wallss, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 7.1ms
# Speed: 3.1ms preprocess, 7.1ms inference, 0.6ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageB-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 2 floors, 8 wallss, 6.2ms
# Speed: 1.4ms preprocess, 6.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageBA.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageBA.jpeg
# Output saved at: Output_test_folder_combined/imageBA-1-0-0-226.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageBA-1-0-0-226.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 floors, 8 wallss, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageBB-1-0-0-0.jpg
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 floors, 1 walls, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageBC-2-0-0-0.jpg
#
# 0: 800x608 2 750ml cokes, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 1 walls, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageC.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageC.jpeg
# Output saved at: Output_test_folder_combined/imageC-1-0-0-233.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageC-1-0-0-233.jpg
#
# 0: 800x608 2 750ml cokes, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 2 wallss, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageD.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageD.jpeg
# Output saved at: Output_test_folder_combined/imageD-1-0-0-216.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageD-1-0-0-216.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 2 wallss, 6.7ms
# Speed: 2.0ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 4 Propellers detection - v1 2025-02-20 11-43ams, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageE.jpeg
# Output saved at: Output_test_folder_combined/imageE.jpeg
# Output saved at: Output_test_folder_combined/imageE.jpeg
# Output saved at: Output_test_folder_combined/imageE.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageE.jpeg
# Output saved at: Output_test_folder_combined/imageE-1-0-0-294.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageE-1-0-0-294.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 5 wallss, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageF-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 5 wallss, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageG.jpeg
# Output saved at: Output_test_folder_combined/imageG.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageG.jpeg
# Output saved at: Output_test_folder_combined/imageG-1-0-0-205.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageG-1-0-0-205.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 floors, 1 walls, 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageH.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageH.jpeg
# Output saved at: Output_test_folder_combined/imageH-1-0-0-299.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageH-1-0-0-299.jpg
#
# 0: 800x608 2 750ml cokes, 10.0ms
# Speed: 3.7ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 4 floors, 1 walls, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 3 Propellers detection - v1 2025-02-20 11-43ams, 7.6ms
# Speed: 3.5ms preprocess, 7.6ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageI.jpeg
# Output saved at: Output_test_folder_combined/imageI.jpeg
# Output saved at: Output_test_folder_combined/imageI.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageI.jpeg
# Output saved at: Output_test_folder_combined/imageI-1-0-0-209.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageI-1-0-0-209.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 2 wallss, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 5 Propellers detection - v1 2025-02-20 11-43ams, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageJ.jpeg
# Output saved at: Output_test_folder_combined/imageJ.jpeg
# Output saved at: Output_test_folder_combined/imageJ.jpeg
# Output saved at: Output_test_folder_combined/imageJ.jpeg
# Output saved at: Output_test_folder_combined/imageJ.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageJ.jpeg
# Output saved at: Output_test_folder_combined/imageJ-1-0-0-256.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageJ-1-0-0-256.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 1 floor, 3 wallss, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 4 Propellers detection - v1 2025-02-20 11-43ams, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageK.jpeg
# Output saved at: Output_test_folder_combined/imageK.jpeg
# Output saved at: Output_test_folder_combined/imageK.jpeg
# Output saved at: Output_test_folder_combined/imageK.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageK.jpeg
# Output saved at: Output_test_folder_combined/imageK-1-0-0-192.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageK-1-0-0-192.jpg
#
# 0: 800x608 2 750ml cokes, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 floor, 3 wallss, 6.3ms
# Speed: 1.2ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageL-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 4 floors, 3 wallss, 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageM.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageM.jpeg
# Output saved at: Output_test_folder_combined/imageM-1-0-0-161.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageM-1-0-0-161.jpg
#
# 0: 800x608 1 750ml coke, 7.2ms
# Speed: 3.1ms preprocess, 7.2ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 5 floors, 3 wallss, 6.3ms
# Speed: 1.3ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageN.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageN.jpeg
# Output saved at: Output_test_folder_combined/imageN-1-0-0-262.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageN-1-0-0-262.jpg
#
# 0: 800x608 2 750ml cokes, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 2 floors, 6 wallss, 6.3ms
# Speed: 1.1ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageO-1-0-0-0.jpg
#
# 0: 800x608 2 750ml cokes, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 3 floors, 5 wallss, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageP-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 ceiling, 1 floor, 4 wallss, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 7.5ms
# Speed: 3.3ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageQ-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 7 wallss, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.9ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageR-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 2 floors, 2 wallss, 6.2ms
# Speed: 2.2ms preprocess, 6.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageS-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 4 wallss, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageT-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 1 floor, 4 wallss, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageU-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 3 ceilings, 4 floors, 8 wallss, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageV-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 9 wallss, 8.3ms
# Speed: 1.7ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 7.9ms
# Speed: 4.8ms preprocess, 7.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageW-1-0-0-0.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 3 floors, 3 wallss, 9.7ms
# Speed: 2.3ms preprocess, 9.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 2 Propellers detection - v1 2025-02-20 11-43ams, 7.0ms
# Speed: 3.1ms preprocess, 7.0ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageX.jpeg
# Output saved at: Output_test_folder_combined/imageX.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageX.jpeg
# Output saved at: Output_test_folder_combined/imageX-1-0-0-246.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageX-1-0-0-246.jpg
#
# 0: 800x608 2 750ml cokes, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 floors, 4 wallss, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 1 Propellers detection - v1 2025-02-20 11-43am, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageY.jpeg
# Propeller Output saved at: Output_test_folder_propeller_only/imageY.jpeg
# Output saved at: Output_test_folder_combined/imageY-1-0-0-256.jpg
# Propeller Output saved at: Output_test_folder_propeller_only/imageY-1-0-0-256.jpg
#
# 0: 800x608 1 750ml coke, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 640x480 2 ceilings, 1 floor, 5 wallss, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 800x608 (no detections), 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 0.4ms postprocess per image at shape (1, 3, 800, 608)
# Output saved at: Output_test_folder_combined/imageZ-1-0-0-0.jpg
#
# Final Results:
# Photo 1 | ID imageA-1-0-0-0.jpg | Ceiling height 307.6309509277344 | AC Height YYYY
# Photo 2 | ID imageAA-1-0-0-0.jpg | Ceiling height 294.55731201171875 | AC Height YYYY
# Photo 3 | ID imageAB-1-0-0-220.jpg | Ceiling height 301.8272399902344 | AC Height P1: 220.19 cm
# Photo 4 | ID imageAC-1-0-0-272.jpg | Ceiling height 315.20770263671875 | AC Height P1: 272.97 cm, P2: 258.21 cm
# Photo 5 | ID imageAD-1-0-0-241.jpg | Ceiling height 321.8530578613281 | AC Height P1: 241.03 cm
# Photo 6 | ID imageAE-1-0-0-293.jpg | Ceiling height 249.3351287841797 | AC Height P1: 293.26 cm, P2: 264.54 cm
# Photo 7 | ID imageAF-1-0-0-237.jpg | Ceiling height 245.53062438964844 | AC Height P1: 237.07 cm
# Photo 8 | ID imageAG-1-0-0-282.jpg | Ceiling height 290.0636901855469 | AC Height P1: 282.88 cm
# Photo 9 | ID imageAH-1-0-0-0.jpg | Ceiling height XXXXX | AC Height YYYY
# Photo 10 | ID imageAI-1-0-0-300.jpg | Ceiling height 343.8098449707031 | AC Height P1: 300.06 cm, P2: 261.20 cm
# Photo 11 | ID imageAJ-1-0-0-303.jpg | Ceiling height 252.31283569335938 | AC Height P1: 303.23 cm, P2: 242.32 cm, P3: 193.99 cm
# Photo 12 | ID imageAK-1-0-0-281.jpg | Ceiling height 338.0352478027344 | AC Height P1: 260.50 cm, P2: 281.64 cm
# Photo 13 | ID imageAL-1-0-0-0.jpg | Ceiling height 294.537353515625 | AC Height YYYY
# Photo 14 | ID imageAM-1-0-0-0.jpg | Ceiling height 344.3485107421875 | AC Height YYYY
# Photo 15 | ID imageAN-1-0-0-206.jpg | Ceiling height 361.7584228515625 | AC Height P1: 204.75 cm, P2: 206.09 cm
# Photo 16 | ID imageAO-1-0-0-0.jpg | Ceiling height 267.79632568359375 | AC Height YYYY
# Photo 17 | ID imageAP-1-0-0-0.jpg | Ceiling height 326.2060546875 | AC Height YYYY
# Photo 18 | ID imageAQ-1-0-0-0.jpg | Ceiling height 314.78265380859375 | AC Height YYYY
# Photo 19 | ID imageAR-1-0-0-0.jpg | Ceiling height 328.735595703125 | AC Height YYYY
# Photo 20 | ID imageAS-1-0-0-258.jpg | Ceiling height 313.198486328125 | AC Height P1: 258.22 cm
# Photo 21 | ID imageAT-1-0-0-0.jpg | Ceiling height 262.61993408203125 | AC Height YYYY
# Photo 22 | ID imageAU-1-0-0-0.jpg | Ceiling height 309.018798828125 | AC Height YYYY
# Photo 23 | ID imageAV-1-0-0-0.jpg | Ceiling height 330.59405517578125 | AC Height YYYY
# Photo 24 | ID imageAW-1-0-0-0.jpg | Ceiling height 278.7346496582031 | AC Height YYYY
# Photo 25 | ID imageAX-1-0-0-0.jpg | Ceiling height 251.76698303222656 | AC Height YYYY
# Photo 26 | ID imageAY-1-0-0-0.jpg | Ceiling height 337.9870910644531 | AC Height YYYY
# Photo 27 | ID imageAZ-1-0-0-148.jpg | Ceiling height 201.94715881347656 | AC Height P1: 148.67 cm
# Photo 28 | ID imageB-1-0-0-0.jpg | Ceiling height XXXXX | AC Height YYYY
# Photo 29 | ID imageBA-1-0-0-226.jpg | Ceiling height 257.3345031738281 | AC Height P1: 226.04 cm
# Photo 30 | ID imageBB-1-0-0-0.jpg | Ceiling height XXXXX | AC Height YYYY
# Photo 31 | ID imageBC-2-0-0-0.jpg | Ceiling height XXXXX | AC Height YYYY
# Photo 32 | ID imageC-1-0-0-233.jpg | Ceiling height 408.877197265625 | AC Height P1: 233.45 cm
# Photo 33 | ID imageD-1-0-0-216.jpg | Ceiling height 328.1866760253906 | AC Height P1: 216.60 cm
# Photo 34 | ID imageE-1-0-0-294.jpg | Ceiling height 368.6846008300781 | AC Height P1: 202.35 cm, P2: 266.27 cm, P3: 294.88 cm, P4: 250.73 cm
# Photo 35 | ID imageF-1-0-0-0.jpg | Ceiling height 351.9521179199219 | AC Height YYYY
# Photo 36 | ID imageG-1-0-0-205.jpg | Ceiling height 321.4570007324219 | AC Height P1: 205.34 cm, P2: 166.18 cm
# Photo 37 | ID imageH-1-0-0-299.jpg | Ceiling height XXXXX | AC Height P1: 299.78 cm
# Photo 38 | ID imageI-1-0-0-209.jpg | Ceiling height 298.92034912109375 | AC Height P1: 193.49 cm, P2: 155.25 cm, P3: 209.89 cm
# Photo 39 | ID imageJ-1-0-0-256.jpg | Ceiling height 379.2301330566406 | AC Height P1: 256.92 cm, P2: 251.86 cm, P3: 233.40 cm, P4: 238.10 cm, P5: 223.27 cm
# Photo 40 | ID imageK-1-0-0-192.jpg | Ceiling height 314.8763427734375 | AC Height P1: 188.50 cm, P2: 192.75 cm, P3: 192.22 cm, P4: 67.17 cm
# Photo 41 | ID imageL-1-0-0-0.jpg | Ceiling height XXXXX | AC Height YYYY
# Photo 42 | ID imageM-1-0-0-161.jpg | Ceiling height XXXXX | AC Height P1: 161.21 cm
# Photo 43 | ID imageN-1-0-0-262.jpg | Ceiling height 299.4074401855469 | AC Height P1: 262.11 cm
# Photo 44 | ID imageO-1-0-0-0.jpg | Ceiling height 300.9940490722656 | AC Height YYYY
# Photo 45 | ID imageP-1-0-0-0.jpg | Ceiling height 322.6451110839844 | AC Height YYYY
# Photo 46 | ID imageQ-1-0-0-0.jpg | Ceiling height 305.1584777832031 | AC Height YYYY
# Photo 47 | ID imageR-1-0-0-0.jpg | Ceiling height 285.68121337890625 | AC Height YYYY
# Photo 48 | ID imageS-1-0-0-0.jpg | Ceiling height 264.60211181640625 | AC Height YYYY
# Photo 49 | ID imageT-1-0-0-0.jpg | Ceiling height 289.5052490234375 | AC Height YYYY
# Photo 50 | ID imageU-1-0-0-0.jpg | Ceiling height XXXXX | AC Height YYYY
# Photo 51 | ID imageV-1-0-0-0.jpg | Ceiling height 273.49163818359375 | AC Height YYYY
# Photo 52 | ID imageW-1-0-0-0.jpg | Ceiling height 323.060302734375 | AC Height YYYY
# Photo 53 | ID imageX-1-0-0-246.jpg | Ceiling height 272.64056396484375 | AC Height P1: 218.11 cm, P2: 246.76 cm
# Photo 54 | ID imageY-1-0-0-256.jpg | Ceiling height XXXXX | AC Height P1: 256.72 cm
# Photo 55 | ID imageZ-1-0-0-0.jpg | Ceiling height 274.90631103515625 | AC Height YYYY
#
# Detection results saved at: Output_test_folder_combined/detection_results.txt

# %%
# import os
# import string

# def number_to_alphabet(n):
#     """Convert number to alphabetic sequence like A, B, ..., Z, AA, AB, ..."""
#     result = ""
#     while n >= 0:
#         result = chr(n % 26 + ord('A')) + result
#         n = n // 26 - 1
#     return result

# # Define folder
# image_folder = "Input Dataset folder"

# # Get and sort image filenames
# image_files = sorted(
#     [f for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))],
#     key=lambda x: int(''.join(filter(str.isdigit, x)))  # Extract numbers and sort
# )

# # Rename files
# for index, image_name in enumerate(image_files):
#     old_path = os.path.join(image_folder, image_name)
#     new_name = f"image{number_to_alphabet(index)}{os.path.splitext(image_name)[1]}"  
#     new_path = os.path.join(image_folder, new_name)
    
#     os.rename(old_path, new_path)
#     print(f"Renamed: {image_name} -> {new_name}")

# print("Renaming completed successfully!")

# %%
txt_output_path = os.path.join(output_folder, "detection_results.txt")

with open(txt_output_path, "w") as txt_file:
    for image_name in image_files:
        # Define the new filename based on detection results
        if coke_detected and not propeller_boxes:
            new_filename = f"{image_name.split('.')[0]}-1-0-0-0.jpg"
        elif not coke_detected and propeller_boxes:
            new_filename = f"{image_name.split('.')[0]}-0-0-0-0.jpg"
        elif not coke_detected and not propeller_boxes:
            new_filename = f"{image_name.split('.')[0]}-2-0-0-0.jpg"
        else:  # Both Coca-Cola bottle and propeller detected
            propeller_height_cm = max(propeller_heights_d) if propeller_heights_d else 0
            new_filename = f"{image_name.split('.')[0]}-1-0-0-{int(propeller_height_cm)}.jpg"

        # Write the formatted filename to the text file
        txt_file.write(new_filename + "\n")

print(f"Detection results saved at: {txt_output_path}")
# Out:
# Detection results saved at: Output_test_folder_combined/detection_results.txt
