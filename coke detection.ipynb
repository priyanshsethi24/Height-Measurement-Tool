# %%
import os
import cv2
import torch
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO("best (8).pt")  # Ensure the correct path

# Define input and output directories
input_folder = "Input_test_folder(3m approx)"  # Folder containing images
output_folder = "coke"  # Folder to save results

# Create output directory if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Confidence threshold (optional) - Ignore very low-confidence detections
CONFIDENCE_THRESHOLD = 0.4  

# Process all images in the input folder
for filename in os.listdir(input_folder):
    if filename.lower().endswith((".jpg", ".jpeg", ".png")):  # Process only image files
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path)

        # Perform inference
        results = model(image)
        
        highest_conf_box = None  # Store the most accurate detection

        # Loop through detections to find the highest confidence one
        for result in results:
            if hasattr(result, 'boxes') and result.boxes is not None:
                for box in result.boxes:
                    confidence = box.conf.item()
                    
                    # Check if confidence is above threshold
                    if confidence >= CONFIDENCE_THRESHOLD:
                        # If no box is stored or the new one has a higher confidence, replace it
                        if highest_conf_box is None or confidence > highest_conf_box['confidence']:
                            highest_conf_box = {
                                'x1': int(box.xyxy[0][0]),
                                'y1': int(box.xyxy[0][1]),
                                'x2': int(box.xyxy[0][2]),
                                'y2': int(box.xyxy[0][3]),
                                'confidence': confidence
                            }

        # Draw only the most accurate detection
        if highest_conf_box:
            x1, y1, x2, y2 = highest_conf_box['x1'], highest_conf_box['y1'], highest_conf_box['x2'], highest_conf_box['y2']
            confidence = highest_conf_box['confidence']

            # Draw bounding box and label
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 3)
            cv2.putText(image, f"Coca-Cola {confidence:.2f}", (x1, y1 - 10), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

        # Save output image
        output_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_path, image)

print("Processing complete. Check 'output_test_folder_coke' for results.")
# Out:
# C:\Users\Priyansh Sethi\anaconda3\anaconda_3\Lib\site-packages\torch\utils\_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
# 0: 800x608 1 750ml coke, 1137.3ms
# Speed: 19.3ms preprocess, 1137.3ms inference, 22.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 920.6ms
# Speed: 9.5ms preprocess, 920.6ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 911.7ms
# Speed: 15.0ms preprocess, 911.7ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 750ml cokes, 929.8ms
# Speed: 12.1ms preprocess, 929.8ms inference, 11.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 989.4ms
# Speed: 9.2ms preprocess, 989.4ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 912.9ms
# Speed: 9.8ms preprocess, 912.9ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 750ml cokes, 922.5ms
# Speed: 10.1ms preprocess, 922.5ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 750ml cokes, 853.2ms
# Speed: 10.1ms preprocess, 853.2ms inference, 3.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 885.0ms
# Speed: 10.6ms preprocess, 885.0ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 968.2ms
# Speed: 11.0ms preprocess, 968.2ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1087.7ms
# Speed: 10.7ms preprocess, 1087.7ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 934.2ms
# Speed: 11.8ms preprocess, 934.2ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 916.4ms
# Speed: 10.5ms preprocess, 916.4ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 926.1ms
# Speed: 10.1ms preprocess, 926.1ms inference, 3.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1037.9ms
# Speed: 12.0ms preprocess, 1037.9ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 910.0ms
# Speed: 10.1ms preprocess, 910.0ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1087.8ms
# Speed: 10.6ms preprocess, 1087.8ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 750ml cokes, 912.7ms
# Speed: 11.6ms preprocess, 912.7ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1268.4ms
# Speed: 10.1ms preprocess, 1268.4ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1003.2ms
# Speed: 11.5ms preprocess, 1003.2ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1299.7ms
# Speed: 9.5ms preprocess, 1299.7ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1216.2ms
# Speed: 10.4ms preprocess, 1216.2ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 750ml cokes, 943.5ms
# Speed: 9.7ms preprocess, 943.5ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1080.6ms
# Speed: 10.9ms preprocess, 1080.6ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 931.2ms
# Speed: 9.6ms preprocess, 931.2ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1116.0ms
# Speed: 10.9ms preprocess, 1116.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 898.7ms
# Speed: 9.7ms preprocess, 898.7ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 992.5ms
# Speed: 9.6ms preprocess, 992.5ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1197.8ms
# Speed: 11.2ms preprocess, 1197.8ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1096.7ms
# Speed: 10.1ms preprocess, 1096.7ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1364.7ms
# Speed: 10.6ms preprocess, 1364.7ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 934.4ms
# Speed: 9.7ms preprocess, 934.4ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 750ml cokes, 983.9ms
# Speed: 8.9ms preprocess, 983.9ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 750ml cokes, 972.1ms
# Speed: 10.7ms preprocess, 972.1ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 949.9ms
# Speed: 10.5ms preprocess, 949.9ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1023.8ms
# Speed: 9.0ms preprocess, 1023.8ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 998.2ms
# Speed: 7.9ms preprocess, 998.2ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 573.3ms
# Speed: 9.4ms preprocess, 573.3ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 536.0ms
# Speed: 9.6ms preprocess, 536.0ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1045.3ms
# Speed: 9.4ms preprocess, 1045.3ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1089.9ms
# Speed: 9.8ms preprocess, 1089.9ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 894.5ms
# Speed: 10.1ms preprocess, 894.5ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 899.0ms
# Speed: 9.3ms preprocess, 899.0ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 918.2ms
# Speed: 12.2ms preprocess, 918.2ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 991.0ms
# Speed: 9.4ms preprocess, 991.0ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1051.6ms
# Speed: 8.9ms preprocess, 1051.6ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 750ml cokes, 1006.0ms
# Speed: 10.5ms preprocess, 1006.0ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1048.1ms
# Speed: 9.2ms preprocess, 1048.1ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 881.1ms
# Speed: 8.6ms preprocess, 881.1ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 456.5ms
# Speed: 12.0ms preprocess, 456.5ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 486.1ms
# Speed: 9.6ms preprocess, 486.1ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 1053.3ms
# Speed: 18.3ms preprocess, 1053.3ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 1 750ml coke, 402.8ms
# Speed: 7.9ms preprocess, 402.8ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 608)
#
# 0: 800x608 2 750ml cokes, 1187.2ms
# Speed: 9.3ms preprocess, 1187.2ms inference, 4.7ms postprocess per image at shape (1, 3, 800, 608)
# Processing complete. Check 'output_test_folder_coke' for results.

# %%
# import os
# import cv2
# import torch
# from ultralytics import YOLO

# # Load the YOLOv8 model
# model = YOLO("best (8).pt")  # Ensure the correct path

# # Define input and output directories
# input_folder = "Input_test_folder(3m approx)"  # Folder containing images
# output_folder = "output_test_folder_coke"  # Folder to save results

# # Create output directory if it doesn't exist
# os.makedirs(output_folder, exist_ok=True)

# # Process all images in the input folder
# for filename in os.listdir(input_folder):
#     if filename.lower().endswith((".jpg", ".jpeg", ".png")):  # Process only image files
#         image_path = os.path.join(input_folder, filename)
#         image = cv2.imread(image_path)
        
#         # Perform inference
#         results = model(image)
        
#         # Draw bounding boxes
#         for result in results:
#             for box in result.boxes:
#                 x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates
#                 confidence = box.conf[0].item()  # Confidence score
#                 label = int(box.cls[0].item())  # Class label
                
#                 # Draw rectangle and label on image
#                 cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 3)
#                 cv2.putText(image, f"Coca-Cola {confidence:.2f}", (x1, y1 - 10), 
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
        
#         # Save output image
#         output_path = os.path.join(output_folder, filename)
#         cv2.imwrite(output_path, image)

# print("Processing complete. Check 'detect_coke_bottle' folder for results.")
